# %% [markdown]
# ### 데이터셋 준비 하기
# Instruction Fine Tuning을 위해 데이터셋을 준비합니다.
# 데이터셋은 아래의 순서로 준비합니다.
# ---
#
# 1. 도메인 정하기
# 부동산에 대해 잘 대답할 수 있는 챗봇을 타겟으로 설정합니다.
#
# 2. 부동산에 관련된 키워드를 생각해보기
# 책, 뉴스, 부동산 사이트에서 키워드를 수집합니다. 사람들이 궁금해할만한 키워드를 대상으로 합니다. (예: 전세 계약, 신혼부부 특별공급, 토지거래허가구역...)
#
# 3. 부동산 키워드를 통해 사람들이 찾아볼만한 질문리스트 만들어보기(`query.jsonl`)
# 2번에서 수집한 키워드를 기반으로, 사람들이 궁금해할만한 질문리스트를 ChatGPT를 활용해 만들어봅니다. 충분한 데이터셋 확보할 만큼의 질문리스트를 생성합니다.
#
# 4. 질문리스트로 네이버에 검색하여 인기 글 데이터 수집하기(`search_data.json`)
# 3번에서 수집한 질문리스트를 Selenium 라이브러리를 활용하여 네이버에 검색합니다. 검색 결과중 인기글의 텍스트 데이터를 추출합니다.
#
# 5. encoder 모델을 활용하여 데이터를 유사도 기준으로 정렬하기(`search_data.json`)
# 4번에서 수집한 인기글 텍스트 데이터가 질문리스트와 얼마나 유사한지 계산합니다.
# 질문리스트와 가장 유사한 인기글 텍스트를 상위 순위로 정렬합니다.
#
# 6. Instuction 데이터셋 만들기(`instruction.jsonl`)
# 질문리스트 + 정렬한 인기글을 합쳐서 ChatGPT에 Instruction 데이터를 만들어달라고 요청합니다. 이 Instruction 데이터는 Fine Tuning에 사용됩니다.

# %%
# !pip install --quiet\
selenium==4.20.0\
openai==1.23.6\
datasets==2.19.0\
accelerate==0.27.2\
flash-attn==0.2.4\
peft==0.10.0\
trl==0.8.6\
transformers==4.40.1\
python-dotenv==1.0.1

# %%
import json
from tqdm import tqdm
from transformers import AutoModel, AutoTokenizer

import utils
import prompts
import similarity

# %% [markdown]
# ### 2. 부동산에 관련된 키워드를 생각해보기
# 부동산에 관련된 키워드를 수집하여 저장합니다.
# 예시 데이터는 `seed_words.txt` 파일로 제공합니다.

# %%
with open("./data/seed_words2.txt", "r") as f:
    seed_words = f.readlines()

# %%
seed_words[:4]
# Out:
# ['부동산 매도\n', '부동산 매수\n', '부동산 가계약금\n', '부동산 계약금\n']

# %%
# Element마다 있는 \n 제거, '전세 계약\n' -> '전세 계약'
seed_words = list(map(lambda x: x.strip("\n"), seed_words))

# %%
seed_words[:4]
# Out:
# ['부동산 매도', '부동산 매수', '부동산 가계약금', '부동산 계약금']

# %% [markdown]
# ### 3. 부동산 키워드를 통해 사람들이 찾아볼만한 질문리스트 만들어보기
# `format` 메서드를 적용할 수 있게 프롬프트를 미리 작성합니다.
# 미리 작성된 프롬프트에 `seed_words`를 `format` 적용하여 프롬프트를 완성시킵니다.
# 예시 데이터는 `query.jsonl` 파일로 제공합니다.

# %%
print(prompts.SEED_WORD_PROMPT_PREFIX + prompts.SEED_WORD_PROMPT_CONTENT)
# Out:
# 주어진 seed_word에 대해 궁금해할 질문을 10개를 생성하세요.
# 만들어내는 문장들은 어휘의 다양성을 위해 다양한 단어를 사용해야합니다.
# 만들어낸 질문은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 아래 양식으로 출력하세요:
# {{"seed_word": "{seed_word}", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}}

# %%
print(prompts.SEED_WORD_PROMPT_PREFIX + prompts.SEED_WORD_PROMPT_CONTENT.format(seed_word=seed_words[0]))
# Out:
# 주어진 seed_word에 대해 궁금해할 질문을 10개를 생성하세요.
# 만들어내는 문장들은 어휘의 다양성을 위해 다양한 단어를 사용해야합니다.
# 만들어낸 질문은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 아래 양식으로 출력하세요:
# {"seed_word": "부동산 매도", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}

# %%
# 모델에게 Prefix 토큰을 중복해서 전달할 필요가 없으므로, Prefix 토큰은 1번만 사용하고 Content을 반복해서 프롬프트를 생성
seed_word_prefix = prompts.SEED_WORD_PROMPT_PREFIX
seed_word_content = [prompts.SEED_WORD_PROMPT_CONTENT.format(seed_word=s) for s in seed_words]

# %%
# 모델에게 Prefix 토큰을 중복해서 전달할 필요가 없으므로, Prefix 토큰은 1번만 사용하고 Content을 반복해서 프롬프트를 생성
# 1개의 Prefix 마다 10개의 Content를 추가한다
seed_word_prompts = []
total_prompts = len(seed_words) // 10
for idx in range(1, total_prompts+2):
    start_index = (idx -1) * 10
    end_index = idx * 10
    seed_word_prompt = seed_word_prefix + "\n".join(seed_word_content[start_index:end_index])
    seed_word_prompts.append(seed_word_prompt)

# %%
print(seed_word_prompts[0])
# Out:
# 주어진 seed_word에 대해 궁금해할 질문을 10개를 생성하세요.
# 만들어내는 문장들은 어휘의 다양성을 위해 다양한 단어를 사용해야합니다.
# 만들어낸 질문은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 아래 양식으로 출력하세요:
# {"seed_word": "부동산 매도", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 매수", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 가계약금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 계약금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 중도금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 잔금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 배액배상", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 계약금 포기", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "실거래신고", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 취득세 신고", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}

# %%
for prompt in tqdm(seed_word_prompts[1:]):
    completion = utils.get_completion(prompt, model="gpt-4-turbo")
    with open("./data/query2.jsonl", "a", encoding="utf-8") as f:
        for line in completion.split("\n"):
            f.write(line)
            f.write("\n")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [18:45<00:00, 140.70s/it]

# %%
with open("./data/query2.jsonl", "a", encoding="utf-8") as f:
    for line in completion.split("\n"):
        f.write(line)
        f.write("\n")

# %%
print(seed_word_prompts[0])
# Out:
# 주어진 seed_word에 대해 궁금해할 질문을 10개를 생성하세요.
# 만들어내는 문장들은 어휘의 다양성을 위해 다양한 단어를 사용해야합니다.
# 만들어낸 질문은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 아래 양식으로 출력하세요:
# {"seed_word": "부동산 매도", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 매수", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 가계약금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 계약금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 중도금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 잔금", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 배액배상", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 계약금 포기", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "실거래신고", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}
# {"seed_word": "부동산 취득세 신고", "answer": ["1번째 질문", "2번째 질문"... , "10번째 질문"]}

# %% [markdown]
# ### 4. 질문리스트로 네이버에 검색하여 인기 글 데이터 수집하기
# 3번에서 생성한 질문리스트를 selenium 라이브러리를 통해 네이버로 검색합니다.
# 검색 결과의 인기글의 텍스트 정보를 저장합니다.
# 예시 데이터는 `search.jsonl`로 제공합니다.

# %%
query_data = utils.jload("./data/query2.jsonl")

# %%
query_data[:2]
# Out:
# ['{"seed_word": "부동산 매도", "answer": ["부동산 매도 시 필요한 서류는 무엇인가요?", "부동산 매도 과정에서 가장 중요한 점은 무엇인가요?", "부동산 매도 시 시장 가격을 어떻게 평가하나요?", "부동산 매도 후 세금은 어떻게 계산되나요?", "부동산 매도를 위해 중개인을 선정하는 기준은 무엇인가요?", "부동산 매도 시 주의해야 할 법적 문제는 무엇인가요?", "부동산 매도 과정에서 자주 발생하는 문제는 무엇인가요?", "부동산 매도 시 가격 협상 팁은 무엇인가요?", "부동산 매도를 결정할 때 시장의 어떤 요소를 고려해야 하나요?", "부동산 매도 시 이전 소유주의 책임은 어디까지인가요?"]}\n',
#  '{"seed_word": "부동산 매수", "answer": ["부동산 매수 전에 확인해야 할 주요 사항은 무엇인가요?", "부동산 매수 시 가장 중요한 검토 포인트는 무엇인가요?", "부동산 매수 과정에서 흔히 저지르는 실수는 무엇인가요?", "부동산 매수 시 시장 분석은 어떻게 해야 하나요?", "부동산 매수를 위한 최적의 시기는 언제인가요?", "부동산 매수 시 필요한 재정 계획은 어떻게 세워야 하나요?", "부동산 매수 후 유지 관리 비용은 어느 정도인가요?", "부동산 매수 시 법적 검토는 어떻게 이루어지나요?", "부동산 매수 시 중개인의 역할은 어떻게 중요한가요?", "부동산 매수 시 교통 편의성을 어떻게 평가하나요?"]}\n']

# %%
queries = []
for line in query_data:
    query = json.loads(line)
    queries = queries + query['answer']

# %%
queries[:5]
# Out:
# ['부동산 매도 시 필요한 서류는 무엇인가요?',
#  '부동산 매도 과정에서 가장 중요한 점은 무엇인가요?',
#  '부동산 매도 시 시장 가격을 어떻게 평가하나요?',
#  '부동산 매도 후 세금은 어떻게 계산되나요?',
#  '부동산 매도를 위해 중개인을 선정하는 기준은 무엇인가요?']

# %%
len(queries)
# Out:
# 830

# %% [markdown]
# selenium이 4.1 버전으로 업그레이드 되면서 별도로 webdriver를 다운로드 받을 필요가 없어졌습니다.
# webdriver 파일이 없으면 selenium이 자체적으로 다운로드하게 된다고 합니다. [stackoverflow](https://stackoverflow.com/questions/22130109/cant-use-chrome-driver-for-seleniumhttps://stackoverflow.com/questions/22130109/cant-use-chrome-driver-for-selenium)
# 본 예제의 selenium 코드 크롤링 코드는 [wikidocs](https://wikidocs.net/137914) 내용을 참조하였습니다.

# %%
search_data = utils.get_document_through_selenium(queries, n_documents=5, indent=4, save_path="document2.json")
# Out:
# 830it [06:18,  2.19it/s]

# %%
search_data
# Out:
# [{'question': '부동산 매도 시 필요한 서류는 무엇인가요?',
#   'document': ['부동산매매서류 부동산 매수 매도 매매시필요서류 여기까지 부동산 매매시 필요서류에대해서 알아보았습니다 롯데건설에서 제공하는 주거시설 입주가예정되어 있고 주변 분양시장도 호황입니다. 많은 관심을 가지고 계시는 곳 중 하나라고 볼 수 있는데 현재 매물로 나왔던 아파트는 실거래가가 약 평으로 형성됩니다. 는 있지만 지금이 급매물이 나와 있는걸 확인했어요....',
#    '참고로 재외국민등록이 되어 있지 않다면, 처분 위임장,인감증명서 발급 위임장, 주민등록초본, 등기필증 등 기본적인 서류만 필요하기에 보다 더 간단합니다. 해외에서 한국 부동산 매도하는 일이 흔치 않아 헷갈려하시는 분들이 있을텐데요, 일단 한국부동산 매도 계획이 있으신 분 중 재외국민등록을 생각하시는 분들은 기를 감안하여 등록하시길...',
#    '부동산 매도 시 필요한 서류들을 처리하다가 남겨놓으면 좋을 것 같아 포스팅합니다. 소유권이전등기 필요서류 (매도인) 1. 인감증명서(부동산매도용) 1통 2. 인감도장 3. 주민등록초본(주소변동사항 포함) 1통 4. 등기권리증(=등기필증) 5. 신분증(주민등록증 또는 운전면허증) *부동산 매도용 인감증명서의 매수인란에 매수인의 성명, 주민등록주소(주민등록초본 상 현주소)...',
#    '부동산 찾으시는 분들은 서민안심전환대출을 정부대출 찾으시는 분들은 정부 서민금융대출부터 조회해보세요. 부지원 대환대출 신청 목차 1. 서론 2. 정부지원 대환대출이란 무엇일까... 정부지원 대환대출을 신청하기 위해 필요한 서류는 무엇인가요? A2. 사업 계획서, 신용등급 증빙 , 담보 등이 합니다. * 자세한 내용은 각 기관 홈페이지 참고 Q3. 정부지원...',
#    '센텀오피스텔 부동산 매도 시 필요한 서류? 안녕하세요, 센텀오피스텔 분양 프렌즈엠입니다. 오늘은 부동산에 관심이 있으신 분들이라면 모두 궁금해하실 부동산 매도에 관련된 내용에 대해 말씀을 드리려고 합니다. 평소 부동산 매도인과 매수인의 필요 서류 등 다양한 궁금증을 가지셨던 분들께서는 이번 포스팅을 통해 다양한 정보 얻어 가시길 바라겠습니다....']},
#  {'question': '부동산 매도 과정에서 가장 중요한 점은 무엇인가요?',
#   'document': ['평택 고덕 힐스테이트 스카이시티 전문부동산 (매수, 매도, 전세, 월세) 안녕하세요. 신뢰와 노력으로 응대하는 아침부동산입니다. 최근 평택 고덕 힐스테이트 단지는 입주민들을... 입지안내 단지의 규모, 환경 등 생활함에 있어 필요한 검토 사항이지만 이보다 것은 어느 위치에 자리 잡고 있어 어떠한 생활 편의성을 제공해줄 수 있는지 확인하는 것이 하...',
#    '매도청구소송의 진행원인인 협의매수 불성립이 매매가격 문제가 절대적이라는 점에서 감정평가는 매우 중요하다고 보는데 법원은 감정 내용에 명백한 결함이 없는 한 검정평가 결과에... 이처럼 이것을 비롯한 부동산과 관련된 분쟁은 과정이 어렵고 이해관계에 얽혀 절차가 복잡해 어려움이 생길 수 있으므로 법률대리인과 법리적인 부분에 대해서 제대로 알고 대응해...',
#    '안양부동산변호사, 세입자월세미납 무조건 소송해야할까요 ? 이 글을 보신 분들만 알 수 있는 내용 [왜 안양사무소에서 대륜을 찾아야하나요 ?] 지방법원의 특성을 가장 잘 아는 것은... 오늘은 이와 같은 고민을 가지신 분들을 위해서 안양부동산변호사가 대응 방법에 대해 알려드리도록 하겠습니다. 1. 명도 소송이란? Q. 임대인이 소 제기를 하게 되는 이유는 ...',
#    '안녕하세요~ 오래 검증되고 깊이가 다른 실전 중개교육의 명가~ 부동산멘토스쿨입니다 부동산 세무 전문가 과정도 벌써 이번 주 7회차 수업이 진행되었습니다. 7주차 수업은 지난주... 다주택자의 양도세 중과를 계산할 때 가장 중요한 것은 주택의 수를 산정하는 것입니다. 다주택자가 보유한 주택이 5채라고 하더라도 이것은 세금을 계산하는 것이므로 양도소득세 중과...',
#    '부동산명의신탁 사건에 휘말렸다면 부동산의 경우 우리 삶에 있어 굉장히 중요한 요고이기 때문에 많은 사람들이 원하며 어느 정도의 재산적 여력이 없다면 소유하는 것조차 어렵다고... "부동산처분금지 가처분이 선행되어야 하는 일이기 때문에" 아무리 실소유권자가 본인이라고 해도 법적 권한을 넘겨준 상황이기 때문에 상대가 임의로 건물을 한다고 해도 제재할...']},
#  {'question': '부동산 매도 시 시장 가격을 어떻게 평가하나요?',
#   'document': ['성수기라면 좋은 가격에 매도가 가능하지만, 비성수기라면 수요자가 없기때문에 예상했던 가격보다 가격을 더 조정해야하거나 매매나 임대완료까지 시간이 소요될 수 있습니다. 또한 주변에 많은 입주물량이 있는겨우 매매물건이나 임대물건이 시장에 많이 공급되기 때문에 일시적으로 공급물량이 많아져 시세가 떨어지는 경우가 발생합니다. 아파트 뿐만 아니라...',
#    "위에서 언급한 문제이외에도 주거용 부동산도 경제학적 관점에서는 수요와 공급 측면에서의 분석도 필요합니다. 그 과정에서 사용한 데이터나 지표 등을 어떻게 사용하느냐에... 그러나, 부동산 시장 상황이 전체적으로는 매수 우위 시장이라 매도하는 것이 쉽지는 않을 것입니다. '26년 지방선거, '27년 대선, '28년 총선으로 이어지는 정치 일정에서 어떤 여론이...",
#    '사실이라면 어떻게 되는지 알아보고 계신 분들이 많으셨던 것 같습니다가 그래서 더 자세한 내용에 대해서도 자세하게 알아볼까 고민 중입니다. 그래서 오늘 글에서는 부동산 매수 매도 매매시필요서류에 대해서 알아볼까 까지 같이 알아보도록 하겠습니다. 아파트 및 매물의 살펴보았으니 자세히 살펴보는 시간을 갖도록 하고 싶었기에 이렇게 글을...',
#    '인근 부동산에 거의 모두 뿌린다고 생각하면 된다고 말씀하셨습니다 특히 엠제이님께서는 매매를 가장 잘 하는 방법으로 싼가격 예쁜집 싸고 예쁜 집 이렇게 3가지를 예시로 들었는데요! 매매를 낼 때는 현장마다 다르지만 리모델링을 한 집의 경우 광고 시 이를 강조하고 이번 사례의 물건처럼 비록 새 집은 아니지만 물건의 상태가 좋을 경우엔 현 상태로 에 내놓아...',
#    '결국 "부동산 매수/매도는 사람의 사정이 만드는 것"이다. 생각 정리 작년부터 관심 아파트 시세 모니터링만 했왔으나, 좋은 가격들과 시기들을 다 놓쳤다. 이제 매물들이 다 빠져서 좋은 가격, 원했던 RR 매물들이 사라졌지만, 지금 3-4달 전의 매물 상황이 그대로래도 결정하지 못했을 것이다. 지금보다 저렴하게 남아있어도 비싸다고 생각했을 수도 있다. 그래서 결국...']},
#  {'question': '부동산 매도 후 세금은 어떻게 계산되나요?',
#   'document': ['아파트 매도 세금 계산하려면 범무사 비용을 알면 되고 등기 후 받은 서류에 나오는데요. 취득 중개수수료는 없고, 권리를 매도하는 거라면 중개사분이 있을 수 있어 발생할 수는 있습니다. 기타 필요금액에 양도 중개수수료가 있다면 증빙 영수증을 첨부합니다. 가치 증대, 용도변경으로 개조하면 그 비용도 넣고, 자본적 지출을 줄일 수 있는데 수리나...',
#    '아파트 매도 세금 계산시 법무사 비용도 알아둬야 되는데 등기 후 받은 서류에 명시되어 있습니다. 분양은 취득 중개수수료는 없는데요. 만일 이 권리를 산 것이라면 있을 수 있어 이 또한 확인하면 됩니다. 기타 필요금액에 양도 중개수수료도 있는데 증빙 영수증도 첨부해야 됩니다. 가치 증대나 용도변경을 위해 개조를 했다면 해당 비용도 넣어 자본적 지출을...',
#    '안녕하세요~ 오늘은 부동산투자 시 아파트 및 주택 단기보유, 장기보유 후 매도 시 양도세 세금, 과세표준, 세율 및 안전마진 계산방법에 대해서 공유해 보려고 해요! 1. 단기 매도(단타) 먼저 2년 미만의 기간, 주택, 빌라, 아파트 보유 후 매도할 경우의 양도소득세(양도세)부터 알아볼게요~ [단기보유의 기준] 거래, 매매, 경매 낙찰 이후 2년 미만으로 주택을...',
#    '분양권 매도 시 세금은 어떻게 계산할까? 분양권은 주택일까? 분양권을 매도하거나 매수하는 사람이라면, 주택을 취득할 수 있는 권리인 분양권이 세법에서 어떻게 판단되는지 세금 관계를 정확히 이해해야 한다. 요즘 부동산 시장에서는 분양권 자체를 구하는 것도 어려워, 자의 프리미엄은 계속 올라가는 추세다. 매물이 귀하다 보니, 이제는 프리미엄도...',
#    '이 양도세 계산은 제가 매수 할 때 금액과 매도할 시점의 금액에서 발생한 이익분의 40%(?) 를 세금으로 내나요? 제가 궁금한 부분을 글로 설명하기가 어렵네요..;; 한마디로 1가구 2주택으로 쭉 살 경우 매년 내야되는 세금이 무엇인지. . 얼마정도되는지. . 팔때는 어떤 세금이 있는지 궁금합니다 부동산쪽으로 잘 아시는 분 저 좀 알려주세요']},
#  {'question': '부동산 매도를 위해 중개인을 선정하는 기준은 무엇인가요?',
#   'document': ['그러고 나서 매도를 한 집의 잔금 기준으로 매수를 맞춰보는 것입니다. 당연히 거래시기도 매수할 곳을 알아보기 위해 여유를 어느 정도 둡니다. 거래 시기가 언제쯤이냐에 따라... 부동산 중개인을 하다 보면 많은 우여곡절을 겪습니다. 그래도 그 위기를 잘 벗어나서 좋은 거래가 될 때는 그동안 힘든 것도 다 잊어버립니다. 그런 맛에 일하는 거니까요.^^ 블로그...',
#    '부동산 급매란 무엇인가? 다른 집들의 시세보다 저렴한 값에 나온 매물을 뜻하며, 급하게 처분하기 위해 싸게 팔려는 의도가 담긴 집입니다. 그리고 이를 급매물이라고 부르는데, 대개 2가지 사정에 의해 시장에 등장합니다. 첫 번째 케이스는 소유주의 개인적인 사정에 의한 능동적인 입니다. 여기서 사정이라 함은 시세가 급격히 떨어지는 침체기 또는 하락장이...',
#    '부동산 조정 대상 지역이란 무엇인가? 선정 기준과 규제를 알아보자 부동산 시장 조정 지역은 정부가 주택시장의 과열을 억제하고 시장을 안정화시키기 위해 선정하는 특정 지역들을... 거래 활성화 : 규제의 해제는 부동산 거래를 촉진시킬 수 있습니다. 규제 완화는 매수자와 자 양쪽에게 더 많은 기회를 제공하며, 결국 거래량 증가로 이어질 수 있습니다. 시장...',
#    '매도청구권 확실한 대응은 개발지 선정에 대해 모두가 쉽게 받아들이는 것이 아니라 각별히 애정을 쏟은 터를 떠나라는 요청을 받고 소유한 토지를 국가사업에 사용하는 것에 불만을... 시점을 기준으로 다시 감정을 하게 되고, 현금으로 보상을 받으면 얼마나 평가되는지가 청구 소송에서 주요한 부분입니다. 재건축 사업을 시행하면서 소유자에게 지급돼야 할...',
#    '그렇기에 파트너를 선정할 때는 까다로운 기준으로 선택하시기를 바랍니다. “경제백과를 선택해야 하는 이유” 그럼 어떤 기준으로 고르셔야 하는지 간단히 짚어 보는 시간을 갖겠습니다. 먼저 시장 흐름 분석 자료를 제공하는지 그리고 해외 선물 지식 습득을 위한 교육자료를 받아 볼 수 있는지입니다. 무엇보다 수익률을 꾸준하게 안정적으로 가져가는 곳인지를...']},
#  {'question': '부동산 매도 시 주의해야 할 법적 문제는 무엇인가요?',
#   'document': ['서초부동산전문변호사 법적 대처는 법치주의 공동체에서 활동하기 원하면 판정하는 생활 전술 및 제약를 엄수하고 또는다른 주변인과 배려하는 환경에서 생활한다 지적했어요. 안전성... 서초부동산전문변호사는 강조를 수정하는 뜻하고서 사건 종결이 곤란한 점을 입장에야 한다고 조심하였는데요. 유흥업소를 찾아간 K씨는 업소녀 O씨와 연쇄적인 가 비롯했다고...',
#    '서초부동산전문변호사 법적 대처는 법치주의인 나라에서 생활을 위해서는 확정한 삶 방법 및 제한을 준수하고 다른 여럿과 협력하는 상황으로 지내온다 강조했어요. 안전 확립이... 이미 알아차린 사실에선 서초부동산전문변호사는 말을 변경하는 실정에선 사건 수습이 복잡한 점을 파약해야 한다고 경고했죠. 여관을 들어갔던 S씨는 윤락녀 I씨와 재차 가 존재했다고...',
#    '조사하는 부분이 어려워지는 것은 당연한 사안이고, 피의자 처지에 포함된 처지에서 신속하게 개인적인 언급을 하는 것이 난처한 이유에 성남부동산소송전문변호사는 사항에 대처하지... 문제가 발생한 상황에 서로 동의를 마치고 발생한 성적 태도가 이유가 돼 분하게 피의자로 인정됐다면 대책을 마련해 긍정적이지 않은 논의은 하고, 입장을 받아 신뢰가...',
#    '신탁 문제가 중대한 수준에 이르면 수탁자 또한 불리한 상황에 놓이기 때문에, 항상 신중하게 생각해야 하였습니다. 실제 이와 관련해 보유하고 있는 대상이라면 최초 등기 시기를 토대로 살펴봤을 때 7년 이상 시효를 적용할 수 있고, 또 신탁자는 3년의 공소시효가 있어 이 기한을 넘기면 공소 제기를 수 없게 되기 때문에 가 필요하였습니다. 이 제도는 과...',
#    '부동산전세사기 법적 대처는 사회초년생과 청년층을 중개소로 끌어들여 가짜로 피해를 주는 사건 등 다양한 모습으로 나타나고 있고 매매가격이 전세가격과 비슷하거나 같거나 혹은... 살펴봐야 할 항목이 있는 것은 아닌지 면밀한 체크가 필요하고, 하나부터 열까지 확인해서 아무리 전세사기에 대비한다 하더라도 당장 하게 될 수 있는 만큼 더욱 깊게 살펴야...']},
#  {'question': '부동산 매도 과정에서 자주 발생하는 문제는 무엇인가요?',
#   'document': ['부천부동산전문변호사는 수사가 매우 H씨에게 심리적인 상해를 불러왔다는 실상을 지적했으며, A 씨가 조사 과정에서 근거 인멸까지도 청한 사실이 있는 자료를 원인으로써... 부천부동산전문변호사의 동행으로 해소된 문제를 살펴보겠습니다. 방문자 C와 A직원은 충분한 의견 충돌이 겪었으며, 그들 관계는 나쁜 감정이 됐다며 단언했는데요 해당 범행은 C직원이...',
#    '이미 알아챈 와중에선 부산부동산전문변호사는 단언을 뒤바꾸는 경우엔 사건 수습이 복잡한 점을 깨달아야 한다고 경고합니다. 야간주점에 들어간 C씨는 매춘부 M씨와 자주 갈등이... 부산부동산전문변호사의 동행으로 해소된 문제들을 제시해보겠습니다. 사용자 S와 W직원은 평소 깊은 의견 대립이 했고, 그들 관계는 나쁜 분위기가 일어났다고 충고했죠 관련 범행은...',
#    '발견된 상황에서 부산부동산전문변호사은 진술을 번복할 경우 사건 종결의 복잡성을 고려해야 한다고 밝혔다. 유흥업소를 방문한 c씨는 커리어우먼 S씨와 자주 싸웠다고 진술했다.... 동료들의 제보로 수사가 시작됐고, 수사 과정에서 담당 수사관과 상대방이 동료 관계라는 진실이 지각됐다. 유족들은 격분해 재빨리 c씨를 체포했지만 수사기관은 증거 불충분을 이유로...',
#    '하지만 과도한 투자 심리를 통하여 실패를 경험하는 인간들이 생성하게 되자, 정부에서는 문제를 수습하기 위하여 임계를 통해서 대처를 준비했다고 했습니다. 하지만 한도가... 부동산법률상담을 통하여 사안에 관해서 고발인에게 자주소지 손해가 생겨나게 됐다고 했습니다. 작년 고발인의 개인 주소지 데이터를 악용하기 위한 방식으로 모형 실리콘 손가락 모형을...',
#    '이처럼 부동산 급매는 오르든 내리든 시장의 추세가 급변할 때 자주 등장합니다. 그런데 거래량이 많아지고 시세가 급격히 변화하는 와중에는 경험과 정보가 부족하는 등의 이유로 늦게 대처하는 매도인이 많습니다. 예를 들어 볼까요? 자녀의 학업 문제로 인하여 김 씨는 타 지역으로 이사를 가야 합니다. 그래서 집을 내놓으려 을 찾아가니 비슷한 스펙의 주택들...']},
#  {'question': '부동산 매도 시 가격 협상 팁은 무엇인가요?',
#   'document': ['흔히 매도 및 사는법을 많이 찾습니다. 분양권 살 때 필요자금은 분양계약금, 확장비, 옵션 비용, 프리미엄, 양도소득세라는 점 참고하시면 되겠습니다. 더불어 사기 거래도 있습니다. 일반 부동산 거래 시 등기부등본 확인하면 됩니다만 분양 계약서 가지고 장난치면 그대로 당할 수 있으므로 반드시 꼭 조심하셔서 계약 진행하시길 바랍니다. 갈아타기는 ...',
#    '집을 살 때, 매도 시 잘 팔릴 수 있을까를 생각해 봐야 하는 것처럼 인테리어를 할 때도 내 마음에 드는 것뿐만 아니라 매도 시 호불호가 없게 인테리어를 하는 것도 중요한 것 같아요~~ 말이 나온 김에 부동산 매도 팁을 잠깐 이야기한다면! ( 깨알 매도 경험담) 1. 일 순위는 역이죠. 내가 속한 단지 매물의 양과 뿐만 아니라 우리 아파트 단지 주변 아파트의...',
#    "'같은 스스로를 '신화'로 만들어버리는 책들이 그러한 부류인데 정작 중요한 이야기는 쏙 빼고 자기자랑만 늘어놓는 책도 있고, 자신이 운영하는 무엇인가에 가입하게 하는 책들도... 파악하고 협상하기 2. 내가 줄수 있는 것이 있을때 3. 부동산 중개업소 사장님과의 친목 4. 설령 깎아주지 않더라도 마음의 상처를 안받기 5. 에 매몰되지 않는 것 (나중에 잘 하...",
#    '천차만별이기 때문에 아무리 RR이라고 해도 RR의 가격으로 팔리려면 시간이 필요하고 운대가 맞지 않을 경우 인고의 시간이 필요할 수 있습니다. 여러 건의 부동산을 거래해보니 시간과 자금이 완전히 내 편일 경우에는 오래 버티며 협상의 우위를 가져갈 수 있겠지만 그게 아닌 경우에는 사는 사람에게도 먹을 것을 조금은 남겨주는게 의 정석이라는 생각을 해봅니다.',
#    '잠시 자존심을 내려놓고 자금을 최대한 지킬 것인지 적당한 수준으로 협상할 것인지 [부동산 매수 기록] 협상의 기본은 상대의 니즈를 파악해서 내가 원하는 바를 이루기 위해 나의 욕심을 내려놓는 과정이 필요하다. 가격 조정이 되는 경우는 크게 아래 두 가지에 해당하지 않을까. © owencavlys, 출처 Unsplash 1. 상급지 갈아타기 하는 분 내가 이 케이스였다. 인 분은...']},
#  {'question': '부동산 매도를 결정할 때 시장의 어떤 요소를 고려해야 하나요?',
#   'document': ['금리 뜻 인플레이션 계산법 부동산 시장 관계 예상외로 고금리 기조가 길게 이어지며 세계적인 금융 환경이 크게 영향을 받는 모습입니다. 많은 분이 이자율의 변화가 시장에 어떤... 보통 사람들이 은행에 방문하거나 전화로 문의를 하면서 듣는 퍼센티지는 해당 기준점에 여러 가산 더하고 빼면서 됩니다. 일반적으로 기관의 경영 상황이 양호한지, 대출자의...',
#    '시스템가구를 선택할 때 고려해야 할 중요한 요소 중 하나는 가구의 조립 및 설치 과정입니다. 시스템가구는 일반적으로 조립이 필요한 제품이 많기 때문에 조립 및 설치의 어려움을 고려해야 합니다. 일부 시스템가구는 조립이 간단하고 쉬운 설치 방법을 제공하므로 DIY로 쉽게 조립할 수 있습니다. 그러나 가구는 전문가의 도움이 필요할 수도 있으니 조립 및 설치...',
#    '물론 투자에 있어서는 여러 요소를 고려해야 합니다. 현재 수성구 내에서도 지역별로 편차가 크기 때문에 세심한 분석이 필요합니다. 특히 전셋값이 안정적인 지원을 제공하지 않는다면 자기자본을 많이 투입해야 할 수도 있으므로 이 부분에 대한 면밀한 검토가 필수적입니다. 앞으로 대구 수성구 은 어떻게 변할까요? 전문가들은 적정 공급이...',
#    "의사결정자에 대한 원망. 12억 집 매수는 억울해서 고려하기 힘듦. 더 안좋은 조건의 10억 아파트를 차선으로 검토 함, 내집 - 그나마 장점 : 부동산 매매 대신 코인/주식 등의 금융 자산 투자해 성공가능하나, '영끌'하지 않는 이상 부동산 투자에 비해 수익률이 적기도 하고, 보다 하락률이 너 클 가능성이 있음 아.. 답정너 스러운 고민인가. . 어쨌든 전세 만기일이...",
#    '사례로 매도했을 경우 어떤 시나리오로 흘러가는지 하나하나 보여주시니 더 크게 와닿았던 것 같습니다 싸게 사서 비싸게 팔아 수익을 확정하는 것이 매도 입니다 하락장이라고 싼... 하는 의심을 가진 적이 있었지만, 지금은 그런 것이 의미 없다는 것을 알고 있습니다 오히려 과정에 집중했을 행복한 투자자로 오래오래 에 살아남을 수 있습니다 쟈니튜터님...']},
#  {'question': '부동산 매도 시 이전 소유주의 책임은 어디까지인가요?',
#   'document': ['대해서만 책임을 지면 됩니다. 그러므로 오늘 포스팅에서는 부동산 분쟁이라면 그 누구와 견주어도 자신 있다고 자부하는, 화윤과 함께 원상복구의 의무는 어디까지 적용을 하는지... 이를 원상복구시키기 위한 비용은 세입자 등이 자신 편의상 목적물의 형상, 상태를 변경시켜서 사용을 했을 때 계약 만료시 목적물의 변경 으로 회복을 시키는데 있어 요구되는...',
#    '부동산 재산분할 문의/상담: 0507-1402-4870 법무법인(유) 강남의 강남 제일 부동산 변호사들이 ▼ 궁금하시다면 ▼ 이혼과 부동산재산분할 : 어디까지 재산분할 대상이 될까? 이혼 시... 한편, 결혼 이전에 부부 중 일방이 갖고 있던 재산과 결혼 생활 중이더라도 일방이 상속, 증여받은 재산은 특유재산에 해당하여 분할 대상 재산이 아닌 것이 원칙입니다. 그러나 혼인 기간이...',
#    '신뢰와 노력으로 응대하는 아침부동산입니다. 최근 평택 고덕 힐스테이트 단지는 입주민들을 안전하고 하자 없는 주거공간을 보장하여 맞이하기 위해서 사전 점검을 진행하게 되었는데요. 입주가 다가오고 있는 만큼 매도자 또는 임대인 분들께서는 본인의 주택을 거래할 때 처럼 지고 성심성의껏 진행을 도와주는 공인중개사가 필요하실 것이며 매수자나...',
#    '완공될 시 남아 있는 잔액과 취득세 납부를 거치어 온전한 분양권 소유 상태가 된다고 하였죠. 한국은 법률 규정에 따라서 부동산 소유주들에게 종합 부동산세 및 재산세를 납세하게끔... 이에 한층 더 혼잡한 상황으로 치닫기 이전에 적정한 시기에서 대처하려는 방안으로 양도를 고민한다고 했죠. 만일 체약된 후에 중도금까지 대금이 송금된 경위라면 분양사와...',
#    '분양권 소유주가 된다고 했습니다. 한국은 법령에 따라서 부동산을 가지고 있는 사람한테 종합부동산세와 재산세를 납부하도록 책임을 부여하고 있는데요. 분양권의 처지에는... 이에 더욱 혼란한 입장으로 치닫기 이전에 적정한 시점에서 조치하려는 방편으로 양도를 근심한다고 했습니다. 만약 체약된 이후 중도금까지 대금이 지급된 케이스일 때는 분양사도 나 자신의...']},
#  {'question': '부동산 매수 전에 확인해야 할 주요 사항은 무엇인가요?',
#   'document': ["제목은 'K-Pop 주식을 매수하기 전에 알아야 할 사항'임 한국의 K-Pop 산업은 호황을 누리고 있지만 해당 주식에 투자하는 투자자들은 쉽게 지칠 수 있다. 애널리스트에 따르면, 현재 BTS와 블랙핑크 등 세계적으로 유명한 가수 덕분에 업계는 약 50억 달러 규모로 성장하고 있으며, 세계적으로 더 많은 사람들이 관심을 보임에 따라 계속 성장하고 있다....",
#    '암보험비갱신형추천 고르기 전 주요 체크사항 확인하세요 암보험비갱신형추천은 다양한 상황에 대응하며 거의 모든 서비스를 제공하는 특성이 있어요. 이런 보험은 손해보험사와... 대장 내시경이 일반 검사로 진행될 경우에는 보험 접수가 안 되지만 검사 후에 용종 제거 수술이 필요하다면 보험 요청을 수 있다고 알게 됐어요. 조직검사 결과를 하러 갔을 때 보험...',
#    '대출받아서 매수할 때 은행에서 본인들과 협약된 법무사를 이용하라고 하는데 보기 드물지만 거짓으로 속여서 더 많은 비용을 고객에게 받는 법무사들이 있다. 속지 말고 본인이 확인해야 할 것이다. 손님들 중에서도 보기 드물지만 10년 전 중개 수수료와 다름이 없는 비용인데도 중개 수수료를 깎으려는 사람들이 간혹 볼 때가 있는데 중개 수수료 깍지 말고...',
#    '가족간 부동산 거래 주의사항 확인 혹시 세금폭탄을 맞을까봐 걱정하게 되는 가족간 부동산 거래 주의사항에 대해 알아보겠습니다. 우산 가족간의 부동산거래라는 것은 종류가 상당히... 그러면 과연 적정한 가격이라는 것은 무엇일까요. 세법에서는 시가의 5% 혹은 3억원 중에서 적은 금액의 한도 안에서 거래하라고 합니다. 즉 만약 내가 가족과 매매 거래를 하려는...',
#    '그렇기에 저희 아침부동산은 매물을 맡기는 분들께 최대한 빠른 시일 내로 좋은 매수자 및 임차인들을 소개시켜드릴 수 있고 좋은 컨디션의 주택을 찾고 계시거나 안정적인 전세매물을 찾는 분들께는 선호하는 사항들을 모두 검토하고 최적의 조건을 갖춘 매물들을 소개드릴 수 있게 되었답니다. 평형별로 다수의 매물들이 존재하고 있기 때문에 찾아주시는 고객 분들의...']},
#  {'question': '부동산 매수 시 가장 중요한 검토 포인트는 무엇인가요?',
#   'document': ['평택 고덕 힐스테이트 스카이시티 전문부동산 (매수, 매도, 전세, 월세) 안녕하세요. 신뢰와 노력으로 응대하는 아침부동산입니다. 최근 평택 고덕 힐스테이트 단지는 입주민들을... 입지안내 단지의 규모, 환경 등 생활함에 있어 필요한 검토 사항이지만 이보다 것은 어느 위치에 자리 잡고 있어 어떠한 생활 편의성을 제공해줄 수 있는지 확인하는 것이 ...',
#    '부동산소송변호사 선임비용 결정 시 중요한 포인트는 ? <목차> 1. 부동산소송변호사의 도움이 필요한 이유는? 2. 어떤 법적 절차가 있을까? 3. 어떤 상황에서 진행할 수 있을까? 4. 어떻게... 그렇기 때문에 부동산소송변호사의 도움을 받는것이 현명한 선택입니다. 2. 어떤 법적 절차가 있을까? Q. 명도소송이란 A. 이는 경매 낙찰자 이외의 소유자가 실행할...',
#    '투자 검토 중이신 분들을 위해 실시간 코인 정보 제공 카카오톡방을 소개드리겠습니다. 해당 채팅방에서는 코인과 관련된 시시각각 변화하는 뉴스와 매매 전문가의 견해를 확인하실... 주봉상 중요한 지지 포인트는 3군데로 나뉩니다. 66000불대의 가격, 48000불대의 가격, 33000불대의 가격입니다. 이러한 주요 가격대에까지 되돌림이 나오면 손익비가 매우 좋은 ...',
#    '부동산매매계약서를 작성할 때 놓친 부분이 생기게 된다면 추후에 원금을 제대로 돌려받지 못하거나 하는 피해를 입게 될 수도 있으니 면밀히 검토해 보고 작성하는 것이 좋다... 그리고 작성할 때 상호 간의 확인이 가장 중요하다고 말했습니다. 부동산에서 직접 등기부상 당사자가 대면하여 작성하는 것이 좋은 방법이라고 하였습니다. 만일 대리인을 통해 진행하게...',
#    '미리 검토 해 두시는 것도 중요하시고 매수 전 계약 시 꼼꼼히 따져 보시는 것도 중요합니다. 하자가 발견 되었다면 어떻게 대응해야 할까요? 증거 확보를 위해 먼저 사진과 동영상을... #부동산매매 후 하자 관련 문의나 질문으로 가장 많은 주제가 하자 담보 책임기간, 중대한 하자 누수, 특약사항에 책임 범위를 어떻게 명확히 할 것인지에 대한 부분들이었습니다. 하자...']},
#  {'question': '부동산 매수 과정에서 흔히 저지르는 실수는 무엇인가요?',
#   'document': ['역시 부동산 투자는 꿈을 이루는 것이 아니라 생계처럼 하고 있습니다. 규모가 늘고 종목이 다양해 지면서 매일 새로운 사건이 터지고 해결하는 것이 일상이 되었기 때문입니다. (오늘도 임차인 한 분이 사정이 어려워졌다고 월세 연기해달라고 문자 왔네요. ㅜㅜ) 그 은 즐거움보다 고통과 인내의 입니다. 그렇게, 수많은 투자를 하면서 하고 내상을 입고...',
#    "투자 과정에서 흔히 저지르는 실수 살펴보기 1. 앞뒤가 맞지 않는 투자. 모두가 주식은 싸게 사서 비쌀 때 팔아야 한다는 입에 발린 말을 하는데 '싸다'와 '비싸다'가 진정 무엇을... 투자 과정에 트레이딩 개념을 도입하면 문제가 생기기 시작한다. 순수한 의미의 가치투자자는 다음의 행태를 받아들이기 힘들다. 1. 손실제한 주문 사용하기 2. 피라미드 쌓기 () : ...",
#    '이런 실수는 굉장히 자주 찾아볼 수 있는데 왜 사이드캠을 쓰는가? 에 대해서 생각해볼 필요가 있음 유튜브를 올린 것은 기본적으로 시청 지속 시간을 염두하고 만드는데 이 과정에서 단조로움을 없애기 위해서 대개 사이드캠을 배치함 하지만 ‘단조로움을 없애려면 어떻게 해야하는가?’ 그 솔루션은 는 실무진이 고민해야 하는 문제임 단조로움을 없애려면...',
#    "오늘은 많은 분들이 궁금해하시는 부동산계약금반환 관련 내용을 정리했습니다. <기본 개념 살펴 보기> Q. 민법상 '해약금'의 개념은 무엇인가요? A. 부동산 거래와 같이 매매가... 때문에 이러한 과정이 이미 진행되었음에도 불구하고 매수자 귀책사유로 파기가 이뤄졌다면 계약금반환이 불가할 수 있다고 당부했습니다. Q. 배액상환은 무엇을 말하나요? A. 만약...",
#    '부동산 투자 시 저렴한 가격에 매수하는 것은 매우 중요한 일이라 그 가격을 만드는 과정인 협상은 매수 시점에서 가장 중요한 일이 됩니다. 오늘 글에서는 협상 경험이 많지 않은 초보가 협상 테이블에서 흔히하는 실수 다섯가지를 모아왔습니다. 이런 행동들만 하지 않아도 시간낭비는 줄이면서 더 좋은 결과를 얻어내실 수 있을거라...']},
#  {'question': '부동산 매수 시 시장 분석은 어떻게 해야 하나요?',
#   'document': ['수익형부동산을 통해 수익을 원활하게 벌고 싶다면 기존에 형성된 편견을 깨부숴야 시각적으로 넓게 바라볼 수 있으며, 틈새 시장까지 공략할 수 있는 안목이 만들어집니다. 현재 신도시 및 택지지구 중점으로 물량이 다수 쏟아지고 있어서 우량 상권을 중요하게 여기고 선택하는 것이 바람직합니다. 그러므로 상당한 정보량을 토대로 원하는 니즈를 충족하는 상품을 ...',
#    "데이터를 분석한다. 그리고 이런 데이터를 바탕으로 나만의 투자를 결정한다. 그리고 임장을 통해 매수할 물건을 확인한 후 가격 협상을 통해 투자하게 된다. 부동산 경기가 좋지... 모아둔 돈이 없을수록, 부동산 시장이 어려울수록 임대 수익을 일으키는 투자에 주목해야 한다. 그중에서도 초보자가 가장 쉽게 접근할 수 있는 것이 '소액 월세 투자'다. 앞에서도...",
#    '내가 생각하는 그 원인들을 하나씩 풀어보겠다. 1. 우선 분양권 투자 시장 자체의 메리트가 없어졌다. 한때는 부동산 투자의 꽃이라고 불릴 만큼 투자자들에게 사랑받았던 분양권... 기존의 일반 세율로 적용하면 세율이 24% 적용, 1,920만 원에서 누진공제 522만 원을 제외하면 납부해야 할 최종 세금은 1,398만 원이다. 지방세까지 하면 15,378,000원이다. 8천만 원 벌어서...',
#    '12억 집 매수는 억울해서 고려하기 힘듦. 더 안좋은 조건의 10억 아파트를 차선으로 검토 함, 내집 - 그나마 장점 : 부동산 매매 대신 코인/주식 등의 금융 자산 투자해 성공가능하나... 오늘 뵌 소장님은 매주 매수/임대차 등의 부동산 문의를 기록하면서 자체 시황 데이터를 가지고 있었다. 보통의 은 기록보단 시황 나열과 현재 가능한 매물 브리핑 정도였기...',
#    '파악해야 한다. 이를 전년동월대비증감률(YoY)을 통해 알아보고, 전국·서울 아파트매매지수와 비교해 부동산시장의 선행지수로서 어떻게 활용할 수 있는지를 알려준다. 주식... 3단계는 시 단위 부동산시장을 분석해 투자 지역을 좁히는 방법을 알려준다. 여기서는 ‘공급량·미분양’과 ‘외지인거래량’이라는 선행지수를 알려준다. 특히 외지인거래량은 실거주자가...']},
#  {'question': '부동산 매수를 위한 최적의 시기는 언제인가요?',
#   'document': ['되는 시기는 인플레이션이 진행되는 시기이고 경기침체가 동반되는 시기이기 때문에 수요를 줄이고 유동성을 차단해야 합니다 이자때문에 고민하는 분들이 많을 것입니다 금융시장은... 완화시키기 위한 정책을 유지할것으로 보입니다 그렇다면 부동산의 하락장은 까지 지속될까요? 어려운 문제입니다 전문가들 중에는 앞으로 1~2년 하락장이 지속될것으로 예상하고...',
#    "그럼, 언제가 최수 매수 적기였을까? 현재 부동산 흐름은 어디일까? 매매가는 횡보하지만 전세가는 상승하고 거래량 터질 때 즉, 매수 최적의 타이밍 '회복기' 전반적으로 경북지역의 부동산 회복기는 2020년 하반기였다. 이때 매매가는 횡보하며 전세가가 상승하기 시작하여 거래량이 터지는 타이밍이었음. 이후 2021년 ~2022년 상반기까지...",
#    '이를 기반한 최적의 부동산 매수시기가 언제일지 알아보자. 1. 금리의 향방은 미국과 우리나라를 함께 봐야한다. 미국은 전세계 금융시장을 움직인다. 수출로 먹고 사는 우리나라는 전세계의 금융시장에 영향을 많이 받으며, 특히 미국시장 및 금리에 더 많은 영향을 받는다. 그렇기 때문에 미국과 대한민국의 금리를 함께 봐야한다. 2. 미국의 금리(수급)시장 - F구간...',
#    '있는 시기가 다 왔구나 라고 생각했습니다. 그 생각은 아직도 유효하구요 다만 최적의 매수타이밍은 이미 지나간 것이 아닌가 하는 생각입니다. 부동산은 어차피 단기매도 목적의 투자가 아니라면 기본 2년 이상은 보유해야하는 상품이기에 장기적으로 봤을때 아직도 매수는 유효하다고 보는거죠. 특히 실거주는요 (물론 지방과 수도권, 지역의 흐름에 따라 차이는...',
#    '오르는 시기가 완벽한 투자 타이밍이 나오는 것이겠죠. 그러나 그런 타이밍보다 시장의 움직임은 지속적인 현장 임장으로 현장의 분위기를 지속적으로 체크하고 확실히 급급매 수준의 온라인 매물에 나오지 않는 매물을 잡는 게 중요합니다. 오늘 단톡방에서 나왔던 내용인데요. 부산 실거주로 하기 좋은 타이밍은 냐라는 말로 얘기가 전개됐는데요....']},
#  {'question': '부동산 매수 시 필요한 재정 계획은 어떻게 세워야 하나요?',
#   'document': ['부동산 자산과 관련하여 분쟁이 생긴다면 이는 아주 복잡하고 예민해지기 때문에 많은 분들이 골치를 겪습니다. 오늘은 그 중 하나인 건물철거 소송에 대해서 이야기를 나누어 보려고 합니다. 예를 들어 시골집철거가 필요한 상황에서 건물의 소유자와 개발자, 정부 기관 등의 사이에서 건물 소유권이나 철거 관리, 손해 배상과 같은 부분을 두고 생길 수 있는 분쟁입니다....',
#    '내가 가지고 있는 자금은 얼마이며, 단기 자금인지, 장기 자금인지와 모자르는 투자금의 조달은 어떻게 할 것인지의 계획이 세워져야 합니다. 3,부동산 지역 선택: * 미래 성장 가능성... 7,부동산 리스크 관리: * 임대 공실 발생 시 대비책 마련 * 시장 변동에 따른 가격 변동 위험 계약 분쟁 및 법규 변화에 대한 대비가 합니다. ㅁ 을 투자용으로 했다면 특히...',
#    '사실 부동산 투자 또는 분양 우려가 있다면 이에 대한 제도 등을 상세하게 파악해야 한다고 했는데요. 특정 구역에서 의 권역, 산업 모습 것이 다소 단순하게 들어서 하나의 공간에만... 또, 건물을 볼 시 다양한 현상이 인정되어 사태가 필요한 점이라면 해지 차례로 지출될 수 있다고 지연했는데요. 분양 홍보 사람이 실제와 다른 허위라는 세금을 알고 이를 계약자에게...',
#    '사실이라면 어떻게 되는지 알아보고 계신 분들이 많으셨던 것 같습니다가 그래서 더 자세한 내용에 대해서도 자세하게 알아볼까 고민 중입니다. 그래서 오늘 글에서는 부동산 매수 매도 매매시필요서류에 대해서 알아볼까 까지 같이 알아보도록 하겠습니다. 아파트 가격 및 매물의 가격을 살펴보았으니 자세히 살펴보는 시간을 갖도록 하고 싶었기에 이렇게 글을...',
#    '이번 포스팅에서는 LOC 매수, 매도 주문의 장단점과 활용 방법에 대해 자세히 알아보고, 이를 어떻게 활용하여 자신의 투자 전략에 활용할 수 있는지에 대해 정리해 보도록 하겠습니다.... 매수의 경우, 설정 가격 이하에서만 구매가 가능하여 불필요한 고가 매수를 방지할 수 있고, 매도의 경우에는 설정 가격 이상에서만 판매되어 이익을 최대화할 수 있습니다. 또한, ...']},
#  {'question': '부동산 매수 후 유지 관리 비용은 어느 정도인가요?',
#   'document': ['외국인이라 함은 (부동산 거래신고 등에 관한 법률) 제2조 4. "외국인등"이란 다음 각 목의 어느 하나에 해당하는 개인ㆍ법인 또는 단체를 말한다. 가. 대한민국의 국적을 보유하고 있지... 한국은행에 신고하는 부동산취득자금신고는 별도의 서류가 추가로 필요하니 반드시 확인 일처리를 하는것이 바람직 하다. 자칫 매도인에게 대금이 지급되지 못하는 경우가...',
#    '스킨부스터로 관리받으니 그냥 반짝반짝 피부에서 빛이나요 ㅋㅋㅋ 모공도 쫀쫀해진 느낌이구용! 확실히 울트라콜 비용에 대해 고민 할 수도 있겠지만 이정도 만족감이면 크게 상관... 진짜 화장이 잘먹더라구요 ㅋㅋㅋ 스킨부스터중 울트라콜 유지기간이 제일 길어서 좋았었어요! 화장해도 밀리거나 떡지는거 없이 피부결도 넘 좋아보였구요! (피부표현이 잘되고 예쁘게...',
#    '아무리 순위가 높다고 해도 오래 유지하기는커녕 즉시 떨어진다면 무용지물이기 때문이었어요. 또한 네이버 로직도 떨어지게 되면 나중에는 블로그의 순위 자체가 반영되지 않을 수도 있었어요. 블로그관리대행을 진행하는 비용이 터무니없이 저렴하다면 프로그램을 이용할 가능성이 높았어요. 초기 사업장일수록 만 보고 대행사와 컨택하는 경우가 많기 때문에...',
#    '취득세 무이자 할부카드로 3개월 정도만 자금 납부를 딜레이 시킬 수 있다면 큰 문제 없을 것 같습니다. 올 2월부터 시작한 극한 짠테크 또한 이날을 위해 시작한 것이니 말입니다. 서울부동산 매수는 아내의 꿈이었는데 계약 후 집을 보더니 많이 기뻐하더군요. 행복해하는 모습을 보니 남편으로서 뿌듯했습니다. 40대 초반 전 재산이 3억이었습니다. https://blog....',
#    '국내 월배당리츠ETF인 Tiger리츠부동산인프라도 조정세를 보이고 있는데요, 가격이 내려왔다고 무조건 매수하는 것이 아닌 금리 데이터 와 리츠 관련 정도들을 하나씩 확인해 가면서 안전하고 보수적으로 모아가려고 합니다. 매일 2주씩 매수 원칙을 지켜나가도록 하겠습니다~ 24년 16주차 투자현황입니다! Tiger리츠인프라 24년 16주차 투자...']},
#  {'question': '부동산 매수 시 법적 검토는 어떻게 이루어지나요?',
#   'document': ['▼▼ 강남주식사기변호사 법적 처벌은 강남주식사기변호사 법적 처벌은 어떻게 이루어지나 안녕하세요. 저는 주식 관련 사기 피해 사건을 전문으로 진행하는 안팍 형사센터입니다.... 주식사기 유형과 법적 쟁점 최근 한 피해 사례를 소개해드리겠습니다. A씨는 600만 원의 가입비를 내고 B주식리딩방에 가입했습니다. 리딩방 담당자는 특정 종목을 하라며 유명...',
#    "최고가 매수신고인으로 선언하고 입찰 종결합니다. 문제는 '입찰보증금을 바로 찾아오겠다'라고 하는 경우 시비가 발생합니다. 이런 경우 어떻게 처리해야 하는지 명확한 규정이... 인향만리 곽성민 부동산인생 35년 이야기 오늘은 부동산 지분 경매에서 공유자 우선 신청 가장 많이 실수하는 일에 대하여 알아보았습니다. 함께 읽으면 좋을 내용 (공유자 우선...",
#    '어떻게 하면 합법적인 방법으로 분양권계약해지를 진행할 수 있을지 생각해야 했습니다. 이때 전략만 잘 세우면 문제없이 계약해지가 가능했습니다. 혼자 문제에서 어려움을 호소하고 포기하는 것보다, 빠르게 부동산 법률대리인을 만나 대응하길 바랍니다. 언제 완성될지 모르는 집 때문에 두려움에 떨며 기다리다 보면 걱정되고 건강도 해칠 수 있다고 했지요. 방법이...',
#    '분양권계약해지 법적 접근으로 부동산 수준의 변동성을 크고 복잡한 사항이기 때문에 파약의 내용이 동일하다고였습니다. 매물 비율을 선택할 때 건축 시장의 명성만 판단해야 되는... 여기서 계약 당시에 검토할 단계는 적용되어있는 전체 싸움을 상세히 평가할 물가가 있고, 방편으로 고려해야만 별도의 가치를 해결할 수 있다고 했습니다. 계약을 부르는 책자에는...',
#    "부동산 거래는 복잡한 법적 절차와 위험성을 내포하고 있기 때문에, 전문 변호사의 도움이 필수적입니다. 청주 부동산변호사는 부동산 계약의 작성과 검토부터 분쟁 해결까지... 정○○으로부터 별지 표 기록 부동산(이하 '이 사건 주택'라 한다)을 매수가격 2억 7,900만 원에 입수하였고, 2015. 7. 9. 소유권이전 시기등기부를 마쳤다. 나. 임○○은 용의자에게 ①..."]},
#  {'question': '부동산 매수 시 중개인의 역할은 어떻게 중요한가요?',
#   'document': ['이를 통해 사기에 가장 많이 사용되는 비실명 전세계약을 사전에 차단, 부동산 거래 시 발생할 수 있는 여러 위험을 미연에 방지할 수 있게 됩니다. 또한, 중개인에게는 법적 책임을 선명하게 함으로써 부동산 거래를 더욱 체계적이고 투명하게 만듭니다. 중개인에 의한 사기를 예방하는 데 있어 실명제는 이처럼 매우 한 을 합니다. 하지만 이런 방법들을...',
#    '중 부동산 업무처리를 위해서 따로 공부를 하고 시간을 비워야 하는 것은 매우 큰 부담이 될 수 있습니다. 그렇기 때문에 현장에서만 알 수 있는 정보들을 모두 파악하고 있으며 수집된 정보들 중 확실하고 정확한 내용만을 정리해서 친절히 설명을 해줄 수 있는 을 찾고 계시는 분들이 많을 것으로 판단된답니다. 신뢰할 수 있는 정보를 전해드리는 것도 매우 하...',
#    '데 중요한 역할을 한다고 할 수 있겠습니다. 더 효율적으로 해내려면 먼저 지도를 통해 위치와 주변 시설, 대중교통으로 걸리는 시간 등을 알아보고 가야 합니다. 중개인에게 연락하여 브리핑받으면 더 좋습니다. 이러한 과정을 거쳐 임차인과 원활하게 의사소통을 유지하고 문제나 요구사항을 빠르게 처리할 수 있을 것입니다. 임장 뜻은 단순히 현장을 둘러본다는...',
#    '부동산에 관심 있는 사람들에게 가장 중요한 것 중 하나는 바로 자금 마련입니다. 주택을 매매하든, 전셋집을 구하든 자금 마련이 중요하니까요. 본인의 가용 자본금이 얼마냐에... 아니라 부동산 중개인은 금융기관에게 대출 고객 중개 명분으로 소개수수료까지 받을 수가 있습니다. 6. 그 이후에 분의 영업 실적은 되었을까요? "땡땡 과장님, 나대지 하...',
#    '첫 주택 구매라 잘 모르기도 했고 너무 바쁜 나머지 소유권 이전 등기에 대해 아예 모르고 있었어요 막연히 취득세는 나중에 내도 되니까 이정도 돈까지 마련해야지하고 준비중이었는데 낭패볼뻔 했네요.. 늦게나마 부랴부랴 준비하게 됐는데 당연히 제가 먼저 알아보고 챙겨야 하는게 먼저지만 이런 일정이나 꼭 준비해야하는건 통상 이 좀 챙겨주지 않나요 ? . .']},
#  {'question': '부동산 매수 시 교통 편의성을 어떻게 평가하나요?',
#   'document': ['평택 고덕 힐스테이트 스카이시티 전문부동산 (매수, 매도, 전세, 월세) 안녕하세요. 신뢰와 노력으로 응대하는 아침부동산입니다. 최근 평택 고덕 힐스테이트 단지는 입주민들을... 우선 단지 바로 앞쪽으로 BRT 정류장이 존재하고 있어 대중교통 이용 시 향상된 제공할 수 있음과 동시에 중심상권까지 인접한 곳에 존재하여 다채로운 점포들과 식당을 편리하게...',
#    '매물 가격을 평가할 때 건설 업체의 명성만 고려해야 되는 것이 아닌 건물의 위치, 전동열차, 버스와 같은 교통 편의성, 가까이 인프라와 주민 인식 등 부수적 요건들도 함께 고려해... 그러므로 부동산 가격을 따져볼 때 건설사가 배포하고 있는 홍보물만을 근거로 분양권 취득 여부를 판단한다는 것은 나중에 법적인 분쟁을 맞이할 여지가 다분해 각별히 주의해야...',
#    '분양권계약해지 전략적 접근으로 부동산 시장의 변동성을 크고 복잡한 분야이기 때문에 전문가의 도움이 필요하다고 하였습니다. 매물 가격을 평가할 때 건축 업체의 명성만 고려해야 되는 것이 아닌 건물의 위치, 지하철, 버스와 같은 교통 편의성, 주변 인프라와 주민 인식 등 부수적 요건들도 함께 고려해 실제 가치를 책정한다고 했습니다. 동일 지역에 구성된 아파트...',
#    '분양권계약해지 법적 접근으로 부동산 수준의 변동성을 크고 복잡한 사항이기 때문에 파약의 내용이 동일하다고였습니다. 매물 비율을 선택할 때 건축 시장의 명성만 판단해야 되는 것이 아닌 전문가의 시설, 때, 버스와 같은 교통 편의성, 주변 종부세와 주민 인식 등 전략적 자료들도 함께 의거해 실제 자산세를 우려한다고 했습니다. 동일 최초에 완료된 아파트 회사에서...',
#    '신설동역 자이르네 소형주택 분양안내 부동산 시장이 얼어붙어도 역세권 입지를 갖춘 신규주택은 여전히 인기가 뜨겁습니다. 특히 1인 가구비율이 급증함으로써 소형주택의 인기가... 특히 다방면에 위치한 출구와 다수의 엘리베이터는 간결한 이동동선을 통한 대중 제공하고 있습니다. 2호선, 1호선, 우이신설선 등의 노선 이용 및 환승이 가능한...']},
#  {'question': '부동산 가계약금을 지불할 때 주의해야 할 사항은 무엇인가요?',
#   'document': ['이런 요청에 많은 사람들이 부부 사이이기 때문에 문제 없겠지?라는 생각으로 소유주인 남편이 아닌 아내의 명의로 이체하기도 하는데요, 부동산을 처분하는 행동 또는 이와 관련된 계약은 설령 부부임에도 함부로 할 수 없음을 기억해야 합니다. 마지막으로 알려드릴 계약과 관련된 모든 들을 계약금 또는 입금 전에 확인하는 것입니다....',
#    '대신 부동산 가계약금 반환이 가능한 케이스가 몇 가지 존재합니다. 먼저 부당하게 액수를 지불했을 시 정당한 방법을 통해 돌려받는 것이 용이합니다. 실제로 대금을 지불하는 과정에 대한 합의점을 제대로 이룬 다음에서야 금액을 제공해야 하는데, 이러한 항목과 관련된 합의 없이 그대로 액수를 지원하였을 돌려받을 확률이 높습니다. 그리고 절차상 특약 조건을...',
#    '보증금을 지불하지 못할 경우 돌려받을 수 있다는 등의 내용을 상호 합의하에 특약사항에 기술해 두는 것이 혹시 모를 문제가 닥쳤을 때 유리하게 작용할 수도 있습니다. 무엇이든 집주인과 사려는 사람 혹은 빌리려는 사람과 충분한 합의를 통해 이루어져야 한다는 것도 명심하시기 바랍니다. 개인 사정으로 일이 진행되지 않는 경우 반환은 불가능한...',
#    '물건을 다른 사람에게 빼앗기지 않으려고 서둘러 일정 금액을 제공하고 선계약을 맺은 경우 단순한 변심으로 부동산 가계약금 반환은 보통 쉽지 않습니다. 특히 일정 금액을 선 지불하면서 그와 관련된 사전 계약서를 작성했다면 돌려받기는 더욱 힘들어집니다. 정식적인 서류가 아니더라도 메모지에 가계약과 관련한 을 기록하거나 상호 간에 긴밀하게 협의한 내용의...',
#    '부동산 가계약금 반환 주의사항 알아보기 내 눈에 괜찮게 보인다면 다른 사람의 눈에도 마음에 드는 경우가 많기 때문에 집을 구할 때 마음에 드는 매물을 발견하게 되면 정식 서류를... 세부적인 내용과 정식 서류 작성이 안 되었다 하더라도 서로 특정 목적물에 대해서 거래가격, 중도금, 잔금 방법을 구두로 합의하였다면 정식적으로 본다는 것인데요. 이러한 경우...']},
#  {'question': '부동산 가계약금과 본 계약금의 차이점은 무엇인가요?',
#   'document': ['올바른 정의를 이해하고 현명한 부동산 계약을 진행하시길 바랍니다. 가계약금이란 무엇인가 가계약은 본 계약을 체결하기 전에 이루어지는 임시 계약입니다. 가계약금은 보통 총 금액의 1%이거나, 소유주와 협의를 통해 결정됩니다. 가계약금을 입금하면 이 이루어진 것으로 간주됩니다. 임시 이라고 해서 효력이 없는 것은 아니므로 신중하게 진행해야...',
#    '임대인과 계약서를 쓰기 전 입금되는 돈이기 때문에 어떤 조건으로 입금했는지에 따라 차이가 있습니다. 가계약금이란! 가계금의 의미부터 살펴보겠습니다. 목적물에 대해 집주인과... 결론 지금까지 부동산 가계약금 반환에 대해서 살펴보았습니다. 확실히 는 개념에서 많은 있으나 특약으로 정확하게 작성해서 진행하는 것이 좋습니다. 거래금액...',
#    '일반적으로 계약금의 10퍼센트 즉, 매매 대금의 1퍼센트를 지불하게 되며 일반적인 계약과 많은 차이점을 갖고 있습니다. 큰 차이는 정확한 계약 내용을 서로 합의하지 않았다는 점에... 구두로 진행했다 하더라도 임대료나 입주 일자 등 상세한 내용을 합의한 상황이라면 정식 으로 간주할 수 있어 반환이 힘들 수 있습니다. 따라서 중개인을 통해...',
#    '계약시에 부동산을 방문하여 물건을 보고나서 집이 마음에 드는데 미처 계약금을 준비하지 못한 상태에서 물건 선점을 목적으로 주로 사용하는 계약방법입니다. 가계약금이 보통 본... 가계약금 입금시에 이러한 분쟁과 손해를 막으려면 가계약 입금당시에 확약서를 작성하여야 하며, 확약서 내용에 은 성격이 아님을 분명히 하여야 할 것입니다....',
#    '오늘 포스팅할 내용은 가계약금에 관한 이야기를 해보려고 합니다. 우리가 부동산을 알아보다보면 맘에 딱 드는 집이 나왔을 때, 다른사람이 먼저 계약할까봐 걱정이 되서 계약금의... 일반계약과 마찬가지로 계약당사자는 계약의 내용대로 의무를 이행해야 합니다. 이라는 용어가 <민법>상에 있는 법률용어는 아니지만,말 그대로 에 체결하기 전 행하는 임시...']},
#  {'question': '부동산 가계약금을 반환받을 수 있는 조건은 무엇인가요?',
#   'document': ['반환 방법과 조건 살펴보면 부동산을 사고, 판다면 일정 기간이 필요합니다. 매물의 거래 단계에서는 가계약금이 특히 중요한 역할을 하게 되는데요. 이는 구매자 본인이 관심 있는... 부동산 가계약금 반환이 가능한데도 불구하고 무조건 받지 못하는 비용으로 생각하는 때도 있습니다. 실제 사례에서도 뒤늦게 있다는 걸 알게 된 이후 받아보려 했지만 받지 못해...',
#    '부동산 가계약금 반환 조건 알아보기 우리는 일상적인 삶에서 여러 가지 형태로 물건을 구입하고 소비하게 되지만, 선택한 것에 대한 대금을 지불하고 소유하게 됐을 때 모든 상황에서... 돌려받을 수 있지만, 부동산 가계약금 반환의 경우에는 약간 다른 문제가 발생합니다. 여기서 핵심적인 요소는 가계약이 법률적으로 본 계약과 동일한 효력을 지니고 지에 관한...',
#    '없다면 부동산 가계약금 반환에 대해서 답답한 상황이 발생할 수 있습니다. 다양한 갈등이 생기는 원인 중 하나이기 때문에 법적 싸움으로 이어지지 않도록 공인중개사에게 임대인에게 계약 의사 전달을 요청하고 서로 합의 된 내용을 문자로 받아 계약금을 입금하여야 합니다. 당연하게 돌려 있다고 생각 할 있지만 당연하게 것이 아닙니다. 거래에...',
#    '원하는 조건이 아니어서 계약을 해지하려고 한다면 분쟁이 발생될 수 있는데요. 혹시라도 매도인의 책임이라든지 세대에 하자가 발견된 경우라면 반환이 문제가 되지 않겠지만, 단순 변심으로 해지를 하려면 포기를 해야 될 수도 있습니다. 법률상에도 계약 해지를 할 때, 은 포기를 해야 되고 매도인이 추가로 배상을 요구할 수도 있게 되어데요....',
#    '부동산계약 파기후 가계약금 반환받을 수 있는 조건(주의사항 등) 안녕하세요. 가계약금은 보통 1백~몇천까지 다양한데요. 많은 분들이 가계약금을 거신 이후 마음이 바뀌어서 가계약금 반환을 요청하는 사례들이 많습니다. 오늘은 가계약금에 대한 개념부터 등 실무자로서 알려드릴 팁까지 알려드리도록 하겠습니다. 1.이란?...']},
#  {'question': '부동산 가계약금 지불 후 계약이 파기될 경우 어떻게 처리되나요?',
#   'document': ['사실 개인 사정으로 부동산 가계약을 파기한 경우에, 가계약금 반환은 원칙적으로 어렵습니다. 다만 아예 방법이 없는 것은 아닙니다. 당시에 민법상 계약이 성립이 된 것인지를... 중 계약금 일부로 사용하는 방식이라는 해결책을 통해 분쟁을 마무리 지었습니다. [성공사례 다시 보기] 관련한 소송은 꽤 어렵고 복잡합니다. 또한 어떠한 전략으로 ...',
#    '줄면서, 부동산 중개업소에서 수수료를 받지 말아야 할 경우에도 요구하는 일이 발생하고 있다고 합니다. 어떤 경우에 수수료를 지불해야 할까요? 가계약금만 넣고 계약이 파기된... *사례 매수자 B씨가 가계약금을 지불한 후 부동산 시장의 불안을 이유로 매수 의사를 철회하고 매도인 A씨에게 해제를 통보했다. 이 , A씨가 을 받았음에도 불구하고...',
#    '하지만 매매와 임대에 대한 부동산 계약서를 작성하였다면 가계약금이라고 부를 수 없습니다. 육하원칙에 따라 잔금일자까지 쌍방 합의하여 서류를 작성하였고 계약금 까지... 10%를 지불합니다. 이 후 부터는 해제를 하기 위해서는 소유자는 계약금 배액을 상환하고 매수 또는 임차인은 금액을 포기하야됩니다. 즉, 변심으로 인한 이행하지 않는 를 대비하여...',
#    '오늘은 부동산 전세 계약 파기 시에 계약금을 반환받을 수 있는 방법은 없는지를 알아보겠습니다. 부동산을 둘러보다가 마음에 드는 부동산이 있을 때에는 어떻게 하시나요? 일단은 권리 확보를 하기 위해서 가계약금을 지불하게 되는데요. 정식으로 계약을 할 때에는 10%의 으로 을 하게 됩니다만 을 할 때에는 10%까지는 아니지요. © eshad, 출처...',
#    '제가 오늘 3시 가계약금 넣었는데 3시반쯤 부동산에서 왜 돈 안넣녀고 집주인이 안하겠다고 하더래요 그래서 넣었다 확인 못하신거 아니냐 하고 통화 끝났는데 조금전 연락이 다른 부동산에서 돈 도 쳐줘서 계약 하겠다고 들어왔나봐요 그래서 저랑 계약 안하고 싶다고 난리라고 전이미 오백 넣었는걸요…? 이럴경우 어떻게하나요? 이 집주인이랑 얘기해...']},
#  {'question': '부동산 가계약금은 전체 거래 금액의 몇 퍼센트가 적당한가요?',
#   'document': ['정확히 정해진 액수는 없지만 통상적으로 전체 금액의 10프로를 내는 것으로 되어 있는데 이는 전체 금액이 커질수록 부담하는 액수가 커지기 때문에 부동산 가계약금 반환이 제대로... 선 금액에 추가 배액도 배상받을 수 있으며 최대 2배를 청구하여 돌려받을 수 있어요. 공인중개사를 통한 일방적인 를 진행하는 것도 유의하시는 게 좋으며 문자나 통화 녹음 등으로...',
#    '반대로 임대인, 매도인이 해지 의사를 밝힌다면 해당 금액의 2배를 상대방에게 배상하여야 합니다. 가계약금을 전체 계약금 중 일부로 간주하겠다는 특약을 작성했거나 이에 대한 합의 근거가 있다면 위약금은 더 커질 수밖에 없습니다. 본 계약과 동일한 효력을 지닌 이기 때문에 반환은커녕 계약금 를 지급해야 하는 상황이 발생하는데요....',
#    '되는 금액으로 가계약금을 걸어 둡니다. 이후 본격적인 계약서 작성과 함께 계약이 이루어집니다. 주로 다른 사람에게 먼저 팔리지 않도록 보장받을 수 있는 수단으로 이용합니다. 다만 정식 계약이 아니므로 매수 의향자가 시간이 흐른 후 마음을 바꾸게 될 때 일부나 를 반환받을 수 있습니다. 구매자가 를 최종적으로 이행하지 않았을 때 가능한 부분이고...',
#    '매매, 전세, 월세 등 모든 종류에 있어 필요 여부를 확인하고, 체결 전에 해당 매물에 대한 권리를 일정 기간 동안 선점하는 역할을 하는데요, 이는 거래가 성립될 때 그 금액의 일부로 인정되거나 경우에 따라서는 전체 금액이 계약금으로 간주되기도 한답니다. 하지만, 여러 사정으로 인해 이를 파기할 때 반환 여부와 관련한 문제가 발생하곤 하죠....',
#    '민법에서 정의하는 정식적인 법률용어는 아니지만 이미 계약에사 많이 사용하고 있으며 해약금 규정을 준용하고 있으므로 부동산 가계약금 반환이 어렵다는 점도 다들 알고 계실 겁니다. 매매의 당사자가 계약을 약속하면서 매수인이 계약금을 보내게 됩니다. 10% 정도로 정하는데요. 매도인에게 계약금이 교부된 상황에서 해약하기 위해서는 포기해야...']},
#  {'question': '부동산 가계약금을 지불하는 이유는 무엇인가요?',
#   'document': ['이때 걸어놓은 액수가 소액 수준이라면 손실이 적으나, 임차보증금이 억 단위라서 자연스럽게 가계약금 명목으로 수백만 원을 지불했을 때에는 이야기가 달라집니다. 만약 임차인의... 이처럼 전월세 보증금 서비스 승인 불가 등 다양한 이유로 인해 거래가 불발될 시를 대비하여 반환 관련 특약과 여러 조치를 취하는 게 중요합니다. 집 문제로 인하여 금융...',
#    '올바른 정의를 이해하고 현명한 부동산 계약을 진행하시길 바랍니다. 가계약금이란 무엇인가 가계약은 본 계약을 체결하기 전에 이루어지는 임시 계약입니다. 가계약금은 보통 총... 둘째, 임대인이 부동산 투자 이익을 위해 특별한 이유 없이 계약 해지를 요구하는 경우, 임시 계약의 반환도 가능합니다. 이런 특수한 상황에서는 피해를 본 임차인이 과...',
#    "부동산 가계약금 개념 주택과 아파트 등 마음에 드는 매물을 '찜'한다고 표현하는데, 계약금의 일부를 지불함으로써 다른 사람이 먼저 계약하지 못하도록 '예약'을 걸어두는... 또는 가계약금을 보내는 일이 자주 발생합니다. 에를 들어 소유주가 남편인데 타지에 있거나 다른 볼일을 보는 중이라는 로 아내의 계좌로 입금해 달라는 요청이 꽤나 많습니다. 이런 요청에...",
#    '그러나 선계약을 한 사람에게 우선권이 주어지므로, 순위가 넘어가진 않을까 하는 조바심에 먼저 돈을 지불하는 게 대부분입니다. 부동산 가계약금 반환이 이뤄지는 경우는 많지 않기에... 통상적으로 중개인이 거래 금액과 보증금, 잔금 지불 날짜 등을 구체화시켜 쌍방에게 고지하는 가 바로 여기에 있는데요, 이렇게 내용을 확정 짓고 양 당사자에게 알린 경우 계약이...',
#    '만약 부동산 가계약금 반환 소송을 진행할 예정이라면, 법률 전문가의 도움을 받아 최대한 많은 증거 자료들을 확보해 두는 편이 좋습니다. 서로 주고받은 통신 기록이나 거래 내역을 증명할 수 있는 서류들입니다. 분쟁이 발생하지 않도록 하려면 계약금을 지불하기 전에 확인을 해두는 것이 좋은데요. 계약서를 작성할 때에는 특약사항을 잘 기재해야 합니다. 어떤 로...']},
#  {'question': '부동산 가계약금 지불 시 법적 보호 조치는 무엇이 있나요?',
#   'document': ['새 집으로 이사한 후, 계약금으로 큰 금액을 지불한 상태였기에, 변 씨에게서 돌려받지 못한 나머지 보증금은 도 씨의 생활에 큰 영향을 끼쳤습니다. 도 씨는 이제 법적 조치까지... 씨의 부동산에 대한 가압류 조치를 취했습니다. 법률 대리인은 도 씨에게 전세보증금반환소송의 승소 가능성과 향후 들을 자세히 설명하고, 변 씨에게 전세금 반환 양보할 수...',
#    '무엇보다 법적 대응이 가능한 상황인지 확인하는 것이 가장 먼저입니다. 모든 부동산에 대여 문제가 발생할 수 있지만, 상업시설의 경우 시간이 지나갈수록 대응이 늦어질수록 큰... 있는 법적 근거가 마련되어 있습니다. 이는 소유주의 재정적 손실을 최소화하고, 계약의 신뢰성을 유지하기 위한 중요한 로 볼 수 있습니다. 또 다른 중요한 사유는 세입자가 동의 없이...',
#    '그는 또한 임차인이 자신의 권리를 보호하기 위해 가능한 한 빨리 적절한 법적 조치를 취해야 한다고 강조했습니다. 부동산 임대 사기소송을 제기하려면 무엇이 필요하였습니까... 여기에는 금융기관의 이자 손실, 추가 임대료 지불 등이 포함될 수 있습니다. -기타 관련 증거 : 임대인이 을 타인에게 전대 또는 판매했다는 증거, 임대인의 부도 또는 파산, 기타 보증금...',
#    '체결하고 가계약금을 지불했습니다. 그러나 B씨는 시세 상승을 이유로 A씨와의 계약을 일방적으로 취소하고, 다른 구매자와 더 높은 가격에 계약하려 했습니다. 이에 A씨는 계약금 반환을 요구했으나, B씨는 이를 거부했습니다. 결국 A씨는 법적인 조치를 취하기 위해 법무법인 명헌 대구전문변호사에게 도움을 요청했습니다. 대구전문변호사는 이 사건을 맡아...',
#    '미지불건에 대한 분쟁이 생겼을 때도 철거가 결정 될 수 있는데요. ⑤ 뿐만 아니라 어떠한 건물이 환경에 부정적인 영향을 끼친다고 판단 되거나 안전상의 문제가 있을 때는 해당 지역 주민들이나 정부에서 해당 건물의 철거 요구를 위해서 진행되는 경우도 있습니다. 이렇게 여러가지 사유로 인해 절차가 필요하게 될 수 있습니다. 2. 권리 를 위해서는 객관적...']},
#  {'question': '부동산 가계약금을 지불할 때 계약서에 포함되어야 할 내용은 무엇인가요?',
#   'document': ['보증금을 지불하지 못할 경우 돌려받을 수 있다는 등의 내용을 상호 합의하에 특약사항에 기술해 두는 것이 혹시 모를 문제가 닥쳤을 때 유리하게 작용할 수도 있습니다. 무엇이든 집주인과 사려는 사람 혹은 빌리려는 사람과 충분한 합의를 통해 이루어져야 한다는 것도 명심하시기 바랍니다. 개인 사정으로 일이 진행되지 않는 경우 반환은 불가능한...',
#    '물건을 다른 사람에게 빼앗기지 않으려고 서둘러 일정 금액을 제공하고 선계약을 맺은 경우 단순한 변심으로 부동산 가계약금 반환은 보통 쉽지 않습니다. 특히 일정 금액을 선 지불하면서 그와 관련된 사전 계약서를 작성했다면 돌려받기는 더욱 힘들어집니다. 정식적인 서류가 아니더라도 메모지에 가계약과 관련한 사항을 기록하거나 상호 간에 긴밀하게 협의한 의...',
#    '주로 마음에 드는 부동산이 있는데 자금이 조금 모자를 때 당장 처리하기가 곤란하다 보니 선지급 개념으로 가계약금을 지불하여 선점하는 케이스가 많습니다. 다만 상황에 따라 거래가... 지원하였을 때 돌려받을 확률이 높습니다. 그리고 절차상 특약 조건을 충족하였을 적에도 곧바로 환급이 이루어집니다. 따라서 돈을 다시 돌려받고 싶다면 우선 증명부터 작성해서...',
#    '부동산 가계약금 반환 정보 알아보자 매도자 위주의 부동산 동향을 살피면 거래를 할 때 먼저 상품군을 확보할 목적으로 계약서를 작성하기 전 일정 금액을 제공하는 경우가 많습니다.... 한편 계약 의사를 표현할 때에는 입금을 하기 전 관련 내용을 당사자 간 확인할 수 있도록 문자로 남기는 게 좋습니다. 여기에는 소재지를 한 보증금과 월세 및 계약금 외에도 정해진...',
#    '부동산 가계약금 반환이 이뤄지는 경우는 많지 않기에 아래 사항을 잘 기억하시는 게 좋습니다. 먼저, 해당 금액을 지불하면서 그에 관련해 계약서를 작성하는 경우 돌려받을 수 없습니다. 간이 메모지에 작성을 하든, 개략적인 내용 정리 후 문자 메시지를 통해 쌍방에게 교부를 하든 작성에는 형식을 요하지 않으므로 관련 을 정확히 인지해야 하는데요, 만약...']},
#  {'question': '부동산 가계약금과 관련된 세금 처리는 어떻게 되나요?',
#   'document': ['그로 인하여 거래가 불발되었을 시 이미 지급된 금액을 어떻게 처리해야 하는지 알아봐야 합니다. 통상적으로 계약 단계 중 제공한 액수는 민법상 규정에 따라서 적절한 조치를 취할 수 있습니다. 먼저 당사자 일방이 이행을 착수하기 전까지 교부자 측은 금액을 포기하고서 관계를 해지할 수 있으며, 수령자는 반환을 시행하고 서류를 파기하면 됩니다....',
#    '수수료는 어떻게 될까요? 어느 시점에서 누가 일방적으로 파기되었느냐에 따라 위약금과 세금 처리가 많이 달라집니다. 우선 취득세는 부동산을 취득하고 60일 이내에 납부하는... 행사하지만 부동산 계약이 파기되었다면 공인중개사의 수수료는 어떻게 될까요? 에 들려서 상담받고 현장을 같이 임장하여 물건을 살펴본 후 마음에 들었다면 보통은 으로 일정...',
#    '이 세금은 기타 소득 세금에 속하며, 이 수익에 대한 기타 소득세를 납부해야 합니다. 임대 소득 세금 설명과 예시 설명 부동산을 임대하여 발생한 수익을 바로 임대 소득으로... 이 금액에 대해서 임대 소득세를 납부하셔야 하며, 관련 지출 비용은 반드시 증빙이 가능하고 임대 관리 필요로 한 지출 비만 적용됩니다. 투잡 으로 국민연금 ? 설명 직장인의...',
#    '바뀌었다면 어떻게 될까요? 양해를 구했을 때 큰 문제 없이 돌려받는 경우도 많기는 하지만, 모든 집주인이 그렇지는 않겠지요. 계약의 무효와 동시에 부동산 가계약금 반환 문제로... 문자메시지는 물론 구두로라도 관련 사항을 특약으로 걸어두었다면 그 기록을 잘 보관하는 것이 좋습니다. 분쟁의 소지를 줄이기 위해서는 예약금을 걸기 전부터 주의하는 것이 현명한데요....',
#    '상속주택을 어떻게 처리하느냐에 따라서 세금의 내용이 달라질 수 있으므로 잘 계산하여 처리를 한다면 이득이 되는 때가 있습니다. 상속을 받는 방법으로는 상속받은 부동산을... 때문에 세금을 감면받을 수 있으니 이 점도 기억해 두면 좋을 것 같습니다. 상속 주택을 다루는 과정에서 궁금증이 있다거나 실수를 하지 않으려면 전문가의 조언에 받아 보는일이...']},
#  {'question': '부동산 가계약금을 지불한 후 발생할 수 있는 문제는 무엇인가요?',
#   'document': ['않는다면 문제가 발생할 수 있습니다. 예를 들어 전세 보증금이 2억 원이라면 대략 200만 원 수준에서 결정되고 비용을 선지급하는 방식으로 진행됩니다. 정확히 정해진 액수는 없지만 통상적으로 전체 금액의 10프로를 내는 것으로 되어 있는데 이는 전체 금액이 커질수록 부담하는 액수가 커지기 때문에 반환이 제대로 되지 않으면 수백에서 수천만 원의...',
#    '발생하였다고 간주되며 구두로 한 계약까지도 인정을 받게 됩니다. 만약 자금 문제 등으로 서류상 특약조건에 반환과 관련된 사항을 기재하였을 경우는 반환이 가능할 수도 있겠습니다. 보통 부동산 가계약금 반환의 경우 매수한 사람이 매도자와 협의한 내용과 관계없이 일방적으로 취소를 하면 반환이 어렵고 또 매도자 역시 동의 없이 취소하게 된다면 위약금을 해...',
#    '주변 부동산을 둘러보면서 매물을 구하는 건 쉽지만, 본인의 마음에 드는 집을 발견하기가 어렵습니다. 아무리 발품을 팔아도 끝없이 상품군이 쏟아지고 있는 데다가 괜찮다고 생각한... 돌려받을 수 없으므로 금전적인 피해가 상당히 크게 발생할 수밖에 없습니다. 대신 반환이 가능한 케이스가 몇 가지 존재합니다. 먼저 부당하게 액수를 했을 시...',
#    '즉 일반적인 상황에서는 금액을 되찾기 어려운 것입니다. 또한 금액을 돌려받을 수 있는 예외 조건을 만족하였다고 하더라도 상대방이 비용을 돌려주지 않는다면 소송 등의 절차를 거쳐야만 돈을 되찾을 수 있습니다. 따라서 부동산 가계약금 반환이 어려운 일이라는 점을 기억하셔서 계약을 결정하실 때는 신중하게 모든 상황을 따져보신 결정을 하시길 바랍니다.',
#    '위해 가계약금 반환에 대한 정의를 설명해 드리겠습니다. 올바른 정의를 이해하고 현명한 부동산 계약을 진행하시길 바랍니다. 가계약금이란 무엇인가 가계약은 본 계약을 체결하기... 그렇지 않으면 양측 간에 문제가 발생할 수 있습니다. 계약금을 입금하면 계약이 완료됩니다. 계약금은 총 금액의 10%로 설정되며, 은 일반적으로 계약이 완료된 후에는...']},
#  {'question': '부동산 계약금을 지불할 때의 법적 의무는 무엇인가요?',
#   'document': ['부동산 매매 계약금 중도금 잔금 법적 권리 의무 확인 중 마지막으로 잔금에 대해서 알아보겠습니다. 3. 잔금 마지막으로 남은 금액을 지불하는 것으로, 당일 매도인은 소유권이전을 해줘야 하고, 매수인은 잔금을 지급해 주어야 하는데, 이는 누가 먼저 가 아닌 동시에 진행해야 하는 관계입니다. 만일 잔금일에 매수인이 잔금을 지급하지 않는 경우에는? 매도인은, 상당한...',
#    "민법상 '해약금'의 개념은 무엇인가요? A. 부동산 거래와 같이 매매가 이루어지는 과정 중 당사자 일방이 계약금 또는 보증금의 명목으로 일부 금액을 상대 일방에게 교부한 바 있다면 별도의 특약 사항이 없는 이상 이행착수를 기점으로 하여 교부자의 포기, 내지는 수령자의 상환 가 부여된다고 이야기했습니다. 이 말인 즉, 매매계약을 해지하거나 취소 파기하려고...",
#    '이에 대한 약정을 체결할 때, 계약을 맺고자 보상 판결이 적용되지 않는다고 설명했습니다. 또한, 초기 약정한 점이 해당 약정 내용에 포함돼 상대방이 이를 이행하지 않았다면 계약 해지가 가능한지 그 여부가 부동산계약금반환소송의 중요한 논점이 된다고 했는데요. 갈등으로 섣불리 응수하려다 보면 더 복잡한 상황이 발생할 수도 있어 문제가 발생했을 때는...',
#    '지급 의무와 상호 동시에 이행해야 하는 관계에 있다고 했는데요. 이와 관련한 절차를 이행하고자 할 때, 일반적으로 계약을 체결하는 부분에 보상 내용이 진행되지 않는다고 판단합니다. 그리고 초기에 약속한 사항이 해당 계약 내용에 포함되고 상대방이 이를 이행하지 않을 경우, 계약 해지가 가능한지 그 여부가 반환 소송의 주요 쟁점이 될 것이라고...',
#    '부동산계약금반환 법적 조언은 토지 및 건물을 빌리는 사정으로 법적 분쟁이 나타날 가능성이 존재해 부동산계약금반환 변호사를 선임하고 민·형사상 대응 방안을 강력하게 찾아야... 계약은 최종 단계이며, 의뢰인은 임대인에게 계약금 및 중도금을 그 시점에서 했습니다. 신탁 관계가 마지막 부분이 된 후 잔금 지급을 결정했는데 상대방이 이를 지키지 않아...']},
#  {'question': '부동산 계약금과 가계약금의 차이점은 구체적으로 무엇인가요?',
#   'document': ['정의와 차이점, 반환 방법에 대해 알아보는 시간을 갖도록 하겠습니다 우선 우리가 부동산을 매매하거나 임대료는 경우 공인중개사분들과 매물을 보러 가는데요 그때 공인중개사분들께서 우선 가계약금을 보내고 집주인과 약속을 잡고 그때 계약서를 쓰면서 을 입금하면 된다고 하는데요 도대체 은 무엇이고 은 무엇인지 궁금하기도 하고 이...',
#    '결론 지금까지 부동산 가계약금 반환에 대해서 살펴보았습니다. 확실히 계약금과는 개념에서 많은 차이점은 있으나 특약으로 정확하게 작성해서 진행하는 것이 좋습니다. 거래금액 이외에 중도금 및 잔금 지급 날짜 등 구체적인 합의가 된 경우에는 반환되지 않는다는 것입니다. 매물을 보고 계약 진행시 정확한 내용을 인지하고 진행하시기 바랍니다.',
#    '공덕동 삼원부동산입니다:) 오늘은 “가계약금과 계약금 일부의 차이점”을 정리해 드리려고 합니다! 부동산 계약을 하게되면 절차상 가장 먼저 하게 되는 절차가 가계약금 입급... (임차인)은 가계약금을 포기하고 계약을 해제 할 수 있습니다. (본 계약 체결을 목적의 ()의 성립요건) 본계약서를 작성하지 않아야 함, 계약내용에 대한 인 조건에...',
#    '오늘은 부동산 계약을 깨고 계약금을 돌려 받는 방법에 대해 알아보도록 하겠습니다. 방문판매법을 적용할 겁니다. 목차 1 방문 판매법이 무엇인가요? 2 방문판매법 적용을 받는... 피고들의 분양사무소에 방문하였고, 같은 날 피고 B의 계좌로 가계약금 5,000,000원을 입금하였다. 위 법리와 앞서 본 기초사실을 종합하면, 원고는 피고들의 분양대행사 직원들로부터...',
#    '37.가계약금과 계약금은 보통 얼마로 하나요? 38.가계약금을 송금하고 계약 취소가 가능한가요? 39.계약을 취소해도 중개수수룔르 지불해야 하나요? 40.계약서 작성 시 반드시... 매도 후 해야 할 일은 무엇인가요? 98.일 년에 한 개만 매도하는 게 이익이라고 하던데요? 99.1주택 비과세 전략 vs다주택? 부록 누군가에게 차마 물어보기 힘든 용어...']},
#  {'question': '부동산 계약금 지불 후 계약 취소 시 환불 규정은 어떻게 되나요?',
#   'document': ['당사자 간에 위약금 계약으로 돈을 받은 측은 배액 배상하도록 하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면... 경우, 부동산계약금반환소송을 거처 갈등을 해소해야 하며, 법적으로 검증하기 위하여 서부터 꼼꼼하게 확인하고 기존 판례를 검토해 진행할지 법조인과 대책을 마련해야...',
#    '만약 계약서 작성 시 어떻게 부동산계약금반환을 처리할지에 대해 특약을 넣었다면 다시 돌려받는 것도 가능하지만 법적 다툼으로 이어질 가망성이 높아 이에 대해서는 입증할 자료를... 따라서 중도금을 지급한 후 파기되면 적법한 손해배상을 요구할 수 있고, 잔금까지 치른 경위라도 정당한 사유 없이 약정을 할 수 없다고 했습니다. 한편 10억이 넘는다면 중도금을...',
#    '지식산업센터 분양계약에서 방판법상 청약철회를 주장해서 소송전에 100%환불 받은 실제 저희 로펌의 승소 사례를 소개하고자 합니다. 작년 초부터 지식산업센터, 상가, 오피스텔, 생활형 숙박시설 등 분양계약에 해제 취소에 대해서 문의하시는 분들이 많이 늘어났습니다. 대부분 , 중도금 모두 넣고 잔금치를 때 경제적 사정이 안돼서 잔금을 못 치르시거나...',
#    '이에 대해서 판례는 반드시 전액을 제공을 해야 한다고 보았고 그중 일부만 제공을 하거나 공탁을 할 시 계약을 해제시키는 것에 대한 효과가 생기지 않는다고 말했습니다. 법률사무소 화윤 성공사례 - 부동산가계약파기손해배상청구방어 중도금까지 지급했다면 파기 안 이전에 가만을 교부한 일도 있을 것이라 했는데요. 이 경우 ...',
#    '부동산 계약을 진행하면 당연히 공인중개사는 수고비 명목으로 법적수수료를 받을 수 있는 권리를 행사하지만 부동산 계약이 파기되었다면 공인중개사의 수수료는 어떻게 될까요? 부동산에 들려서 상담받고 현장을 같이 임장하여 물건을 살펴본 후 마음에 들었다면 보통은 가으로 일정 금액을 할 것입니다. 자 여기까지에서 해지를 한다면 수수료는 발생하지...']},
#  {'question': '부동산 계약금은 거래 금액의 몇 퍼센트로 책정되나요?',
#   'document': ['우선 약정점을 양도하는 것을 차익으로 환경과 생활을 결과물로 적정 동시에 분양되는 사유로 금액을 반영하게 됩니다. 또한 원만한 해지를 확인할 수 있는 시기에 , 위약금을 차별하고 있는데요. 처음 근무한 예정인 계약금은 보통 전체 총액 중 10%로 산정된다고 했지요. 이 요건을 보유한 매물에는 공사 지급이 되는 용도에 따라 교통편, 내용이 송금됩니다. 마지막...',
#    '부동산 거래가 저조해지는 변화가 찾아오자 땅을 치고 자신의 선택을 후회하는 분들이 소식이 쏟아져 나왔다 하였죠. 나중에 되어서 분양권해지를 분주히 진행하지 않으려면 사전에... 개개인마다 적용될 양도세율의 경우 다르게 기준이 정해지기 때문에, 자신의 경우 산정될 것인지 체크해보실 필요가 있다고 강조하였죠. 양도세는 각기 소유한 기간별에...',
#    '부동산 계약금반환청구소장 해결 방안은 약정 체결 과정 중, 양 당사자 사이에서의 갈등으로 분쟁이 나타나게 되고 고액으로 거래가 이어지면서 더 심각해지는 상황이 많은데요.... 약정 금액 결정 시, 더욱 어렵고 복잡한 부분에 배상 금액이 불리하게 책정될 수 있고, 이를 분명하게 판단하여 반환청구소장 소송을 진행해야 합니다. 당연히...',
#    '분양계약해지 법적해결로 부동산 시장에 대해 수많은 관심이 집중되어 거래가 활발하던 때를 지나 점차 누그러지게 되면서 해지 관련 문의가 많아진 상황이라고 했는데요. 이러한... 이에 본인의 경우는 몇 퍼센트인지 미리 체크해 보는 것이 좋겠습니다. 양도세율 계산 방식은 보유한 기간별로 차등된 비율을 적용하면 되는데 12개월 미만인 경우엔 70%, 24개월까지 기간을...',
#    '그래서 약정을 이행하겠다는 증거로 금액의 일부분을 받게 되는 것입니다. 기본적으로 5퍼센트나 10퍼센트의 수준에서 가격을 책정하며 이를 계약금 혹은 가계약금이라고 부르는 경우가... 이렇게 서류 자체에 부동산 계약금 반환 내용을 명시해 둔다면 후에 분쟁이 발생하더라도 빠르게 해결이 가능합니다. 또한 단순 변심으로 인해 를 파기했더라도 을 돌려받을...']},
#  {'question': '부동산 계약금 지불 시 주의해야 할 점은 무엇인가요?',
#   'document': ['부동산 계약금배액배상 주의할 점은 현재 사람들이 사는 환경을 살펴보게 되면 금전적인 부분에서 평균 이상으로 여유있게 살고 있는 인간이 있는가 하면 경제적인 어려움을 겪는 분도... 통상 부동산 계약 시 전체 거래금원의 10분의 1에 합당하는 금원을 으로 하고 이를 지급하는 것 자체가 계약이 체결된 증거가 되므로 은 증약 금원의 성질을 가지고...',
#    '급격히 높아진 부동산 금액에 신중할 수밖에 없었고, 명확한 목적을 세우고 그에 맞춰 다양한 요소를 고려해야 했는데요. 약정을 체결하고, 되도록 순조롭게 이를 이어가려고 할 때... 하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면, 대상에 대하여 중개 과정에서의 매물을 찾고자 했고, U씨가...',
#    '원칙으로는 부동산 계약금 반환이 적용된다고 했는데요. 무엇보다 다양한 변수를 예측하고 부동산계약금반환에 확실히 대비하기 위해서는 계약서를 작성할 때부터 꼼꼼하게 작성해야... 경우에는 계약금만 지불한 상태에서 해지를 할 수 있다 했는데요. 즉 아직 중도금이나 잔금 지급, 거래 대상물 지급 등 계약 내용을 실질적으로 이행하지 않은 전 단계라면...',
#    '상대편에게 지불하는 것이 관례이고, 이런 입장에서는 계약 해지 시 세부 약정에 대한 부동산 계약금 반환 협의가 필요하다고 했습니다. 증거로서 효력을 발휘하는 한편 해약금으로서... 때문에 부동산계약금반환 소송에서 입증할 자료를 준비해두어야 한다고 했습니다. 무엇보다 다양한 변수를 예측하고 반환 소송에 확실히 대비하기 위해서는 계약서를...',
#    '아파트계약금대출 받는다고 헤매다가 지나님과 상의해본 뒤 결정을 했고요 도와주신 덕분에 무난하게 아파트계약금대출을 성공한 회원입니다 제 상황 간략히 적어보자면 한창 부동산... 처리를 할 생각이었고 계약금은 제 돈으로 처리를 할 생각이었지만 시작부터 좀 꼬인 상황이라 아파트대출이 고민이었습니다 부족한 돈을 따져보니까 3천은 받아야겠는데 이걸...']},
#  {'question': '부동산 계약금을 지불하는 목적은 무엇인가요?',
#   'document': ['급격히 높아진 부동산 금액에 신중할 수밖에 없었고, 명확한 목적을 세우고 그에 맞춰 다양한 요소를 고려해야 했는데요. 약정을 체결하고, 되도록 순조롭게 이를 이어가려고 할 때... 하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면, 대상에 대하여 중개 과정에서의 매물을 찾고자 했고, U씨가...',
#    '임대 목적으로 일방적으로 해지할 수 있으며, 그리되면 부동산계약금반환소송이 제기될 수 있는데 법률대리인과 함께 법적 처분에 응할 수 있다고 했습니다. 무언가 일을 시작하게... 일반적으로 거래금액과 관련해 약 10% 정도를 지급하며 상황에 따라 모두 조금씩 차이가 있는데, 고 계약을 체결한 상황에서 상황에 따라 그 계약을 해지하기도 하며, 금액을...',
#    '개념은 무엇인가요? A. 부동산 거래와 같이 매매가 이루어지는 과정 중 당사자 일방이 계약금 또는 보증금의 명목으로 일부 금액을 상대 일방에게 교부한 바 있다면 별도의 특약 사항이 없는 이상 이행착수를 기점으로 하여 교부자의 포기, 내지는 수령자의 상환 의무가 부여된다고 이야기했습니다. 이 말인 즉, 매매계약을 해지하거나 취소 파기하려고 하는 이 있다면...',
#    '급격하게 상승한 부동산 가격에 더욱 구매에 신중할 수밖에 없고, 확실한 목적을 세우고 목적에 맞게 여러 요소를 고려해야 합니다. 계약을 체결하고 원만하게 진행하고자 하는 과정... 하고, 지불한 쪽이 계약금 포기 등 약정을 달리한 상황이라면 그 내용에 따라 문제를 해결할 수는 있다고 했는데요. 일례에서 대상물과 관련하여 중개 중 매물을 찾으려던 U씨가 E씨...',
#    '그러한 과정에서 차씨는 부동산 계약금으로 2억원가량을 지급했다고 했는데요. 허나 선수금과 잔금을 지불할 수 없게 되어 계약은 해지되었고, 이에 P사가 계약을 체결할 당시 작성한... 계약금 반환 소송이 전개된다면 이것을 대응하려는 목적으로 준비해야 할 항목이 많다는 점과 1한 어떤 소송이냐에 따라 준비해야 할 것은 다를 수 있어 일반인은 모든 변수에 대응하기...']},
#  {'question': '부동산 계약금 지불 후 발생할 수 있는 문제는 무엇인가요?',
#   'document': ['하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면, 부동산 대상에 대하여 중개 과정에서의 매물을 찾고자 했고... 법적 갈등으로 섣불리 응수하려다 보면 더 복잡한 상황이 발생할 수도 있어 가 했을 때는 법률인의 도움을 통해 대비해야 했습니다. 스스로 권리에 피해가 갈 수도 있어 계약 서류를...',
#    '무엇보다 다양한 변수를 예측하고 부동산계약금반환 소송에 확실히 대비하기 위해서는 계약서를 작성할 때부터 꼼꼼히 작성해야 한다고 했는데요. 여기서 해약금은 계약해지권을 유보하는 성질로 거래가 없던 셈으로 보통 현재로 추정되며, 그러면 금액을 준 사람은 그 금액을 포기하는 것이고, 받은 사람은 그 2배에 달하는 금액을 돌려줘야 해지할 데, 그...',
#    '계약 체결 후 매수인의 계약 불이행의 경우 계약서에서 위약금으로 본다는 특약이 들어있지 않으면 몰수할 수 없다고 했습니다. 이를 통해 확실한 책임 사유를 밝히고 적절하게 입장을 표명하도록 해야 하고, 손해를 최소화하기 위해서는 공정한 계약인지부터 파악할 필요가 있다고 했는데요. 서로 대립해 대화로 반환 를 마무리하지 못해 예측할 없는...',
#    '부동산 계약금 반환? 귀책사유가 누구에게 있냐에 따라 다릅니다. 반갑습니다. 법무법인 테헤란 대표 변호사 오대호입니다. 부동산 거래에 익숙하지 않은 사람이 쉽게 겪는 실수 중... 하자 보수를 매도인이 하는 것으로 사건은 마무리될 수 있습니다. 민법에서 규정하고 해약금은 업계 관행으로 봅니다. 파기를 했을 때 은 돌려받지 못하는 것을...',
#    '과정에서 문제가 발생할 수도 있는데, 약정금에 관한 보유권이 누구에게 있는지 파악할 필요가 있어 부동산계약금반환소송을 제기합니다. 부동산 계약금 반환은 다소 복잡하고 어려운 상황이라고 할 수 있습니다. 만약 부당한 상황에 놓여 있다면 신속하게 법률가의 도움을 받아 내용증명을 발송하거나 부당이득 반환을 요구하는 반환소송으로 원만한 해결을...']},
#  {'question': '부동산 계약금 지불 시 필요한 서류는 무엇인가요?',
#   'document': ['당사자 간에 위약금 계약으로 돈을 받은 측은 배액 배상하도록 하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면... 계약 서류를 작성하면서 신중하게 확인할 필요가 있다고 했는데요. 조항이 존재하는지 파악해야 하며 조항이 없는데 임대인이 반환을 거부할 경우, 반환소송을 거처 갈등을...',
#    '취소가 불가능한 경우가 존재하여 단순 변심에 의하지 않은 해지가 가능한 사유가 필요하며, 계약 단계를 인지해 얼마나 이행되었는지를 알아야 할 것이며, 개인적인 사정이나 시세 변동 등을 이유로 일방적인 해지를 하는 경우에는 계약금만 지불한 상태에서 해지를 할 수 있다 했는데요. 즉 아직 중도금이나 잔금 지급, 거래 대상물 지급 등 계약 내용을...',
#    '상대편에게 지불하는 것이 관례이고, 이런 입장에서는 계약 해지 시 세부 약정에 대한 부동산 계약금 반환 협의가 필요하다고 했습니다. 증거로서 효력을 발휘하는 한편 해약금으로서... 때문에 부동산계약금반환 소송에서 입증할 자료를 준비해두어야 한다고 했습니다. 무엇보다 다양한 변수를 예측하고 반환 소송에 확실히 대비하기 위해서는 계약서를...',
#    '마지막으로, 잔금은 부동산 소유권 이전 등기 전에 최종적으로 지불하는 금액입니다. 지급 시, 소유권 이전에 필요한 서류와 증명서를 구입하는 사람에게 제공하고, 이를 바탕으로 명의 이전을 완료합니다. 비용은 거래 가격에서 계약금과 중도금을 제외한 차액이 되겠습니다. 을 포함한 해당 과정은 합의된 계약서에 명시되어야 되며, 만약 한쪽에서...',
#    '일반적으로 거래금액과 관련해 약 10% 정도를 지급하며 상황에 따라 모두 조금씩 차이가 있는데, 계약금을 지불하고 계약을 체결한 상황에서 상황에 따라 그 계약을 해지하기도 하며... 약조 시 정해진 내용에 따라 금액을 전해야 하고, 금액을 전달하는 과정에서 문제가 발생할 수도 있는데, 약정금에 관한 보유권이 누구에게 있는지 파악할 가 있어 반환소...']},
#  {'question': '부동산 계약금을 지불할 때 중개인의 역할은 무엇인가요?',
#   'document': ['가계약금을 지급했을 때 임대인과 매도인이 자신이 받은 금액과 비교해 더 상당한 돈을 내야 하므로 억울하다는 상황에서 치열한 접전이 이어질 수도 있다고 했습니다. 당사자 간에 위약금 계약으로 돈을 받은 측은 배액 배상하도록 하고, 지불한 측이 계약금 포기 등 다른 상황일 경우 그에 따라 논제를 해결할 수 있다고 말했습니다. 선례를 살펴보면, 대상에...',
#    '계약이 성사되었을 때, 중개인이 중개 수수료를 받기 때문입니다. 매수인이나 매도인이 계약을 진행할 것처럼 이야기하였음에도 계약에 따른 의무가 이행되지 않는다면 계약 당사자는 물론이고 중개인 역시 시간을 허비한 결과가 되어 버립니다. 일방의 변심이나 갑작스러운 계약 파기를 방지하기 위해 받아 두는 것입니다. 을 거래할 때는 관련 대금이...',
#    "오늘은 많은 분들이 궁금해하시는 부동산계약금반환 관련 내용을 정리했습니다. <기본 개념 살펴 보기> Q. 민법상 '해약금'의 개념은 무엇인가요? A. 부동산 거래와 같이 매매가... 때문에 이러한 과정이 이미 진행되었음에도 불구하고 매수자 귀책사유로 파기가 이뤄졌다면 반환이 불가할 수 있다고 당부했습니다. Q. 배액상환은 무엇을 말하나요? A. 만약...",
#    '가계약금을 지급했을 때 임대인과 매도인이 본인이 받은 금액과 비교해 더 큰 금전을 줘야 하므로 억울하다는 주장으로 치열한 접전이 이어질 수도 있다고 했습니다. 당사자 간에 위약금 약정으로 돈을 받은 쪽은 배액 배상하도록 하고, 지불한 쪽이 계약금 포기 등 약정을 달리한 상황이라면 그 내용에 따라 문제를 해결할 수는 있다고 했는데요. 일례에서 대상물과...',
#    '핵심 역할을 한답니다. 먼저 부동산 계약금은 매매 거래가 체결될 때 매수인이 매도인에게 지급하는 금액을 의미합니다. 이는 일종의 보증금 역할을 하며, 거래의 진지함과 결정의... 계약금을 납부함으로써, 매수 의사를 분명히 하고, 양도인은 다른 사람에게 팔지 않겠다는 의무를 지는 거죠. 매매에서 하고 난 뒤의 단계인 중도금은 주로 융자나...']},
#  {'question': '부동산 계약금과 관련된 세금 처리는 어떻게 이루어지나요?',
#   'document': ['수수료는 어떻게 될까요? 어느 시점에서 누가 일방적으로 파기되었느냐에 따라 위약금과 세금 처리가 많이 달라집니다. 우선 취득세는 부동산을 취득하고 60일 이내에 납부하는... 당연히 세금 의무가 없지만 잔금청산 후에 계약이 파기되었다면 취득세와 양도소득세가 발생하기 때문에 약간 복잡해집니다. 예를 들어 계약을 체결한 후에 을 지불하였지만...',
#    '모든 것이 성립된 후, 계약금을 입금하면 첫 발을 내딛는 것입니다. 하지만 추가적인 사항들도 고래해야 합니다. 등기 이전 절차: 필요한 서류를 정확히 준비하고, 관련 법률에 따라 일련의 과정을 정확히 진행해야 합니다. 세금 문제: 부동산 매매를 할 때 발생하는 에 대해 사전에 충분히 이해하고 있어야 되고, 정확한 계산과 납부가 필요합니다. 사실은 복잡할...',
#    '상속주택을 어떻게 처리하느냐에 따라서 세금의 내용이 달라질 수 있으므로 잘 계산하여 처리를 한다면 이득이 되는 때가 있습니다. 상속을 받는 방법으로는 상속받은 부동산을... 때문에 세금을 감면받을 수 있으니 이 점도 기억해 두면 좋을 것 같습니다. 상속 주택을 다루는 과정에서 궁금증이 있다거나 실수를 하지 않으려면 전문가의 조언에 받아 보는일이...',
#    '이 밖에 거래와 관련된 일련의 과정을 모두 담당하여 처리하겠다는 의미로 받는 돈인 만큼 당사자들의 신분 확인을 비롯하여 서류 조항 점검 및 등기부등본을 비롯한 서류 준비 등의 과정도 책임을 지고 담당해 주어야 합니다. [부동산 종류에 따라 달라지는 수수료율] 이렇게 중개인의 의무에 따라 모든 업무를 수행하였다면 거래한 이 무엇이며 내용 및 이...',
#    '분양권계약해지 법적조처로 부동산과 관련하여 오랜 기간 관련 업무를 이행했던 여러 사람의 판단에 따르면, 실질적으로 건축물의 가치를 평가하는 요소에서 단순 건설 브랜드의... 계약금은 총액 중 10%로 납부하며 계장 작성 후 건물이 완공되는 시점에 남은 잔금과 취득세를 납세하여 분양권 취득을 완료합니다. 그리고 국내에서 규정하는 법률 규정에 따르면 ...']},
#  {'question': '부동산 중도금 지불 시기는 언제인가요?',
#   'document': ['부동산 매매에서 계약금을 지불하고 난 뒤의 단계인 중도금은 주로 융자나 자금조달 계획에 따라 납부됩니다. 비율은 합의 내용에 따라 다르지만, 흔히 가격의 40~50% 내외로 설정됩니다. 납부 시기는 특정한 날짜와 시간에 이루어지며, 이 과정에서 양측은 서로의 금융 상태와 계획을 확인하게 됩니다. 마지막으로, 잔금은 소유권 이전 등기 전에 최종적으로 하는...',
#    '보통 지급하는 대금은, 한 번에 지급하는 것이 아닌 일정 시기에 따라서 나누어서 지급하게 됩니다. 보통 매매나 임대차 계약 후 잔금까지 지급되는 기간은, 임대차는 1달 정도, 매매는... 부동산 매매 계약금 중도금 잔금 법적 권리 의무 확인 중 마지막으로 잔금에 대해서 알아보겠습니다. 3. 잔금 마지막으로 남은 금액을 하는 것으로, 당일 매도인은 소유권이전을...',
#    '부동산 계약시 계약금, 중도금, 잔금이란 무엇이며 언제, 얼마의 비율로 지불해야 하나요? 부동산 계약을 진행하면서 나오는 여러 용어들 중에 제일 기본인 계약금, 중도금, 잔금이라는 말이 있습니다. 부동산 매매 계약을 하든, 전세, 월세 계약을 하든 , 아파트, 빌라, 오피스텔, 상가 등 모든 계약에서 나오는 용어인데요. 통상 법적으로 정한 기준에 따라 내기도 하고...',
#    '매매 계약은 보통 가계약과 계약금, 중도금 그리고 잔금 순으로 지불하는 것이 일반적입니다. 여기서 중도금을 이미 내버린 후라면 부동산계약파기가 어려워지는데요. 만약 은행 대출을... 안일하게 대응하시기 보다는 법리적인 검토를 토대로 결정할 수 있도록 하시길 바랍니다. 관련하여 도움이 필요하시다면 든지 문의주세요. 저녁, 주말 구분 없이 상담 진행을...',
#    '2023.10.25(수) 자산 4980만원 - 주식을 손절하면서 부동산 중도금을 마련하였습니다. 뼈아픈 손절이였지만, 손절했던 당시보다 주식가격들이 -20%정도씩은 더 떨어져서... 단, 몰빵투자가 아닌 항상 적립식 매수라는 것을 명심하시길 바랍니다. 저도 몰빵투자는 성적이 좋지 않습니다 ㅎㅎ;; - 미국 주식 뿐만 아니라, 한국 주식들도 많이 빠져서 담기에...']},
#  {'question': '부동산 중도금 지불의 법적 의미는 무엇인가요?',
#   'document': ['부동산 매매 계약금 중도금 잔금 의미 알아보기 오늘은 부동산 매매 과정에서 중요한 세 가지 금융 용어인 계약금 중도금 잔금에 대해 알아보겠습니다. 아파트나 주택 등을 구입하는... 부동산 매매에서 계약금을 지불하고 난 뒤의 단계인 중도금은 주로 융자나 자금조달 계획에 따라 납부됩니다. 비율은 합의 내용에 따라 다르지만, 흔히 가격의 40~50% 내외로 설정됩니다....',
#    '민법에서는, 특별한 약정이 없는 한 계약금을 해약금으로 추정하게 되는데, 계약에 따른 계약해제권을 유보한다는 의미입니다. 해제권이란? 유효하게 성립된 계약을 당사자 일방이... 부동산 매매 계약금 중도금 잔금 법적 권리 의무 확인 중 마지막으로 잔금에 대해서 알아보겠습니다. 3. 잔금 마지막으로 남은 금액을 하는 것으로, 당일 매도인은 소유권이전을 해줘야...',
#    "오늘은 많은 분들이 궁금해하시는 부동산계약금반환 관련 내용을 정리했습니다. <기본 개념 살펴 보기> Q. 민법상 '해약금'의 개념은 무엇인가요? A. 부동산 거래와 같이 매매가... 우리 민법에 따르면 이행착수는 사회 통념과 비교할 때 객관적으로 채무의 이행행위가 이뤄졌거나, 전제행위가 이뤄진 단계를 한다고 설명했습니다. 거래에 있어서 이것은 '...",
#    '이는 계약의 증거로서의 성질을 갖는 것으로, 합치의 내용이 불분명하더라도 당사자 간에 어떠한 합의가 이루어져 거래가 성립된 증거를 의미한다고 했습니다. 즉 이를 지급한... 계약금만 지불한 상태에서 해지를 할 수 있다 했는데요. 즉 아직 부동산 중도금이나 잔금 지급, 거래 대상물 지급 등 계약 내용을 실질적으로 이행하지 않은 전 단계라면 당사자 간 다른 약정이...',
#    '대부분 가계약금을 지불한 이후 만남을 가져 계약서를 작성하게 됩니다. 해당 시점에서 10퍼센트 정도의 계약금을 지급하고 중도금과 잔금에 대한 부분을 약정하게 됩니다. 강남부동산전문변호사는 계약을 진행할 때에 내용을 자세히 검토하는 것이 무엇보다 중요하며 조금이라도 미심쩍은 부분이 있다면 특약사항을 작성하여 위험을 미연에 방지하고 상대방에게 책임을...']},
#  {'question': '부동산 중도금을 지불하지 않을 경우 발생하는 문제는 무엇인가요?',
#   'document': ['부동산 매매에서 계약금을 지불하고 난 뒤의 단계인 중도금은 주로 융자나 자금조달 계획에 따라 납부됩니다. 비율은 합의 내용에 따라 다르지만, 흔히 가격의 40~50% 내외로 설정됩니다.... 세금 문제: 부동산 매매를 할 때 발생하는 세금에 대해 사전에 충분히 이해하고 있어야 되고, 정확한 계산과 납부가 필요합니다. 관련 사실은 복잡할 수 있으므로, 세무 전문가의 조언을...',
#    '문제가 되는 상황은, 계약기간 중 중간에 어느 한쪽에서 계약을 파기하려고 하거나 약속된 날짜에 대금을 지급하지 않을 경우 발생하게 됩니다. 오늘은, 부동산 매매 계약금 중도금... 손해배상 문제가 발생하게 됩니다. 부동산 매매 계약금 중도금 잔금 법적 권리 의무 확인 중 마지막으로 잔금에 대해서 알아보겠습니다. 3. 잔금 마지막으로 남은 금액을 는 것으로...',
#    '법조가는 무슨 사건이 존재해도 외도가 발생하는 건 안 된다 부연했으며, 대구 부동산 변호사 같은 대리인의 보조가 필요했어요. 이미 확인된 가운데선 대구부동산전문변호사는 말을 수정하는 경우엔 사건 수습이 복잡한 점을 고려해야 한다고 경고했죠. 야간시설에 찾아간 K씨는 직업여성 C씨와 지속적인 사건들이 실재했다고 말했죠. 숙박업체에서 비용을 했으며...',
#    '이 경우 나머지 계약금의 금액을 지불을 하고 계약을 파기하여야 할 것이라고 전했습니다. 법률사무소 화윤, 부동산소송 골든타임 놓치지 마세요 계약금을 포기하여도 해제를 할 수 없는 단계도 분명히 존재한다고 하였습니다. 계약금이 지니는 법률적 효력으로는 약정해제권의 유보도 있다고 하였는데요. 이에 따라 까지 지급이 되었다고 한다면 이행에 착수가...',
#    '의해서는 부동산 가계약금 반환을 받을 수 있다는 내용을 명시해 두는 것도 좋겠지요. 잔금을 치르기 위한 대출을 받고자 하였으나 대출을 진행하는 것이 불가하여 매매 대금이나 보증금을 지불하지 못할 경우 돌려받을 수 있다는 등의 내용을 상호 합의하에 특약사항에 기술해 두는 것이 혹시 모를 가 닥쳤을 때 유리하게 작용할 수도 있습니다. 무엇이든 집주인과...']},
#  {'question': '부동산 중도금과 계약금의 차이점은 무엇인가요?',
#   'document': ['부동산 매매 계약금 중도금 잔금 차이점 알아보기 부동산을 거래할 경우에는, 우리가 일상생활에서 사용하는 금액과는 확연하게 큰 금액이 오가게 됩니다. 특히 매매의 경우에는, 전세나 월세에 비해서 보다 많은 금액이 오가게 되고, 그에 따르는 권리와 의무가 뒤따르게 됩니다. 보통 투자를 전문으로 하시는 분들은, 그동안 여러 번 경험을 해봤었기 때문에...',
#    '일상생활이나 실무에서도 잘 쓰이는 단어는 아니라서 쉽게 계약금은 증약금의 성격을 가지고 있다고만 알고 있으면 됩니다. 이상 부동산 용어 중 계약금 중도금 잔금 위약금 해약금 증약금 뜻과 의미 차이점에 대하여 알아보았습니다. 오늘도 긴 글 끝까지 읽어주셔서 감사합니다. "내 집 마련에 도움이 되어 드리겠습니다." - 내집마련멘토 윤준파파 함께 읽으면 좋은 포스팅',
#    '부동산 매매 또는 전세 계약, 임대차계약을 할 때 필수로 나오는 단어들이 몇 가지 있는데요. 계약금, 중도금, 잔금 오늘은 이 용어들이 정확히 무엇인지, 어떤 차이점과 왜 돈을 나눠서 주는지에 대해 알아보는 시간을 가지겠습니다. 인생을 살아보신 연륜 있는 분이라면 경험에 의해 아시는 내용이지만 이런 경험이 없는 젊은 분에게는 생소할 수 있어 자세히 포스팅해...',
#    '중도금대출이 무엇인가요? 청약에 당첨되고 중도금대출을 고려하게 될 때, 보통 입주까지 약 3년 정도의 시간이 소요됩니다. 청약 당첨 시 계약금으로 10%에서 20%의 금액을 지불하게... 유사한데, 차이점으로는 DTI와 DSR 적용이 되지 않으며, 대출한 금액 대비 주택 가치 비율인 LTV만 적용됩니다. 대출 이자 - 보증 한도 그리고 대출 이자 보증 한도가...',
#    '(사진=게티이미지뱅크) 부동산 계약금, 중도금, 잔금의 차이점 부동산 매매 과정에서 발생하는 세 가지 주요한 자금 조달 방법이다. 1. 계약금 부동산 계약을 체결하면서 매도인에게 미리 지불하는 일정 금액이다. 일반적으로 전체 거래 금액의 약 10% 정도로 설정한다. 은 주로 계약 체결과 동시에 일부 또는 전부가 지불되며, 이후에는 취소나 환불이 어렵다. 2....']},
#  {'question': '부동산 중도금 지불 시 필요한 서류는 무엇인가요?',
#   'document': ['마지막으로, 잔금은 부동산 소유권 이전 등기 전에 최종적으로 지불하는 금액입니다. 지급 시, 소유권 이전에 필요한 서류와 증명서를 구입하는 사람에게 제공하고, 이를 바탕으로 명의 이전을 완료합니다. 비용은 거래 가격에서 계약금과 중도금을 제외한 차액이 되겠습니다. 계약금을 포함한 해당 과정은 합의된 계약서에 명시되어야 되며, 만약 한쪽에서...',
# ...
#    '파주 힐스테이트 더 운정 아파트 분양조건 최근 부동산 시장을 달군 대표적인 소식은 GTX A 노선 개통입니다. 지난 3월 30일 수서 동탄 구간에 이어 파주 운정에서 서울역을 잇는... 특히 주부들이 필요로 하는 수납공간에 집중했는데요. 현관과 주방의 펜트리 설치로 인해 알파룸처럼 독립적인 생활공간이 가능하기 때문입니다. 더불어 침실엔 대형 크기의 드레스 룸과...',
#    '유성 하늘채 하이에르 주상복합아파트 분양가격과 필요서류 유성 하늘채 하이에르 입주자 모집공고가 4월 4일 승인이 되었습니다. 공급 위치는 대전광역시... 구비서류 ▶ 조건에 따라 필요서류가 다르니 입주자 모집 공고를 꼭 확인하시길 바랍니다. 당첨자 계약 체결 ▶ 2024년 5월 7일 (화)~ 2024년 5월 9일까지 계약 체결 ...',
#    '☞사실 무슨 서류가 필요한지 잘 몰라도 일단 입주관리센터로 가서 얘기해 보면 된다. 분양사 서류가 준비 된 후엔 취득세를 납부해야 한다. 하지만 아파트 보존등기가 아직 완료 되지 않았을 경우엔 1단계 패스하고 2단계인 취득세부터 납부해도 좋다. 2. 취득세 신고·납부 - ·군·구청 지적과&세무과 - 취득세는 잔금일로부터 60일 이내에 신고·납부해야 한다....',
#    '회사원으로 직장 다닌지 3년차입니다 아파트담보대출 필요서류를 알아보는 중인데 알려주실 수 있나요? 금융사마다 약간의 차이가 있을 수 있어도 거진 대부분 중복적으로 필수 서류가 있다고 알고 있어요 직장인으로 아파트담보대출 필요서류가 무엇이 필요할까요? 사대보험납입 증명? 이런것도 내야할꺼 같고 또 뭐가 하죠? 담보대출 관련해 안내...']},
#  {'question': '아세아 아파트의 설계 특징은 무엇인가요?',
#   'document': ['구성이며, 아파트 다음에도 뒤지지 않는 구성으로 디자인되어 있습니다. 광대한 공간을 활용한 드레스룸, 세탁실과 보조 주방, 큰 발코니, 넓은 거실과 침실을 특징으로 한 호사 A... 삼성전자 수원 사업장 근처의 장점은 무엇인가요? 영통역자이프라시엘 공급되는 서천동 행정 구역은, 수원 영통 망포 생활권에 속하죠. 삼성전자 수원 사업장이 근접하여, 선호하는 직주...',
#    '조성되어진다는 특징이 있는 단지입니다. 지하 1층 공간에는 타상품들과 차별화 되는 미팅룸과 취미실, 집중학습실등의 공간이 보급되고 지하 2층은 입주민들의 건강증진을 위한 피트니스 시설과 실내골프연습장이 있습니다. 나주 두산위브 더퍼스트 아파트의 특화로 단지 내 캠핑장이 위치하여 가족, 이웃과 함께 여유롭게 캠핑을 즐길 수 있겠습니다. 내부 는...',
#    '부영그룹은 국방부로부터 용산지역 부지를 매입한 이후 랜드마크급 아파트단지를 계획하고 있다. 하지만 일부 부지의 확보가 어렵고, 미국측 설계변경 요구 등으로 지연되어 오고... 용산 아세아아파트 특징 (용산 아세아아파트 일반현황) 13개동, 지하3층 ~ 지상 32층 규모의 대단지 공동주택 969가구와 부대복리시설이 포함될 예정 미 대사관 숙소 (150가구)...',
#    '아파트 단지의 특징은 무엇인가요? 더샵 광양레이크센텀 아파트는 40층 건물로 구성되어 있으며, 주변 환경에 따라 호수 풍경을 바라볼 수 있도록 설계되었습니다. 아파트 단지 내에는 다양한 시설과 서비스가 제공되어 편의를 높여줍니다. 또한, 쾌적한 주택환경과 철저한 경비 시스템으로 안전한 생활을 할 수 있습니다. 4. 광양레이크센텀 주거시설은 어떻게...',
#    '\'도시의 유기적 성장을 유도하기 위해 건축이 할 수 있는 일은 무엇인가?\'라는 질문에 그는 이렇게 답했다. "재미있는 곳에 재미있는 사람들이 많이 모입니다. 따라서 도시의 성장을... 못했던 아파트 형태의 공장으로 설계해 소공인을 위한 공간 브랜딩을 제안하는 것뿐만 아니라, 성수동의 장소성을 극대화한 공간 브랜딩을 통해 소공인 제조업 공간의 혁신을 이루고자...']},
#  {'question': '아세아 아파트 분양 정보를 어디에서 얻을 수 있나요?',
#   'document': ['평택은 수도권에서 발전 가능성이 가장 높으며 지속적인 투자가 이루어지는 도시라는 점 잊지 않으셨으면 좋겠습니다. 신영지웰 평택화양 아파트 2024년 5월 모델하우스 오픈 시(예정 )에 더욱 자세한 모형과 유닛 내용 살펴볼 수 있기 때문에 지속적으로 팔로우하도록 하겠습니다. 감사합니다. 위 관심고객등록으로 자세한 분양정보 제공해 드립니다',
#    '매교역 팰루시드 아파트 분양 정보 매교역 팰루시드 완판 , 영통자이 , 영통역자이(조금남음) 수원 미분양 아파트 완판 행진 입니다. 매탄동 영통2구역 재개발 진행중 노려보십시요.... 갈 수 있어요. 영동고속도로 와 용인서울, 경부고속도로 그리고 과천봉담도시고속화 등을 통해 전국 든 수월하게 연결되는 교통 입니다. 반경 2KM 이내에 롯데백화점이나 NC백화점, AK...',
#    '이편한세상 신곡 시그니처뷰 아파트 분양정보 정부의 주거지 공급 활성화를 위한 노력에도 불구하고 주택의 인허가 및 착공 물량이 감소하게 되면서 주택 공급 가뭄에 대한 우려는... 또한 이편한세상 신곡 시그니처뷰는도로면으로 당 사업지의 우측 43번 국도를 이용해 구리포천고속도로의 동의정부IC 진입으로 수도권 든 빠르게 이동할 있겠습니다. 이번에는...',
#    '오송역 동아라이크텐 오송 아파트 분양 정보 충북 청주시는 서울 및 수도권에서 가까운 입지를 바탕으로 다양한 개발 호재가 이어지는 중인데요, 특히 차세대 방사광가속기를... LG를 비롯한 대기업과 국가 주도의 메디컬 중심을 바탕으로 하는 입지인 만큼 철도와 청주국제공항 등 전국 서든 2시간대에 도달할 있는 뛰어난 접근성을 자랑하게 되며 풍부한...',
#    '분양정보 부동산 경기가 불안정한 시기에 분양을 시작해 특별한 조건에 돌입한 하이엔드 단지가 있습니다. 바로 방배동 파세지아타인데요. 아파트 명에서도 알 수 있듯이 우리나라의... 자연스러운 커브를 이루도록 디자인되었으므로 어디에서도 볼 수 없었던 고급스럽고 특별한 실내 장식을 적용할 있다는 점이 특징입니다. 150㎡의 B 타입 역시 4룸, 3베스 룸으로...']},
#  {'question': '아세아 아파트 분양 시 청약 절차는 어떻게 되나요?',
#   'document': ["지하 3층~지상 최고 32층, 13개 동, 총 969가구 규모의 아파트로 이중 849가구의 일반분양 물량으로 청약을 기다는 분들의 관심을 받고 있습니다. 나머지 150가구는 미국 대사관의 직원 숙소로 이용될 예정입니다. 2024년 1월 31일에 '용산 지구단위계획 및 특별계획 구역 세부 개발계획' 결정 변경안 이 열람공고하면서 용지의...",
#    '총평 오늘은 서대문 센트럴 아이파크 분양가 홍은 13구역 서울 아파트 청약 (GTX-A 호재?)에 대하여 살펴봤습니다. 서대문 센트럴 아이파크는 현재 기준으로는 지하철역과 무척 거리가 멀어 교통이 불편한 편입니다. 하지만 기대주 GTX-A 가 개통 예정입니다. 광역도시철도에서 가장 먼저 착공된 라인으로 완공 삼성역까지 30분 내 도착 가능해집니다. 하지만...',
#    '사전청약 제도 문제점 일반청약 사전청약 본청약 뜻 절차 차이 일반청약은 주택을 분양할 때 지구계획 승인을 받고 아파트 등 주택 건설 사업승인을 받은 뒤 착공에 들어가면 청약을... 사전청약에 당첨되고 본청약까지 자격을 유지하게 되면 본청약에 당첨된 것과 동일한 효력이 있고, 본 계약금을 넣고 정식으로 계약을 하거나 당첨을 포기할 수 있습니다....',
#    '아파트 분양을 선호하는 분들이 많으실 겁니다. 아파트에 살면 편리한 시설을 누리는 것은 물론 비용도 저렴하고 이후 타인에게 매도하기가 쉽다는 이점이 있지요. 그럼 어떻게 해야... 이어서 절차에 대해 하나씩 알려드리겠습니다. 2. 주택청약통장 가입하기 할 때 필수적으로 가지고 있어야 하는 통장입니다. 만 19세 이상 누구나 가입할 수 있고 시중...',
#    '아파트 청약 방법 절차 살펴보기 내 집 마련의 방법은 여러가지 인데요. 그중에서 합리적인 루트는 당연 주택청약입니다. 관련하여 알아보도록 할텐데요. 어느새 내 집 장만할 나이가... LH 홈페이지를 클릭하여 공인인증서 로그인 후 분양공고를 참고하시어 공고일 이후 조건과 접수일, 마감일을 꼼꼼히 확인하시어 해당 날짜에 신청하시면 됩니다. 방법 주의...']},
#  {'question': '아세아 아파트 분양에 대한 후기는 어떻습니까?',
#   'document': ['사실 분양 단지 분석 강남 아파트 갈아타기라고 한 거는 여러분들이 나 지금 강남 아파트 갈아탈 필요 없는데라고 생각할지라도 그것에 대한 기준을 갖고 보시면 더 어떻게 여러분들이 이제 내 집 마련을 해서 어떻게 상급지로 이동을 할 수 있는지 갈아타기를 할 수 있는지를 알 수 있을 것 같습니다. 하지만 무주택자 같은 경우에는 난 갈아타기도 할 거 없는데라고...',
#    'ㅎㅎ 참고로 나도 부영 아파트 거주 중 아세아아파트는 과거 용산 미군 부대 등 군부대 용지로 쓰이던 곳이다. 2001년 특별계획구역으로 정해지고 2014년에 부영이 국방부로부터 사서... 부영이라는 브랜드 이미지를 봤을 때 선호도는 차이가 날 수 있겠지만 워낙 용산 노른자 땅이라 올해 물량이 나온다면 가장 핫한 단지가 될 것이라는 긍정적인 평이 많다....',
#    '좋아질자리 아세아아파트 특별계획구역 빗물펌프장 특별계획구역 중장기적으로 볼자리 각지역들의 지역분석자리 용산 각지역들은 모두다 별5개 짜리임 서부이촌동 특별계획구역... 용산업무지구에 아파트가 들어오면 어찌될까? 개발에 대한 이슈가 있기 때문에 비싸다 삼호 다음달부터 거래가능한 동부이촌동 거의다 개발되었음 한강맨션...',
#    '아세아아파트는 옛 용산 미군 부대와 국군복지단 등 군부대 용지로 쓰이다가 2001년 특별계획구역으로 정해진뒤, 부영그룹이 2014년 국방부로부터 사서 현재까지 보유하고 있는데 도로확보를 위한 수용이 문제가 생기면서 아직 착공도 그래서 분양도 지연이 되고 있는 상태라고 합니다. 근데 한강보이고 공원인접에 정말 최강 금싸라기 땅이 아닐수 없습니다. 경쟁률...',
#    '임장 후기는 꼭꼭 써야 한다는 걸! 몇 달 전에 다녀왔던 곳들도 임장기를 써야 나중에 기억할 수 있는 것들이 많더라고요. 우리의 기억 용량은 한계가 있습니다. 다리 아프게... 아세아아파트 특별계획구역 아세아아파트 특별계획구역 -부영그룸이 2014년 국방부에서 사들임 -총 969가구(일반 819가구), 지상 최고 32층 -21년 7월 기와 가마 등 유물이...']},
#  {'question': '가점제란 무엇이며 어떻게 적용되나요?',
#   'document': ['주택 청약가점제 적용비율의 모든 것 청약가점제란 무엇이며, 각 지역별로 적용되는 비율은 어떻게 다른가요? 주택시장의 공정한 기회 제공을 위해 도입된 청약가점제는 다양한 조건에 따라 가점을 매기고, 이를 통해 주택을 분양받을 수 있는 순위를 결정합니다. 이제, 서울을 비롯한 수도권, 공공주택지구, 투기과열지구, 청약과열지구 등 다양한 지역에서의...',
#    '그 이유 중에 하나가 가점을 얼마나 잘 쌓아왔냐에 따라서 달라지게 되는데, 가점제 점수는 개개인에 따라서 다르게 적용이 되기 때문에 무엇을 어떻게 해야 하는지를 알아보셔야 합니다. 1. 무주택기간 가산 표를 확인해 보시면 첫 번째로 나오는 항목은 무주택기간 입니다. 말 그대로 집을 소유하지 않은 상태로, 청약통장에 가입을 하신 후 일정한 기간이 지나게 되면...',
#    '추첨제의 경우는 가점제를 적용한 뒤에 남아 있는 분양 물량을 말 그대로 무작위 추첨으로 선정하는 방식입니다. 분양에서 가장 유리한 가점제의 경우 사실 충족하기가 매우... 이렇게 주택청약 추첨제 가점제에 대해 알아보았습니다. 둘 중 나에게 더 유리한 것이 인지 하면 가점을 더 올릴 수 있는지 전략을 잘 짜보시길 바랍니다.',
#    '그래서 오늘은 이 주택청약가점제가 무엇인지 그리고 산정기준이 어떻게 나뉘어져 있는지 알아볼게요. 주택청약가점제란? 주택청약제도는 국민들이 내집마련을 쉽게 할 수 있도록 도와주는 제도예요. #청약통장 가입자에게 우선권을 주는 방식으로 진행되는데 점점 의 비중이 높아지고 있어서 많은 사람들이 관심을 가지고 있어요. 그래서 많은 분들이...',
#    '청약가점제란 무엇인가요? 아파트청약 1순위 청약자 내에 경쟁이 있을 경우에 부양가족수(35점), 무주택기간(32점), 청약통장가입기간(17점)을 기준으로 산정하여 가점점수가 높은 순으로... 예외사항이 있는데 수도권 보금자리기구, 주택거래 신고지역, 투기과열지구에는 청약가 되지 않으니 참고하시길 바랍니다. 청약 당첨 결과는 아나요? 보통 청약...']},
#  {'question': '가점제를 통한 청약 시 어떤 요소가 중요한가요?',
#   'document': ['청약가점제 계산 방법 청약가점제에서는 소득 수준, 주택 소유 여부, 무주택 기간, 부양 가족 수 등 여러 가지 요소를 고려하여 가점을 계산합니다. 이 과정에서 신청자의 개인적 상황이 매우 중요한 영향을 미치게 됩니다. 4. 청약가점제를 통한 주택 분양 신청 팁 정확한 정보 제공: 신청 제공하는 정보는 정확해야 합니다. 정보의 정확성이 가점 계산에 큰...',
#    '대한민국 정부에서는 이 점을 해소하기 위해 추첨을 통한 것이 아니라 가점제를 도입해 가산점이 높은 사람들에게 먼저 우선순위를 제공하는 방식을 도입했습니다. 하지만 이에... 이는 주택청약 가점제와 관련해 중요하므로 많은 분들이 더 꼼꼼하게 살펴보게 되는데요. 만 30세 이상이라는 조건으로 많은 점수를 얻을 수 있기 때문입니다. 또한 결혼하면 혼인 신고일부터...',
#    '주택청약가점제 에서 우선권을 얻으려면 어떤 항목에서 가점이 이루어지는지 필수적으로 알아두셔야 하는데요. 무주택기간과 부양가족수, 청약통장 가입 기간 이라는 세 가지... 청약통장 추천 납입금액 그리고 가장 중요한 기준이죠! 가입기간은 통장 개설일부터 입주자 모집공고일까지의 기간이며, 1회 납입금액은 10만원으로 제한이 되어있어요. 따라서 매월 꾸준히...',
#    '공급 가점제 40% + 추첨제 60% 85㎡ 초과 100% 추첨제 어떤 것을 선택했는지에 따라 청약통장 납입횟수와 금액 등 전략을 다르게 해야 합니다. 국민주택부터 알려 드리겠습니다. 청약통장 납입횟수와 금액을 오래도록 유지해야 합니다. 국민주택은 횟수와 납입 금액을 오래 유지하는 것이 합니다. 통상적으로 12개월 이상, 12회 이상 연체 없이 납부해야 하고 투기...',
#    '청년주택드림청약통장 전환방법은 아래에서 3초만에 확인하실 수 있으니 참고하시길 바랍니다. 청년주택드림청약통장 전환 >> * 자격요건 / 지원내용 / 신청방법 1. 어떤 제도인가요?... 것이 중요합니다. 5-2. 세액 공제 혜택 청년드림청약통장을 이용하면 세액 공제 혜택도 받을 수 있으니, 세금 신고 이를 잊지 말고 반영해야 합니다. 결론 6-1. 전환을 장기적 이점...']},
#  {'question': '가점제에서 가장 높은 점수를 받을 수 있는 조건은 무엇인가요?',
#   'document': ['생각보다 조건이 너무 높아서 저는 지금 5점때라 많이 초초했는데요. 다행히도 시간적 여유가 조금 있어서 급하게 아이엘츠학원을 알아봤고 알아본 곳이 edm아이엘츠 였어요. 목표기간안에 6.0을 받을 수 있을지 걱정이 컸지만 아이엘츠만 하는 학원이고 빠르게 향상시켰다는 후기가 많고 시험센터라는게 맘에들어서 edm아이엘츠로 선택했어요! 가 데 반...',
#    '주택청약가점제 개념과 의미는? 아파트와 같은 내 집 장만의 종류는 다양한데요. 그중에서 오늘 부동산 단어를 공부해 보겠습니다. 주택청약가점제는 내 집 마련을 위해 꼭 챙겨야 하는 점수입니다. 해당 제도는 동일 순위 안에 있는 사람이 많아 경쟁의 여지가 있을 경우 부양가족 수와 무주택기간, 청약보유기간을 모두 산정하여 가 당첨자 순서로...',
#    '후자의 경우 기본적인 조건만 갖춘다면 누구나 신청이 가능하여 기본적인 경쟁률이 높아 당첨될 가능성이 매우 낮기 때문입니다. 이와 관련하여 높은 점수를 받을 수 있는 기준은 무엇인지 그 세부적인 사항을 알아보겠습니다. 우선 주택청약 가점제의 기준을 먼저 알아보자면 청약저축과 무주택기간 그리고 부양가족의 세 가지 항목을 바탕으로 산정하게...',
#    '높여서 받을 수 있다는 것도 알고 계시나요? 마케터 K와 차근차근 하나씩 알아보도록 해요. 이 청약가점제 정보를 읽고 나면 주택청약 당첨될 가능성이 파워업! 청약은 신청자의 조건에 따라 가산점을 부여하여 분양주택의 당첨자를 결정하는 제도고요. 이 제도는 무주택 기간, 부양 가족수, 청약통장 유지 기간을 기준으로 계산하며, 이를 합산하여 총점이 높은...',
#    '이 통장은 아파트 등과 같이 분양을 원할 때 신청할 수 있는 자격 조건이 됩니다. 적금형과 일시 예치식인 두 가지의 납입 방법이 있고, 국민과 민영 등 선택하여 공급받을 수... 주택청약가점제의 가장 높은 점수는 84점입니다. 집을 보유하지 않은 기간은 1년이 지날수록 2점씩 추가되며 32점까지 있습니다. 부양가족의 수는 한명당 5점씩이며 총 35점까지...']},
#  {'question': '가점제 적용 시 청약 당첨 확률을 높이는 방법은 무엇인가요?',
#   'document': ['힐스테이트 가장더퍼스트는 남향 위주의 단지 배치와 전 가구 4Bay 판상형 구조를 적용해 채광 및 통풍이 우수하도록 설계되었습니다. 내부에는 모든 가구에 드레스룸을 구성하고... 이제는 가점제에서 동점자가 발생 시 장기 가입자가 당첨자로 결정합니다. 부부 중복 으로 높이기 2024.03.25. 시행된 주택 공급에 관한 규칙에 따라 부부는 자 발표일이...',
#    '청약 제도에 대해 설명을 드리고 당첨확률을 높일 수 있는 방법에 대해 설명을 드릴게요. 먼저 주택에 대해 구분을 지어주는것이 필요한데요 청약을 할 수 있는 대상 주택은 무엇이... 전국의 대부분이 조정지역 이상의 규제지역이기에 일반분양분에서 가점제는 최소 75%를 받는다는것을 의미하고 있어요. 알기 위해 이를 거꾸로...',
#    '이처럼 공공분양은 높은 경쟁률로 인하여 당첨될 확률이 낮은데, 오늘은 공공분양 청약 당첨 확률을 높이는 방법과 사전청약 나눔형, 선택형, 일반형의 차이에 대하여 적어보겠다.... 이번에 진행된 뉴홈 사전청약은 말 그대로 사전청약이다. 본 청약까지는 시일이 걸리는데, 2030년 1월에 진행 예정인 등 입주까지 너무 오랜 기간 남았다는 아쉬움이 있다. 본 ...',
#    '주택청약에서 당첨 확률을 높이기 위해서는 무주택기간, 부양가족수, 청약통장 가입기간으로 산정되는 청약가점제 계산이 중요하다는 사실! 모두 알고 계실 텐데요. 다만 신청자... 그래서 오늘은 주택청약에서 정확한 가점제 계산을 위해 청약가점제 계산방법 및 가점 계산기에 대해 알아보도록 하겠습니다. 란? 란 입주자를 선정할 때...',
#    '(공공분양)에서 적용됩니다. 동일한 순위이나 수요는 높고 공급은 부족한 경우 청약점수 계산기를 통해 추출된 점수를 비교해서 선정을 하는 것이죠. ▼청약가점 계산 및 가점제... 활용 방법까지 알아보았는데요. 조금 도움이 되셨나요? 요즘처럼 청약이 대박 이라고 불리는 시대에 이러한 점수 계산기를 활용해서 나온 점수들이 데 도움이...']},
#  {'question': '가점제 청약에서 자주 발생하는 문제점은 무엇인가요?',
#   'document': ['‘가점제에서 자주 나오는 실수’라고 하면 대부분의 사람들은 고개를 갸웃거린다. 그도 그럴 것이 가점제는 딱히 어려운 절차가 아니기 때문이다. 무주택기간과 부양가족, 청약통장... 무주택기간 중 잠깐 집을 가지고 있었던 것을 ‘깜빡’하고, 한두 달 단기주택 매매나 갭투자를 했던 기억을 또 ‘깜빡’해서 한다. 배우자나 세대원이 상속받거나 다른 사람에게...',
#    '주택청약입니다. 그래서 오늘은 주택청약통장에 대해 명확히 알아보고 주택청약 1순위 조건 금액 및 신청방법에 대해 안내해 드리도록 하겠습니다. 주택청약통장이 무엇인가요?... 민영주택 가점제 시행 : 청약통장 가입기간, 무주택 유지기간, 부양가족 수 등의 다양한 기준에 따라 채점하여 합산점수가 높은 순으로 결정 추첨제 시행 : 말 그대로 추첨하여 복불복...',
#    '문제가 발생 하였습니다.추가 분담금으로 건설사와 많은 갈등을 격고 있는것은 뉴스에 자주 나오고 있습니다.그래서 저는 빨리 정부가 건축비 인상으로 인한 문제점을 빨리 해결해 주는것이 분양 시장이 활기를 찾는 방법이 아닐까란 생각이 듭니다. 청약자격 서울시 특별시 거주자 및 수도권 지역 거주자(인천,경기) 세대주인 미성년자(자녀양육,형제 자매부양)...',
#    '공고일이 같으면 2)청약접수일 3)예비자발표일이 먼저인 예비자번호부터 소멸됩니다. 그러니 중복 지원을 하시더라도 꼭 서로 빌표일 공고일 확인을 잘 하셔서 소멸되도 상관 없는지... 따로 사는 자녀의 차량을 등록할 수 있습니다. (자주 방문하기 때문에) 그런데 실거주자 아니면 절대 등록이 불가한 곳도 많으니 미리 문의를 해봐야 합니다~ (15) 입주하라고 연락',
#    '같이 지식 더하기 그런데 청약, 자주 들어보기만 하고 정확히 어떤 건지는 잘 모르시겠다구요? 청약이란 무엇인가? 새로 건축된 아파트나 오피스텔을 분양할 때, 해당 집을 살... 1순위 - 가점제) 청약 순위에 따라 입주자를 선정 2순위 - 추첨제) 통장을 소유하되, 기준을 충족하지 못하는 경우 취소 후 재공급 (계약취소 주택 재공급) 이후, 계약 취소된 주택들을...']},
#  {'question': '가점제를 이용한 청약 절차는 어떻게 진행되나요?',
#   'document': ['어떻게 사용하는지 모르는 때가 많아 자세히 숙지해야 합니다. 주택청약 가점제에 대해 자세한 정보를 알아보고 그 제도를 이용해 내 주택 마련을 위한 발판을 다져놓아야 합니다.... 받아 당첨이 취소되면 1년간 신청하는 자격을 잃게 되므로 꼼꼼히 따져 요청해야 합니다. 신청방법은 개인에게 어려움을 겪지만 자신의 상황과 조건에 맞춰 해 큰 도움이 되길 바랍니다.',
#    '추첨제는 같은 순위 안에서 경쟁이 생기면 추첨을 하는 제도를 말하는데 높은 점수를 받지 못해도 번거로운 신청 절차 없이 적용 대상이 될 수 있습니다. 추첨제 가점제의 비율은 공급하는 곳마다 차이가 있고 주택의 종류에 따라 다르게 적용합니다. 특히 투기과열지구는 85제곱 미터 이하의 경우 추첨제가 없으며 과열지구는 25프로만 추첨제를 합니다. 추첨제도...',
#    '그래서 오늘은 이 주택청약가점제가 무엇인지 그리고 산정기준이 어떻게 나뉘어져 있는지 알아볼게요. 주택청약가점제란? 주택청약제도는 국민들이 내집마련을 쉽게 할 수 있도록 도와주는 제도예요. #청약통장 가입자에게 우선권을 주는 방식으로 진행되는데 점점 의 비중이 높아지고 있어서 많은 사람들이 관심을 가지고 있어요. 그래서 많은 분들이...',
#    '단, 현장에서 동호수 배정에 참석한 이후라면 통장을 이용한 것으로 간주합니다. 이 경우는 추첨 후 계약을 포기했더라도 더 이상 쓸 수 없다는 점 꼭 기억하여 손해 없으시길 바라겠습니다. 한편 당첨자와 청약 예비당첨자까지 순서가 진행되었음에도 물량이 소진되지 않아 무순위도 넘어가는 경우도 많습니다. 이는 가점, 거주지, 보유한 주택 수 등 여러 조건에 제한받지...',
#    '그렇기에 주택청약가점제 같은 경우에는 현재 어떻게 점수를 높여볼 수 있는지 알아보셔야 합니다. 급히 돈이 필요하다는 이유로 무리하게 넣은 통장을 해지한다면 사실 의미가... 평형에 따라서 차이가 있긴 한데 60m²가 넘지 않는 경우에는 추첨으로 60% 비율로 이루어지며 85m²이하 같은 경우에는 추첨 30%를 하여 활용하게 됩니다. 추첨제로 더해지는 비율 같은...']},
#  {'question': '가점제 청약 시 유의해야 할 사항은 무엇인가요?',
#   'document': ['민영주택 일반공급 1순위 가점제 청약 시 지금까지는 청약신청자 본인의 통장 가입기간만 인정되었으나, 앞으로는 배우자가 청약통장이 있는 경우 아래 표에 따라 통장 가입기간별... 단, 배우자가 아닌 다른 세대원(부모, 자녀 등)의 당첨 이력은 예외로 하지 않는다는 점을 하셔야 합니다. 부부가 당첨자발표일이 동일한 주택에 중복신청 수 있나요? 네, 2024년...',
#    '#A107숨마데시앙 동탄2신도시 아파트 청약 결과 및 청약 유의사항 - 변경된 전매제한 ·청약조건·실거주기간·가점제·추첨제 등 동탄2신도시 아파트 청약 시 꼭 알아두셔야 할 유의 사항을 요약해 보면, 투기과열지구에서 해제되었지만 수도권 내 공공택지에서 공급하는 분양가 상한제 적용 민영주택이므로 8년 전매제한기간과 거주의무기간 5년, 투기과열지구...',
#    '이때 유의해야 할 것은 지역의 기준이 분양이 이루어지는 지역이 아니라 본인의 현재 거주지라는 것인데요. 주민등록상의 거주지가 기준이 되니 이 점 고려하여 찾아보시는 것이 좋습니다. 우리나라에는 이미 주택청약 1순위 조건을 충족하고 있는 사람들이 많은데요. 그렇기에 그 이상의 조건은 를 통해서 가리고 있습니다. 가점은 무주택 기간, 부양가족 수...',
#    '질병휴직 시 유의해야 할 사항은 무엇인가요 질병휴직 시 유의해야 할 사항은 매우 중요합니다 질병휴직은 질병이나 다른 의학적 상태로 인해 일시적으로 일을 수행할 수 없는 상황에서 근로자가 일시적으로 휴식을 취할 수 있는 제도입니다 이는 근로자의 건강과 안녕을 보호하기 위한 조치로, 근로자가 적절한 치료와 회복 기간을 가질 수 있도록 도와줍니다 그러나...',
#    '지원내용 청년주택드림청약통장을 이용하면 최대 4.5%의 이자율을 적용받을 수 있으며, 청약 당첨 시에는 우선권을 부여받아 내집 마련의 기회를 한층 더 가까이 할 수 있습니다. 2.... 청년주택드림청약통장 전환 시 유의사항 4-1. 전환 시기와 기한 청년주택드림통장 전환은 연중 언제든지 가능하지만, 일정 기간 내에 신청해야 하는 경우도 있으니 마감일을 확인해야...']},
#  {'question': '가점제 청약의 장단점은 무엇인가요?',
#   'document': ['주택청약 추첨제 가점제의 다른점에 대한 것이니 함께 살펴보시면 좋을 것 같습니다. 먼저, 전자부터 무엇인지 볼까요? 이는 청약 1순위의 자격을 갖춘 사람들만 뽑아 랜덤으로 추첨을... 주택청약 추첨제 가점제 중 후자보다는 전자가 진입하기가 수월하다 할 수 있을 것입니다. 물론 그만큼 당첨률을 운에만 기대야 한다는 단점은 존재하지만 말입니다. 또한, 이때...',
#    '청약 장점 서울 경기 인천에 거주하면 무주택 조건 없이 1주택 세대주도 추첨으로 당첨 가능 특별공급 생애최초 1인가구도 당첨 가능 (확률은 희박) 입지가 깡패 공급 물량 많음 평수가 작지만 주변 시세대비 확실히 쌈 (시세차익 무조건 발생) 신반포 메이플자이 단점 2월말 당장 현금 2.5-3.5억 보유 필요 평수가 작음 서울특별시 2년 이상 거주해야 유리...',
#    '가점제와 추첨제 선정 순서는 예를 들어 84A 타입이면 98세대 중 가점 40%인 40세대 가점순으로 뽑고 나머지 58세대 중 75%인 44세대 무주택 중에서 추첨하고 나머지 14세대는... 장점은 구의역 초역세권, 잠실 생활권, 복합시설, 한강뷰 가능 세대, 초고층 랜드마크, 강남. 북 이동이 편리하다, 대형 평형 위주인 아파트인 점이네요. 단점은 구의역...',
#    '방식으로 청약이 이루어진 곳입니다. 우선 정부정책에 따라 명칭이 자주 변경되어 이해를 돕고자 신혼희망타운이라는 것이 무엇인지 안내해 드리겠습니다. 신혼희망타운... 1단계에서 30%를 혼인기간 2년이내이거나 2세 이하의 자녀를 둔 신혼부부와 예비신혼부부 및 2세이하의 자녀를 둔 한부모가족에세 로 우선해 공급됩니다. 1단계에서 30%공급후 2단계에서는...',
#    '장단점: 무순위 청약의 장점은 청약통장이나 가점제의 제약 없이 기회를 얻을 수 있다는 점입니다. 그러나 단점은 당첨된 이후 재당첨에 제한을 받는 것과 무순위 청약 분양 물량이... 무순위 청약에 당첨된 후 나의 의무와 주의할 점은 무엇인가요? A1. 당첨된 후에는 계약금과 중도금 등의 납부 의무를 이행해야 합니다. 또한 당첨된 주택의 소유권 및 재산권에 변동이...']},
#  {'question': '가점제 청약에 영향을 미치는 외부 요인은 무엇이 있나요?',
#   'document': ['카사바 가격에 영향을 미치는 외부 요인은 무엇인가요 카사바는 많은 사람들에게 중요한 영양원으로 인식되고 있습니다 이로 인해 카사바 시장은 꾸준한 수요를 유지하며 성장하고 있습니다 그러나 카사바 가격은 다양한 외부 요인에 의해 변동될 수 있습니다 첫째로, 기후 조건은 카사바 생산에 큰 미칩니다 카사바는 따뜻하고 습한 기후를 선호하며, 건조하거나...',
#    '수원 교통사고 입원 요인을 찾아 한의원 대응을 자동차 사고가 발생하는 것은 예상하지 못하는 시점이었고 이로 인해서 몸에 나타나는 영향 또한 상당하다고 했어요. 충격이 심각하다면... 추돌에 의해 사람의 몸에 미치는 영향은 다양하기 때문에 참고하셔서 조치를 취하시길 바랐어요. 만약 개방골절이나 분쇄골절과 같은 뼈가 여러 조각으로 부서지거나 로...',
#    '소비자 행동에 영향을 미치는 외부 요인에는 무엇이 있나요? 이 책에서 소비자 행동을 처음 이야기 할 때 소비자 행동에 영향을 미치는 요인은 크게 내부 요인과 외부 요인이 있다고 말했습니다. 이 중 외부요인은 다음과 같습니다: ① 문화적 요인(cultural factors), ② 상황적 (situational factors), 그리고 ③ 사회적 (social factors). 첫째...',
#    '우리, 아파트 딱 100채만 보러 가보자 아파트 매매할 때 체크해야할 사항 시세에 영향을 미치는 내부.외부 요인 팩트만 짚어주는 부동산 입지분석 투자책 별점 : ★★★★ (4.0) 분류... 싶고 청약 대상이 아니라 분양권을 사는게 어떨까 고민도 했다. 분양권은 "초기 분양권"을 사라. 깔끔하게 팩트만 정리해주어 군더더기 없어 좋다. 아파트 매수할 때 을 체크해봐야할...',
#    '키성장에 영향을 미치는 요인과 조절법 "어린이들의 키는 어떻게 자라는 걸까요 " 많은 부모님들이 이 질문에 대해 궁금해하십니다 키 성장은 유전적인 요소뿐만 아니라 다양한 외부 요인들에도 영향을 받습니다 무엇보다도 올바른 영양섭취가 중요합니다 단백질, 칼슘, 비타민 등이 충분히 공급되어야 키 성장을 도와줍니다 뿐만 아니라 충분한 수면도 키 성장에 중요한...']},
#  {'question': '가점제 청약을 위해 준비해야 할 서류는 무엇인가요?',
#   'document': ['주택청약가점제는 내 집 마련을 위해 꼭 챙겨야 하는 점수입니다. 해당 제도는 동일 순위 안에 있는 사람이 많아 경쟁의 여지가 있을 경우 부양가족 수와 무주택기간, 청약보유기간을... 하려고 할 때 점수가 낮은 상황이 발생하여 경쟁에서 밀릴 수 있습니다. 예치금이 밀리지 않고 오랜 기간 가지고 있는 것이 좋기 때문에 상황을 잘 살펴보고 보다 유리한 쪽으로 하...',
#    '내 집 마련에 뜻이 있다면 꼭 준비해야 할 청년우대형 주택청약 전환 서류 조건에 대해 알아보려고 합니다. 이미 기존의 주택청약종합저축을 가지고 계신 분들은 많으실 겁니다.... 2009년부터 나오기 시작한 통장으로 아파트 청약에 사용하기 위해서 만듭니다. 한때 가점을 높인다고 아이가 태어났을 때부터 통장에 가입시켜주는 부모님도 계셨으나 인정기간이...',
#    '지금까지 아파트 청약 예비당첨이 되기 위한 준비 사항과 필요한 서류에 대해 알아보았습니다. 각 단지마다 세부 요건이 다를 수 있으니, 주의 사항과 필요한 요건을 정확히 확인하고 준비하는 것이 중요합니다. 또한, 희망하는 공동주택에 성공적으로 입주하기 서는 자격 불충분이나 자금 관련 문제로 인한 낙첨을 피하기 모든 조건을 꼼꼼히 검토하는 것을...',
#    '청약가점제는 점수를 더 높게 받기 위해서는 시간이 필요하므로, 미리 계획을 세우고 철저히 준비하는 것이 필요해요. 청약가점제는 주택시장에서 공정한 기회를 제공하기 위해... 수, 청약통장 유지 기간의 점수를 합산하여 최종적인 청약 가점이 산출되기 때문이에요. 산출된 가점을 바탕으로 전략적인 접근이 필요한대요. 신청은 인터넷을 통해 수 있으며...',
#    '공급하기 위해 여러 청약 제한 사항들을 두고 있습니다. 따라서 제대로 준비하지 않고 청약을 진행할 경우 불이익을 받을 수도 있는데요. 오늘은 청약 제한 사항이 무엇인지... 마지막으로 과거 2년 이내에 가점제로 당첨된 사실이 있는 세대에 속해 있다면 1순위 로 수 없는 것을 의미합니다. 제한을 받는 기간은 나의 제한사항 조회를 통해...']}]

# %%
print(utils.jload("./document2.json")[0]['document'][0])
# Out:
# 부동산매매서류 부동산 매수 매도 매매시필요서류 여기까지 부동산 매매시 필요서류에대해서 알아보았습니다 롯데건설에서 제공하는 주거시설 입주가예정되어 있고 주변 분양시장도 호황입니다. 많은 관심을 가지고 계시는 곳 중 하나라고 볼 수 있는데 현재 매물로 나왔던 아파트는 실거래가가 약 평으로 형성됩니다. 는 있지만 지금이 급매물이 나와 있는걸 확인했어요....

# %% [markdown]
# 가끔 크롤링이 안되는 경우가 있어서 한번 검수해줍니다.

# %%
search_data = utils.jload('./document2.json')
for idx in range(len(search_data)):
    if len(search_data[idx]['document']) == 0:
        print(f"Index [{idx}] 번째 데이터가 수집되지 않았네요.")
# Out:
# Index [500] 번째 데이터가 수집되지 않았네요.
# Index [501] 번째 데이터가 수집되지 않았네요.
# Index [506] 번째 데이터가 수집되지 않았네요.

# %% [markdown]
# 수집되지 않은 데이터를 한번더 크롤링하게 하고 `document.json`에 저장합니다.

# %%
for idx in range(len(search_data)):
    if len(search_data[idx]['document']) == 0:
        search_data[idx] = utils.get_document_through_selenium(
            inputs=search_data[idx]['question'],
            n_documents=5,
            indent=4
        )[0]
# Out:
# 1it [00:03,  3.69s/it]
# 1it [00:02,  2.80s/it]
# 1it [00:02,  2.76s/it]

# %% [markdown]
# 제대로 수집되었는지 또 검사해줍니다.

# %%
for idx in range(len(search_data)):
    if len(search_data[idx]['document']) == 0:
        print(f"Index [{idx}] 번째 데이터가 수집되지 않았네요.")
# Out:
# Index [500] 번째 데이터가 수집되지 않았네요.
# Index [501] 번째 데이터가 수집되지 않았네요.
# Index [506] 번째 데이터가 수집되지 않았네요.

# %%
search_data[506]
# Out:
# {'question': '줄피의 원산지는 어디인가요?', 'document': []}

# %% [markdown]
# 원인 파악을 위해 해당 페이지로 검색해보면 인기글이 없으므로 데이터에서 삭제합니다.

# %%
# 삭제할 인덱스 모으기
remove_idx_list = []
for idx in range(len(search_data)):
    if len(search_data[idx]['document']) == 0:
        remove_idx_list.append(idx)

# 삭제할 인덱스를 pop 
for idx in remove_idx_list:
    search_data.pop(idx)

# %%
utils.jsave(data=search_data, file="./data/document.json", mode="w", indent=4)

# %%
for idx in range(len(search_data)):
    if len(search_data[idx]['document']) == 0:
        print(f"Index [{idx}] 번째 데이터가 수집되지 않았네요.")

# %% [markdown]
# ### 5. encoder 모델을 활용하여 데이터를 유사도 기준으로 정렬하기
# 최근에 공개된 intfloat의 e5 Multi Lingual 모델을 사용하여 유사도를 계산합니다.
# 질문을 했을 때, 검색되는 인기글 데이터들중 유사도가 높은 순서대로 문서를 다시 정렬합니다.
# 정렬된 순서대로 데이터를 좀더 많이 참조하도록 프롬프트를 통해 지시합니다.

# %%
search_data = utils.jload("./data/document.json")

# %% [markdown]
# e5모델의 자세한 내용은 [hugginface](https://huggingface.co/intfloat/e5-base-v2)를 참조하세요
# 유사도 계산시 `multiprocessing` 모듈을 사용합니다.
# 데이터 전처리시에 `multiprocessing`, `threading`, `concurrent.futures` 등의 병렬처리 도구를 사용하는 것이 속도 개선에 많이 도움이 되었습니다.

# %%
for question in tqdm(search_data):
    question['document'], question['scores'] = similarity.sort_by_similarity(question['question'], question['document'])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 959/959 [20:19<00:00,  1.27s/it]

# %%
utils.jsave(search_data, "./data/search_data.json", "w", indent=4)

# %% [markdown]
# ### 6. Instuction 데이터셋 만들기
# 완성된 질문리스트와 인기글 데이터를 통해 ChatGPT에 정답을 출력하도록 요청합니다.
# ChatGPT는 아래의 프롬프트처럼 question에 대한 answer 답변을 출력합니다.
# 완성된 question, answer 텍스트는 학습시킬 모델의 훈련용 데이터셋으로 전달됩니다.
# 본 문서의 프롬프트는 [Stanford Alpaca의 프롬프트](https://github.com/tatsu-lab/stanford_alpaca/blob/main/prompt.txthttps://github.com/tatsu-lab/stanford_alpaca/blob/main/prompt.txt)를 참조하였습니다.
# 예시 데이터는 `instruction.jsonl`로 제공합니다.

# %%
print(prompts.INSTRUCTION_PROMPT_PREFIX + prompts.INSTRUCTION_PROMPT_CONTENT)
# Out:
# 요청받은 question을 document를 참조하여 answer로 답변하세요.
# question 1개당 여러개의 document가 주어지며, question은 10개씩 전달됩니다.
#
# 요구사항은 다음과 같습니다:
# 1. 어휘의 다양성을 위해 같은 단어를 반복하지 않습니다.
# 2. 문장의 형태가 다양해야합니다. 예를 들어 질문과 명령형이 결합되는 형태여야 합니다.
# 3. 답변은 제공받는 document들을 기반으로 작성되어야 합니다.
# 4. 제공되는 document의 순서가 먼저 제공될 수록 더 중요한 데이터이므로 답변에 더 많은 영향을 끼쳐야합니다.
# 5. 답변은 자세한 내용이 포함되도록 제공되어야하지만 200단어를 넘지 않는 것이 좋습니다.
#
# 출력 형식은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 각 question마다 출력 형식은 다음과 같아야합니다:
# {'question': '전달 받은 question의 내용', 'answer': '답변 내용'}
#
# ###question:
# {question}
# ###document:
# {document}

# %%
search = utils.jload("./data/search_data.json")

# %%
# 리스트 형태인 document 데이터를 하나로 합치기
for data in search:
    data['document'] = "\n".join([f"{idx+1}. {d}" for idx, d in enumerate(data['document'])])

# %%
print(search[0]['document'])
# Out:
# 1. 말해야 되나요? 주택임대차보호법 제 6조 제 1항 (계약의 갱신) 계약이 해지되기 6개월 전부터 2개월 전까지, 계약을 해지하겠다는 통보를 해야 한다. 즉, 법률상 늦어도 계약이 종료되기 2개월 전까지는 임대인에게 말해야 된다는 뜻인데요. 만약 해당 기간 안에 말하지 않았다면? 자동으로 연장되는 묵시적 갱신이 될 수 있습니다. 때문에, 종료 시점에 맞춰서 자금을...
# 2. 기간을 보통 2달 정도 주게 되는데, 해당 기간 내 임대인은 건설사에 중도금 대출과 잔금을 모두 상환해야 하기 때문에 금액이 떨어지게 됩니다. 오늘은, 미등기 신축 아파트 전세 계약... 요즘은, 임차인이 전세를 구할 때 전세자금 대출을 받는 경우가 상당히 많습니다. 그런데 대출에 필요한 모든 서류를 은행에 제출했을 경우 은행에서 대출금이 나오는지?는...
# 3. 전세보증금반환소송 유리한 결과를 위해 전세 보증금은 결국 임대인과 임차인이 계약을 하게 된 시점부터 법적 효력이 가능한 기간 동안 임차인이 임대인의 부동산을 사용하겠다는... 사례에는 얼마나 더 다양한 시점이 있는지를 사전에 꼭 파악한 뒤 철저히 준비를 해야 한다고 하였습니다. 인가결정이나도 안도할 수 없어 반환금 지급 명령은 인가 결정이 되었다고...
# 4. 전세사기변호사 법무법인 이현 부동산 소송 전략센터입니다. 대여금반환청구소송에 급여채권가압류, 추심까지 책임져드렸어요 생각보다 많은 분들이 겪고 있는 문제입니다. 얼마나... 수원전세사기변호사 ‘내용증명’을 통해 보다 확실하게 계약만료를 알릴 수 있습니다. 내용증명에는 집주인에게 ‘부동산 목적물’ ‘임차’ ‘만료일’ ‘종료...
# 5. 생각하면 전세사기 초기 때의 내 예전 모습이 떠올라서, 마음이 찡해진다... 얼마나 힘드실까... 그래서 결심했다. 그 사람들을 위해서, 정보의 사막 속에서 몸소 필요한 정보를 찾고... 어, 근데 계약기간이 남았다? 1. 이사 가고 싶다. 2. 전세금 반환 소송을 걸고 싶다. (승소 후 재산 압류, 경매 진행, 채권추심 하고 싶다.) 1, 2 중 하나에 해당된다면, 중도해지하는 걸...

# %%
print(prompts.INSTRUCTION_PROMPT_CONTENT)
# Out:
# ###question:
# {question}
# ###document:
# {document}

# %%
prefix = prompts.INSTRUCTION_PROMPT_PREFIX
instructions = []
total_instructions = len(search) // 10
for index in range(1, total_instructions + 2):
    start_index = (index - 1) * 10
    end_index = index * 10
    content = "\n".join([
        prompts.INSTRUCTION_PROMPT_CONTENT.format(question = data['question'], document = data['document'])
        for data in search[start_index:end_index]
    ])
    instruction = prefix + content
    instructions.append(instruction)

# %%
print(instructions[0])
# Out:
# 요청받은 question을 document를 참조하여 answer로 답변하세요.
# question 1개당 여러개의 document가 주어지며, question은 10개씩 전달됩니다.
#
# 요구사항은 다음과 같습니다:
# 1. 어휘의 다양성을 위해 같은 단어를 반복하지 않습니다.
# 2. 문장의 형태가 다양해야합니다. 예를 들어 질문과 명령형이 결합되는 형태여야 합니다.
# 3. 답변은 제공받는 document들을 기반으로 작성되어야 합니다.
# 4. 제공되는 document의 순서가 먼저 제공될 수록 더 중요한 데이터이므로 답변에 더 많은 영향을 끼쳐야합니다.
# 5. 답변은 자세한 내용이 포함되도록 제공되어야하지만 200단어를 넘지 않는 것이 좋습니다.
#
# 출력 형식은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 각 question마다 출력 형식은 다음과 같아야합니다:
# {'question': '전달 받은 question의 내용', 'answer': '답변 내용'}
#
# ###question:
# 전세 계약 기간은 보통 얼마나 되나요?
# ###document:
# 1. 말해야 되나요? 주택임대차보호법 제 6조 제 1항 (계약의 갱신) 계약이 해지되기 6개월 전부터 2개월 전까지, 계약을 해지하겠다는 통보를 해야 한다. 즉, 법률상 늦어도 계약이 종료되기 2개월 전까지는 임대인에게 말해야 된다는 뜻인데요. 만약 해당 기간 안에 말하지 않았다면? 자동으로 연장되는 묵시적 갱신이 될 수 있습니다. 때문에, 종료 시점에 맞춰서 자금을...
# 2. 기간을 보통 2달 정도 주게 되는데, 해당 기간 내 임대인은 건설사에 중도금 대출과 잔금을 모두 상환해야 하기 때문에 금액이 떨어지게 됩니다. 오늘은, 미등기 신축 아파트 전세 계약... 요즘은, 임차인이 전세를 구할 때 전세자금 대출을 받는 경우가 상당히 많습니다. 그런데 대출에 필요한 모든 서류를 은행에 제출했을 경우 은행에서 대출금이 나오는지?는...
# 3. 전세보증금반환소송 유리한 결과를 위해 전세 보증금은 결국 임대인과 임차인이 계약을 하게 된 시점부터 법적 효력이 가능한 기간 동안 임차인이 임대인의 부동산을 사용하겠다는... 사례에는 얼마나 더 다양한 시점이 있는지를 사전에 꼭 파악한 뒤 철저히 준비를 해야 한다고 하였습니다. 인가결정이나도 안도할 수 없어 반환금 지급 명령은 인가 결정이 되었다고...
# 4. 전세사기변호사 법무법인 이현 부동산 소송 전략센터입니다. 대여금반환청구소송에 급여채권가압류, 추심까지 책임져드렸어요 생각보다 많은 분들이 겪고 있는 문제입니다. 얼마나... 수원전세사기변호사 ‘내용증명’을 통해 보다 확실하게 계약만료를 알릴 수 있습니다. 내용증명에는 집주인에게 ‘부동산 목적물’ ‘임차’ ‘만료일’ ‘종료...
# 5. 생각하면 전세사기 초기 때의 내 예전 모습이 떠올라서, 마음이 찡해진다... 얼마나 힘드실까... 그래서 결심했다. 그 사람들을 위해서, 정보의 사막 속에서 몸소 필요한 정보를 찾고... 어, 근데 계약기간이 남았다? 1. 이사 가고 싶다. 2. 전세금 반환 소송을 걸고 싶다. (승소 후 재산 압류, 경매 진행, 채권추심 하고 싶다.) 1, 2 중 하나에 해당된다면, 중도해지하는 걸...
#
#
# ###question:
# 전세 계약서에는 어떤 내용이 포함되어야 하나요?
# ###document:
# 1. 전세사기 근저당과 같은 문제는 으로 인해 발생합니다. 는 있지만 실제로 많은 사람들이 돈을 빌려준다면 원금이나 이자를 갚지 못하는 경우가 많기 때문에 꼭 알아두시는 것이 좋습니다. 주의를 하셔야 할 내용들을 하나하나 정리해보았으니 자세하게 살펴보겠습니다만 이 글을 마무리하고자 합니다. 조언드렸지만 현재 진행 중인 을 정리해 보자면 다음과...
# 2. 부동산 계약서 양식 어떻게 구성되어 있고 어떤 내용들을 포함하고 있을까요? 부동산 계약서 양식은 어떠한 방식으로 되어있고 어떠한 내용들을 포함하고 있는지 말씀드리겠습니다. 이... 매매 계약서의 양식은 서울중앙지방법원-양식-생활 속의 계약서 경로로 가시면 확인이 가능하십니다. 부동산 양식 하고 있는 더 상세 간단하게 씩 차근차근 말씀을...
# 3. 안녕하세요 여러분 :) 전세 계약을 준비중이라면 전세계약서 양식이 어떻게 되어 있는지 어떤 내용이 들어가는지 꼼꼼히 준비하는 것이 좋습니다. 워낙 전세사기 피해자분들이 많이... 전세계약서 양식은 네이버에 검색하면 유료, 무료 많이 올라와 있습니다. 필요한 만 들어가면 되기 때문에 아무거나 다운받으셔도 되는데요. 저도 오늘 링크 가지고 왔습니다. 이...
# 4. 등기부등본과 계약서의 주소명이 다를 경우 법적 문제가 발생할 수 있는데요. 특히 임대차 소송에서 많이 제기되는 문제 중 하나가 소재지의 명확하지 않는 주소 때문이라고 합니다.... 오늘은 월세와 전세의 부동산 임대차 계약서 작성방법 및 직거래 시 주의사항에 대하여 알아보았는데요. 작성이 비교적 간단하게 보이더라도 주의하실 들이 많기 때문에...
# 5. 조건 등 상세 내용 포함 이번에는 중소기업 청년 전세자금대출의 조건과 더불어서 여러 가지 상세 내용에 대해서 알아보도록 하겠습니다. 중소기업취업청년 전월세보증금대출이라는... 이 외에도 소득확인 시 서류와, 주택관련 확정일자부 임대차계약서 사본, 임차주택 건물 등기사항전부증명서 등이 필요합니다. 중소기업 재직 확인을 위한 서류도 미리 구비하시길...
#
#
# ###question:
# 전세 계약 시 부동산 중개수수료는 어떻게 책정되나요?
# ###document:
# 1. 부동산 중개 수수료는 전세 계약 시 필수적으로 고려해야 할 비용입니다. 이러한 정보를 미리 알고 계시면, 부동산 계약을 보다 투명하고 안정적으로 진행할 수 있습니다. 부동산 중개수수료는 할인이 가능할까요? 부동산 중개수수료에 대한 할인은 가능한 경우도 있지만, 이는 여러 요인에 따라 다릅니다. 여기 몇 가지 중요한 사항들을 고려해야 합니다 법적 상한선...
# 2. 전세(월세)계약 중도해지 시, 부동산 중개수수료 누가 부담? 안녕하세요. 명지국제KB부동산 명지김선생입니다. 특별한 경우가 아닌 이상 보통 전세계약 또는 월세계약시 임대차기간(주택)은 2년으로 계약합니다. 하지만, 피치 못할 사정으로 인해 계약기간을 채우지 못하고 여러 가지 사정으로 중도해지를 해야 되는 경우가 발생할 수 있습니다. 임차인은 어쩔 수 없이...
# 3. 이제 본론으로 넘어와서 매매와 전세, 월세 계약 시 부동산 중개 수수료에 대해 알아보겠습니다. 매매 시 부동산 중개 수수료 주택 매매시 5천만원 까지는 최대 25만원을... 5억짜리 전세를 들어갈 때는 0.3%로 150만원이 복비입니다.(VAT 별도) 월세의 경우에는? 월세는 계산할까요? 매달 내는 월세에 100을 곱한 금액을 보증금에 더한 값을 기준으로...
# 4. 일단 시세에 맞춰 계약을 하게 되었고 계속 거래 중인 부동산 사장님 이번에도 거래를 하게 되어 일단 계약 전 부동산 사장님과 전세중개수수료에 대해 조율하게 되었어요. 전세금이 6억이 넘어가니 부동산중개보수 요율이 0.4%더라고요. T.T 임대차 중개보수 요율이 서울시 기준 1억~ 6억 미만 구간은 0.3% 6억부터 12억 미만 구간은 0.4% 계산을 해보면 가가 6억이라면...
# 5. 임대차 계약 시 임대차 계약 시에는 조금 다르게 적용됩니다. 먼저 3억원 미만 주택 임대차 시에는 부동산 중개수수료가 0.3%로 통합되고, 이후 3억원부터 6억원 미만 주택은 0.4%의 중개수수료와 30만원 공제가 적용됩니다. 6억원에서 9억원까지는 0.5%의 와 90만원 공제가 적용되며, 9억원에서 12억원까지는 0.4% 가 적용되고요. 이후 이후 6억원마다...
#
#
# ###question:
# 전세 계약 갱신 시 주의해야 할 점은 무엇인가요?
# ###document:
# 1. 만약 전세 계휙중이라면 여기 공도사 카페에 올라와 있는 전세 관련 글을 많이 참고해보시길 바랍니다. 전세 묵시적 갱신 외에도 꼭 알아야 할 것, 계약 시 주의사항 등 유용한 정보들이 올라와 있습니다. 여기까지 읽어주셔서 감사드리며 오늘 하루도 수고 많으셨습니다. ▼ 무상임대차서 작성 사항 한 눈에 확인
# 2. 증액되었을 경우에는 이 부분에대한 계약서를 작성하여 추가적으로 증액된 금액에 대해서도 확정일자로 보호를 받으셔야 하겠습니다. 여기까지 전세계약연장 갱신시 주의할 점을 정리해봤는데요. 사실 공인중개사무실을 통 할 경우 대부분은 중개사가 미리 확인을 해주는 경우가 많지만 혹시라도 발생할 수 있는 상황에 대비하여 꼼곰히 직접 챙겨주셔야 하겠습니다.
# 3. 전세 계약 갱신 주의할 점 주거를 마련한는 방법은 자가,전세,월세 등으로 사는 경우들이 있습니다.특히나 전월세 계약이 만료되면 집주인은 세입자에게 보증금을 돌려줘야하는데요.... 방법이라고 할 수 있겠습니다. 하지만 요즘 같이 역전세 현상에서 전세 계약 갱신 시 다시 한번 해당 주택 관련 서류 체크해보는것이 필요하며 동일한 상태에서 서로 진행하는 경우도...
# 4. 여기서 주의해야 되는 부분은 임차인은 연장 후 언제든 해지 통보를 할 수 있으며 3개월 이후 계약 해지 효력이 발생됩니다. 반대로 임대인은 중간에 해지 통보를 할 수 없으며 연장된 계약기간을 모두 충족해야 됩니다. 전세 계약 장점 전세 계약에 보증금은 일반적으로 임차료에 20~30배로 측정됩니다. 국내에서는 임차인 보호 규정으로 최저 임대 기간을 2년으로 정하고...
# 5. 요즘처럼 이렇게 정보를 쉽게 얻을 수 있고, 많은 것이 발전했음에도 불구하고 아직까지도 계약을 할 때 선량한 사람들에게 사기를 치는 경우가 많습니다. 특히 이제 막 사회에 나온 청년들이 주택을 계약할 때 이런 상황이 발생되는 경우가 많은데요. 그래서 오늘은 월세 사항 정리, 청구권 등에 대해서 알아보도록 하겠습니다. 바로 시작할게요!...
#
#
# ###question:
# 전세 계약 종료 시 보증금 반환은 어떻게 이루어지나요?
# ###document:
# 1. 전세계약 종료 또는 중도해지 시 전세보증금 반환절차 및 방법 전세자금대출 질권 근질권 설정통지서 전세계약 종료 시 전세보증금 반환 절차 및 방법 전세보증금을 마련하기 위해서... 그렇다면 임대인은 전세계약이 종료되어 보증금을 반환해야 할 때 누구에게 해야 할까요? 일반적으로 임대인이 생각할 수 있는 절차 및 방법은 임차인에게...
# 2. 전세보증금반환소송 사전 파악은 전세계약이 종료됨에도 반환이 이뤄지지 않으면서 거의 전 재산이나 다름없는 돈을 날릴 처지에 놓이게 된 분들이 많다고 했는데요. 더욱이 은행에서 빌린 대출금 대부분을 반환하지 않은 상황에서 약정기간이 만료돼 이사를 해야 하는 상황인데 집주인에게 을 돌려받지 못하면서 막대한 재산적 피해가 초래되기도 했습니다....
# 3. 계약 종료 의사를 반드시 표현하고 전화 녹음과 문자 메시지처럼 증거를 남길 수 있는 자료를 만들어야 한다고 하였습니다. 보통 부동산 계약 경험이 많지 않은 사람들의 경우 이런 문제들을 겪게 되었을 때 크게 당황할 수 있다고 하였습니다. 이에 따라 제때 제대로 된 대처를 하지 못하고 피해를 고스란히 받게 되는 경우도 많다고 하였습니다. 물론 청구소...
# 4. 圖 씨는 이 사태를 어떻게 해결해 나가야 할지 고민하게 되었습니다. 여러 차례 變 씨에게 연락을 시도했음에도 불구하고, 變 씨의 응답이 없자 圖 씨는 문제를 혼자 해결할 수 없다고... 또한, 이러한 문제를 예방하기 위해서는 임대차 계약 시 보증금 반환 조건을 명확히 하는 것이 중요합니다. 또다른 소송 사건의 주인공 學 씨는 직장생활로 인해 분주한...
# 5. 먼저 송달함에 있어 세입자 측이 전세보증금반환소송장을 재판소에 제출하면 즉시 소장 부본을 임차인에게 전달하여 다음 기일 지정에서 판사는 변론기일을 정하여 법률관계에 따라 심사를 한다고 했는데요. 계약의 종료에 따른 보증금 미발 후와 혜택이 명백한 경위 판사는 통상 1회의 변론기일에 심리를 종결한다고 했습니다. 최후의 판결에 관한 것은 변론 종결 후 바로...
#
#
# ###question:
# 전세 계약 중 집주인이 바뀌면 어떻게 해야 하나요?
# ###document:
# 1. 전세 계약기간중 집주인이 바뀌면 어떻게 해야하나요? 화창한 불금입니다. 이번한주도 화이팅 하셨나요. 최근 뉴스에서 들려오는 전세사기 깡통전세에 대한 피해소식이 야속하기만... 전세 계약시 특약사항을 꼼꼼하게 체크해야 합니다. 전세계약 기간 중 매매로 소유권이 변경될 경우 이 사실을 임차인에게 알려야 한다는 고시를 해야합니다. 또 채무관계가 변경되는 일은...
# 2. 되었는데 집주인이 바뀌었다고 연락이 왔어요. 매매했다고요. 전 주인분 말로는 계약서가 그대로 효력이 있으니 안바꿔도 된다고 하시네요. 저는 전세로 있고, 전세, 월세 섞여있는... 받아두었어요 저는 어떻해 해야 안전할까요? 1. 전세 계약서를 새주인과 다시 쓴다. 2. 전주인과 쓴 전세계약서(4년전 쓴)가 효력이 있으므로 다시 쓸필요 없다. 1,2번중 할까요?
# 3. 전세 임대계약 중 집주인 바뀌면 어떻게 해야할까 간혹 전세 계약기간 중 집주인이 바뀌는 경우가 있습니다. 기존의 집주인이 집을 매매한 경우입니다. 전세 임대계약에서 집주인이 변경되면 몇 가지 중요한 절차를 따라야 합니다. 이번 포스팅에서는 전세 계약 기간 바뀌었을 때 반드시 확인해야 할 사항들을 알려 드리겠습니다. 먼저 새 과의 임대...
# 4. 바뀌면 주의 및 확인할 점 집주인이 전세계약기간 중에 바뀌었다. 세입자 입장에서 무슨 일을 주의해야하며 확인해야 안전하게 전세 보증금을 지킬 수 있을가? 계약서 다시 써야하나?... 그렇게 하지 않으면 살던 집을 그냥 뺀 것과 같아 집주인에게 보증금을 반환 받지 못할 수도 있다. 특약사항 기간 매매로 소유권이 변경되면 이 사실을 임차인에게 알려야...
# 5. 현재 LH전세임대로 살고 있는데 집주인이 집을 내놓으셨다고 해요 집이 팔려도 저는 계약기간까지 살수 있나요? 혹여 집이 팔려 나가라고 하면 나가야 될까요? 중간에 나가게 되면 LH쪽에서 다시 전세임대를 알아봐주시나요? - 가구원수 = 명 - 부양의무자 = - 재산(금융&일반,부동산) = 만원 - 소득(양육비포함) = 만원/월 - 소득발생자 나이 = - 부채 = 만원 - 자동차(배기량...
#
#
# ###question:
# 전세 계약 시 등기부등본은 왜 확인해야 하나요?
# ###document:
# 1. 오늘은 전월세 계약 시 필히 확인해야 할 등기부등본(등기사항전부증명서)을 확인하는 방법에 대해 말씀드리고자 합니다. 부동산을 통해 계약을 진행하니, 등기부등본을 발급해 주고... 것은 등기부등본 첫 장의 맨 위의 주소란 입니다. 내가 본 곳의 주소와 동/호수가 맞는지 합니다. 또한 에 에 전힌 주소와 서상의 주소가 일치해야...
# 2. 지금까지 등기부등본을 꼼꼼하게 확인했어도 전세 사기를 당할 수 있는 사례들을 살펴봤습니다. 최근 전세 사기가 점점 고도화∙지능화되면서 피해 역시 커지고 있는 상황인데요. 등기부등본을 통해 미쳐 파악하지 못한 부분이 있을 수 있기 때문에 전세 사기 유형 및 대처 방안을 잘 숙지하고,  반드시 주의하시길 바랍니다....
# 3. 전세,월세 계약시 등기부등본 확인방법 안녕하세요~ 공인중개사 신화영입니다. 오늘 포스팅할 내용은 아파트 전,월세 계약시 등기부등본 확인하는 방법에 대해 글을 써보려고 합니다. 요즘같이 이사철에 전,월세 아파트를 알아보실텐데요~ 여러군데 집을 많이 보다가 이집이다! 싶으면 바로 을 하게되죠. 이때 아무리 마음에 꼭 드는 집을 발견하셨더라도 금 일부...
# 4. 필수 등기부등본 확인 사항들 전세 계약 시 등기부등본이란, 해당 부동산의 소유자, 부동산의 권리 상태, 부동산에 대한 채무 관계 등을 확인할 수 있는 식적인 문서를 말합니다. 1.... 전에는 등기부등본을 통해 부동산의 상태를 확인하고, 필요하다면 전문가의 도움을 받는 것이 좋습니다. 보는 필수 항목들 사기 피해를 방지 하기 위해 중요한 방법중 ...
# 5. 등기부 등본을 잘 확인하지 않고 계약을 했다가 낭패를 보거나 크게 손해를 보는 경우가 종종 발생하곤 하는데요 특히 전세같은 나의 거의 전재산이 등기부 등본을 잘못 봐서 위험한 경우가 간혹 생기곤 할때는 정말 괴로운일이 아닐수 없습니다. 특히 근저당권에서 가장 문제가 되는 부분은 액수인데 예를 들면 3억짜리 아파트에 근저당권이 2억5000정도 걸려있는...
#
#
# ###question:
# 전세 계약 기간 중 월세로 전환하는 것이 가능한가요?
# ###document:
# 1. 요즈음은 전세 계약을 월세로 전환하기를 희망하는 사람들이 많아지고 있어요. 왜 그럴까요? 그 이유는 부동산 가격 하락으로 인하여 전세 세입자가 전세 기간이 만료가 되었음에도... 그래서 오늘은 전세 계약을 월세로 전환할 때 적용되는 전월세 전환율에 대하여 알아볼게요. 전월세 율이란 를 바꿀 때나 월세를 로 바꿀 때 보증금과 월세의...
# 2. 임대차 기간 중, 새로운 임대인으로 바뀌면서 생기는 여러 가지 경우들이 있는데요. 오늘은 새로운 임대인이 기존 전세 계약을 월세 계약으로 전환한다고 일방적 통보를 받게 된... 2년 전세로 계약을 했습니다. 그러던 중에, 임대차 기간이 1년 지난 시점에서 건물주가 바뀌었습니다. 새로운 건물주는 보증금 5천만 원만 남기고 나머지는 돌리겠다고 합니다....
# 3. 아파텔 구조로 19평, 방3화2 살고 있어요~ 전세로 3억 3천 , 2년+2년 살았고(7월 만기), 월세로 돌리고자 해요. <전월세전환율>이라고 네이버에 계산기도 있고, 월세로 전환시 참고하는것 같던데요. 이게 좀 저렴하게 책정되는것 같더라구요... 이걸로 계산하는거 집주인이 싫어하나요? 이 근처에 월세가 많지 않아 참고할게 없기도 하고, 아파트가 아니다보니 이렇다 할...
# 4. 2023년 6월말 제가 소유하고 있는 부동산 중 하나의 전세계약 만기가 도래합니다. 1월부터 부동산을 통해 매물을 내놓았고, 매매 또는 월세 둘다 내놓았습니다. 원래는 매도를 하고 싶었지만 3월경엔 워낙 경기가 안좋고 살려는 사람이 없어서, 마음을 접고 있긴 했습니다. 다행히 라도 들어오겠다는 사람이 있어서 월세을 했습니다. 이걸로 월세를 받는 부동산이...
# 5. 연장 계약을 요청드렸다. 집주인(임대인)분께서는 2년 연장은 가능하지만 최근 집값이 많이 올라서 5% 인상을 말씀하셨고, 5% 인상분에 대한 이자를 월세 개념으로 받고 싶어 하셨다. 쉽게 말하면 기존 전세계약에서 → 월세계약으로 전환되는 것을 의미 기존 금을 보증금으로 하고 5% 인상분을 내는 개념이다. 를 계산하는 방법은 네이버...
#
#
# ###question:
# 전세 계약 시 확인해야 할 집의 하자 사항은 무엇인가요?
# ###document:
# 1. 한마디로, 계약기간이나 해지 조건 등에 대한 사항들을 자유롭게 계약할 수 있다는 것이죠. 무엇보다 어느 한 쪽에 불리한 조건으로 전세 월세 계약이 진행되지 않기 위해서 넣는 것이... 세번째는 계약을 다 한 후에 받아야 할 서류입니다. 이는 공인중개사법에 의거한 것이며, 서 작성을 완료한 후에도 중개대상물의 과 설명서 그리고 공제증서를 받아야 합니다....
# 2. 지급 계약서는 서브, 메인은 예쁜 혜리님 계약서 작성시 반드시 체크! 계약서 작성한지 한달 좀 된 거 같은데 벌써 가물가물하네요ㅎㅎ ✅ 계약서상 임대인이 실제 임대인인지 확인해야... 임대 계약서 특약에 ' 입주당일의 다음날까지 임차주택에 전세권, 저당권 등 담보권 설정을 수 없다' 는 문구를 넣어달라고 하세요 ✅ 저는 월세였고, 보증금이 최우선변제금 내여서...
# 3. 최근 전세 사기가 사회적 문제로 대두되면서 전세 계약 전, 계약 시 확인해야 할 사항은 많은 분들이 알고 계실 것이라고 생각합니다. 하지만 전세 계약 후 확인해야 할 사항은 잘... 전세 계약 종료 후 확인사항(3) : 임차권등기명령 부동산 계약 관련하여 '임차권등기명령'이라는 용어가 참 많이 등장하는데요. 그렇다면 '임차권등기명령'이란 무엇일까요? 출처: 네이버...
# 4. 그런데 이때 본인은 전세계약 연장을 원하지만 집주인이 일방적으로 퇴거 요청을 할 수도 있습니다. 그럴 경우 계약 갱신 청구권을 요구하면 되는데 이는 임차인의 권익이 보호될 수 있도록 만들어진 제도로 만기 6개월 전에서 한 달 이내에 임대인에게 요청할 1회에 한 해 거주 기간을 2년 더 늘릴 수 있습니다. 정당 사유가 없다면 주인은 이 제안을 거절하는 게...
# 5. 전세사기 예방위한 전세계약시 주의사항 체크리스트 1. 임차주택 확인 전세가격 확인 중요하게 생각되는 부분이 반환보증가입이 되는지 체크해야 합니다. ✔ 보증금 확인 ① kb부동산... 전세보증금 대출 및 반환보증 특약 임대인은 전세자금대출에 협조한다. (우편물 수령, 은행원 방문 서명 등) 물건의 로 대출승이 안될 경우 금 포함 보증금 반환해준다....
#
#
# ###question:
# 전세 계약 분쟁 발생 시 어떤 법적 대응을 할 수 있나요?
# ###document:
# 1. 상관되는 법적 대비까지 가해질 수 있으므로 적절한 대비를 마련하여 혐의에 대처하는 것이 타당하다고 재차 지적했는데요. 그동안 동료 간의 대립과 분쟁을 파악해 적개심이 있는 이해사이는 존재하나 폭력이 발생한 상황은 없다고 충언했습니다. 이에 더해 피고인 H씨와 J씨의 악감정을 계기로 고발이 했다고 주장하면서 실질적으로 무혐의 결론이 가능했다...
# 2. 안정 거리가 확보 되는 활동을 위배하면 상당히 무서운 법적 분쟁을 야기하며, 어떤 사유가 있다고 존재 해도 가정폭력은 행사하면 안된다고 간언드렸습니다. 자기의 목적 달성을 위해 배우자에게 상해를 입힌다고 한다면 냉혹한 현실을 바라볼 수 있다고 주장했는데요. 수사 진행이 가중되는 것은 당연한 이치이며 피의자 입장에서는 옳은 판단으로 소명할 기회가...
# 3. 사실 이러한 통보는 연락수단의 일종에 불과하기 때문에 어떤 내용을 담아서 보낸다고 해도 법적 효력이 발생하지는 않는다고 안내했습니다. 하지만 내용증명의 경우 우체국을 통해 전달하는 것이기 때문에 객관적인 증거가 남는다고 언급했는데요. 이에 소송을 진행할 경우 임대인과 이 있었는지 간편하게 소명할 수 있다고 언급했습니다. 다시 말해, 내용증명을...
# 4. 천 리 길도 한 걸음부터 전세계약중도해지 분쟁이 발생한다면 임대인도 임차인도 각자의 사정이 있어 힘든 시간을 보낼 수밖에 없는데요. 아무래도 당사자 간의 합의를 이끌어낼 수... 저희는 수없이 많은 임대인을 상대해 봐서 그 수도 어느 정도 예측이 되니까, 그에 맞춰서 할 수 있게 도와드릴 수 있죠. ▼금 돌려받는 방법 더 자세히 알아보고 싶다면▼
# 5. 분양권 계약을 진행하기로 마음먹었다고 했는데요. 하지만 오씨가 계약하고 난 이후 경제적인 어려움이 전 세계적으로 불어닥치면서 금리가 계속해서 인상되고 환율까지 오르는 등... 변호인은 분양권 계약은 매우 신중하게 이루어져야 하며 계약 내용을 세밀하게 검토하지 않을 경우 추후 분양해지를 원한다 하더라도 이 할 수 있다는 점을 유념해야...

# %% [markdown]
# 포맷팅하여 완성한 프롬프트는 아래와 같습니다.
# 아래 데이터를 ChatGPT API로 넘겨줍니다.

# %%
print(instructions[0][:2000])
# Out:
# 요청받은 question을 document를 참조하여 answer로 답변하세요.
# question 1개당 여러개의 document가 주어지며, question은 10개씩 전달됩니다.
#
# 요구사항은 다음과 같습니다:
# 1. 어휘의 다양성을 위해 같은 단어를 반복하지 않습니다.
# 2. 문장의 형태가 다양해야합니다. 예를 들어 질문과 명령형이 결합되는 형태여야 합니다.
# 3. 답변은 제공받는 document들을 기반으로 작성되어야 합니다.
# 4. 제공되는 document의 순서가 먼저 제공될 수록 더 중요한 데이터이므로 답변에 더 많은 영향을 끼쳐야합니다.
# 5. 답변은 자세한 내용이 포함되도록 제공되어야하지만 200단어를 넘지 않는 것이 좋습니다.
#
# 출력 형식은 JSON형식을 따라야 합니다.
# Indentation은 없도록 출력하세요.
# 각 question마다 출력 형식은 다음과 같아야합니다:
# {'question': '전달 받은 question의 내용', 'answer': '답변 내용'}
#
# ###question:
# 전세 계약 기간은 보통 얼마나 되나요?
# ###document:
# 1. 말해야 되나요? 주택임대차보호법 제 6조 제 1항 (계약의 갱신) 계약이 해지되기 6개월 전부터 2개월 전까지, 계약을 해지하겠다는 통보를 해야 한다. 즉, 법률상 늦어도 계약이 종료되기 2개월 전까지는 임대인에게 말해야 된다는 뜻인데요. 만약 해당 기간 안에 말하지 않았다면? 자동으로 연장되는 묵시적 갱신이 될 수 있습니다. 때문에, 종료 시점에 맞춰서 자금을...
# 2. 기간을 보통 2달 정도 주게 되는데, 해당 기간 내 임대인은 건설사에 중도금 대출과 잔금을 모두 상환해야 하기 때문에 금액이 떨어지게 됩니다. 오늘은, 미등기 신축 아파트 전세 계약... 요즘은, 임차인이 전세를 구할 때 전세자금 대출을 받는 경우가 상당히 많습니다. 그런데 대출에 필요한 모든 서류를 은행에 제출했을 경우 은행에서 대출금이 나오는지?는...
# 3. 전세보증금반환소송 유리한 결과를 위해 전세 보증금은 결국 임대인과 임차인이 계약을 하게 된 시점부터 법적 효력이 가능한 기간 동안 임차인이 임대인의 부동산을 사용하겠다는... 사례에는 얼마나 더 다양한 시점이 있는지를 사전에 꼭 파악한 뒤 철저히 준비를 해야 한다고 하였습니다. 인가결정이나도 안도할 수 없어 반환금 지급 명령은 인가 결정이 되었다고...
# 4. 전세사기변호사 법무법인 이현 부동산 소송 전략센터입니다. 대여금반환청구소송에 급여채권가압류, 추심까지 책임져드렸어요 생각보다 많은 분들이 겪고 있는 문제입니다. 얼마나... 수원전세사기변호사 ‘내용증명’을 통해 보다 확실하게 계약만료를 알릴 수 있습니다. 내용증명에는 집주인에게 ‘부동산 목적물’ ‘임차’ ‘만료일’ ‘종료...
# 5. 생각하면 전세사기 초기 때의 내 예전 모습이 떠올라서, 마음이 찡해진다... 얼마나 힘드실까... 그래서 결심했다. 그 사람들을 위해서, 정보의 사막 속에서 몸소 필요한 정보를 찾고... 어, 근데 계약기간이 남았다? 1. 이사 가고 싶다. 2. 전세금 반환 소송을 걸고 싶다. (승소 후 재산 압류, 경매 진행, 채권추심 하고 싶다.) 1, 2 중 하나에 해당된다면, 중도해지하는 걸...
#
#
# ###question:
# 전세 계약서에는 어떤 내용이 포함되어야 하나요?
# ###document:
# 1. 전세사기 근저당과 같은 문제는 으로 인해 발생합니다. 는 있지만 실제로 많은 사람들이 돈을 빌려준다면 원금이나 이자를 갚지 못하는 경우가 많기 때문에 꼭 알아두시는 것이 좋습니다. 주의를 하셔야 할 내용들을 하나하나 정리해보았으니 자세하게 살펴보겠습니다만 이 글을 마무리하고자 합니다. 조언드렸지만 현재 진행 중인 을 정리해 보자면 다음과...
# 2. 부동산 계약서 양식 어떻게 구성되어 있고 어떤 내용들을 포함하고 있을까요? 부동산 계약서 양식은 어떠한 방식으로 되어있고 어떠한 내용들을 포함하고 있는지 말씀드리겠습니다. 이... 매매 계약서의 양식은 서울중앙지방법원-양식-생활 속의 계약서 경로로 가시면 확인이 가능하십니다. 부동산 양식 하고 있는 더 상세 간단하게 씩

# %% [markdown]
# `gpt-4-turbo`는 `gpt-4` 보다 성능이 좋으면서 가격은 1/3입니다.
# `gpt-4-turbo`를 사용하길 추천드립니다.
# [OpenAI 가격 정책](https://openai.com/pricing)을 참조하세요

# %%
for inst in tqdm(instructions):
    result = utils.get_completion(inst, model="gpt-4-turbo-2024-04-09")
    with open("instruction.jsonl", "a", encoding="utf-8") as f:
        for line in result.split("\n"):
            f.write(line)
            f.write("\n")
